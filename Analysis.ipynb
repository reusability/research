# %%
# import local modules.
from model.least_squares import LeastSquares
from model.tree_classifier import TreeClassifier
from model.nerual_net import NN
from model.k_nearest_neigbors import KNearestNeighbors
from model.decision_tree import DecisionTree
from model.support_vector_machine import SupportVectorMachine
from model.lmnn import LMNN

from utils import data_loader, pre_training_analysis_tools

# %%
# base method of every feature selection varation/method used 
def describe_data():
    # no feature selection
    display("no feature selection")
    data = data_loader.load_real_dataset(sqaured=False, remove_multicollinearity=False)
    pre_training_analysis_tools.all_model_score(data['train_x'],data['train_y'],data['test_x'],data['test_y'])
    
    display("for decision tree, after pca and variance removal")
    #for decision tree, after pca and variance removal
    data = data_loader.load_real_dataset(only_dt=True)
    pre_training_analysis_tools.all_model_score(data['train_x'],data['train_y'],data['test_x'],data['test_y'])
    
    display("using cfs after removing variance of zero")
    #using cfs after removing variance of zero
    data = data_loader.load_real_dataset(cfs_mi=True)
    pre_training_analysis_tools.all_model_score(data['train_x'],data['train_y'],data['test_x'],data['test_y'])
    
    display("after removing all 0 variance metrics, then doing pca")
    # printing pca - after removing all 0 variance metrics, then doing pca
    data = data_loader.load_real_dataset(only_pca=True)
    pre_training_analysis_tools.all_model_score(data['train_x'],data['train_y'],data['test_x'],data['test_y'])
    
    display("after removing variance and hihgly correlated at 0.9")
    # after removing variance and hihgly correlated at 0.9
    data = data_loader.load_real_dataset(sqaured=False, remove_multicollinearity=False)
    output_xy = pre_training_analysis_tools.variance_threshold(data['train_x'],data['train_y'])
    output_xy = pre_training_analysis_tools.remove_collinear_features(output_xy, 'maven_reuse', 0.90, 'True')
    data = pre_training_analysis_tools.generate_train_test_xy(output_xy)
    pre_training_analysis_tools.all_model_score(data['train_x'],data['train_y'],data['test_x'],data['test_y'])
    
    
describe_data()
# Out:
# 'no feature selection'
# knn accuracy:
# 0.7129629629629629
# 0.4444444444444444
#               precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00        18
#          2.0       0.44      1.00      0.62        24
#          3.0       0.00      0.00      0.00        12
#
#     accuracy                           0.44        54
#    macro avg       0.15      0.33      0.21        54
# weighted avg       0.20      0.44      0.27        54
#
# wkn accuracy:
# 0.7129629629629629
# 0.4444444444444444
#               precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00        18
#          2.0       0.44      1.00      0.62        24
#          3.0       0.00      0.00      0.00        12
#
#     accuracy                           0.44        54
#    macro avg       0.15      0.33      0.21        54
# weighted avg       0.20      0.44      0.27        54
#
# decision tree accuracy:
# 0.9768518518518519
# 0.3888888888888889
#               precision    recall  f1-score   support
#
#          1.0       0.34      0.83      0.48        18
#          2.0       0.60      0.25      0.35        24
#          3.0       0.00      0.00      0.00        12
#
#     accuracy                           0.39        54
#    macro avg       0.31      0.36      0.28        54
# weighted avg       0.38      0.39      0.32        54
#
# svm accuracy:
# 0.5509259259259259
# 0.4444444444444444
#               precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00        18
#          2.0       0.44      1.00      0.62        24
#          3.0       0.00      0.00      0.00        12
#
#     accuracy                           0.44        54
#    macro avg       0.15      0.33      0.21        54
# weighted avg       0.20      0.44      0.27        54
#
# LMNN accuracy on train set of 216 points: 0.9722
# LMNN accuracy on test set of 54 points: 0.4444
# 'for decision tree, after pca and variance removal'
# knn accuracy:
# 0.6527777777777778
# 0.46296296296296297
#               precision    recall  f1-score   support
#
#          1.0       0.33      0.11      0.17        18
#          2.0       0.48      0.96      0.64        24
#          3.0       0.00      0.00      0.00        12
#
#     accuracy                           0.46        54
#    macro avg       0.27      0.36      0.27        54
# weighted avg       0.32      0.46      0.34        54
#
# wkn accuracy:
# 0.6527777777777778
# 0.46296296296296297
#               precision    recall  f1-score   support
#
#          1.0       0.33      0.11      0.17        18
#          2.0       0.48      0.96      0.64        24
#          3.0       0.00      0.00      0.00        12
#
#     accuracy                           0.46        54
#    macro avg       0.27      0.36      0.27        54
# weighted avg       0.32      0.46      0.34        54
#
# decision tree accuracy:
# 0.9768518518518519
# 0.3333333333333333
#               precision    recall  f1-score   support
#
#          1.0       0.25      0.06      0.09        18
#          2.0       0.42      0.54      0.47        24
#          3.0       0.21      0.33      0.26        12
#
#     accuracy                           0.33        54
#    macro avg       0.29      0.31      0.27        54
# weighted avg       0.32      0.33      0.30        54
#
# svm accuracy:
# 0.5648148148148148
# 0.4444444444444444
#               precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00        18
#          2.0       0.44      1.00      0.62        24
#          3.0       0.00      0.00      0.00        12
#
#     accuracy                           0.44        54
#    macro avg       0.15      0.33      0.21        54
# weighted avg       0.20      0.44      0.27        54
#
# LMNN accuracy on train set of 216 points: 0.6528
# LMNN accuracy on test set of 54 points: 0.4444
# 'using cfs after removing variance of zero'
# knn accuracy:
# 0.6435185185185185
# 0.4444444444444444
#               precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00        18
#          2.0       0.44      1.00      0.62        24
#          3.0       0.00      0.00      0.00        12
#
#     accuracy                           0.44        54
#    macro avg       0.15      0.33      0.21        54
# weighted avg       0.20      0.44      0.27        54
#
# wkn accuracy:
# 0.6435185185185185
# 0.4444444444444444
#               precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00        18
#          2.0       0.44      1.00      0.62        24
#          3.0       0.00      0.00      0.00        12
#
#     accuracy                           0.44        54
#    macro avg       0.15      0.33      0.21        54
# weighted avg       0.20      0.44      0.27        54
#
# decision tree accuracy:
# 0.9768518518518519
# 0.42592592592592593
#               precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00        18
#          2.0       0.43      0.96      0.60        24
#          3.0       0.00      0.00      0.00        12
#
#     accuracy                           0.43        54
#    macro avg       0.14      0.32      0.20        54
# weighted avg       0.19      0.43      0.27        54
#
# svm accuracy:
# 0.5324074074074074
# 0.4444444444444444
#               precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00        18
#          2.0       0.44      1.00      0.62        24
#          3.0       0.00      0.00      0.00        12
#
#     accuracy                           0.44        54
#    macro avg       0.15      0.33      0.21        54
# weighted avg       0.20      0.44      0.27        54
#
# LMNN accuracy on train set of 216 points: 0.6435
# LMNN accuracy on test set of 54 points: 0.4444
# 'after removing all 0 variance metrics, then doing pca'
# knn accuracy:
# 0.6620370370370371
# 0.4444444444444444
#               precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00        18
#          2.0       0.44      1.00      0.62        24
#          3.0       0.00      0.00      0.00        12
#
#     accuracy                           0.44        54
#    macro avg       0.15      0.33      0.21        54
# weighted avg       0.20      0.44      0.27        54
#
# wkn accuracy:
# 0.6620370370370371
# 0.4444444444444444
#               precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00        18
#          2.0       0.44      1.00      0.62        24
#          3.0       0.00      0.00      0.00        12
#
#     accuracy                           0.44        54
#    macro avg       0.15      0.33      0.21        54
# weighted avg       0.20      0.44      0.27        54
#
# decision tree accuracy:
# 0.9768518518518519
# 0.42592592592592593
#               precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00        18
#          2.0       0.44      0.96      0.61        24
#          3.0       0.00      0.00      0.00        12
#
#     accuracy                           0.43        54
#    macro avg       0.15      0.32      0.20        54
# weighted avg       0.20      0.43      0.27        54
#
# svm accuracy:
# 0.5601851851851852
# 0.4444444444444444
#               precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00        18
#          2.0       0.44      1.00      0.62        24
#          3.0       0.00      0.00      0.00        12
#
#     accuracy                           0.44        54
#    macro avg       0.15      0.33      0.21        54
# weighted avg       0.20      0.44      0.27        54
#
# LMNN accuracy on train set of 216 points: 0.7361
# LMNN accuracy on test set of 54 points: 0.4259
# 'after removing variance and hihgly correlated at 0.9'
# Original feature shape: (216, 265)
# Transformed feature shape: (216, 209)
# publicMethodsQty_stdev | lcom_average | 0.93
# publicMethodsQty_stdev: 0.079
# lcom_average: 0.083
# dropped: publicMethodsQty_stdev
# -----------------------------------------------------------------------------
# staticFieldsQty_sum | publicMethodsQty_sum | 0.98
# staticFieldsQty_sum: 0.129
# publicMethodsQty_sum: 0.126
# dropped: publicMethodsQty_sum
# -----------------------------------------------------------------------------
# staticFieldsQty_max | staticFieldsQty_stdev | 0.9
# staticFieldsQty_max: 0.028
# staticFieldsQty_stdev: 0.024
# dropped: staticFieldsQty_stdev
# -----------------------------------------------------------------------------
# publicFieldsQty_sum | parenthesizedExpsQty_sum | 0.9
# publicFieldsQty_sum: 0.079
# parenthesizedExpsQty_sum: 0.106
# dropped: publicFieldsQty_sum
# -----------------------------------------------------------------------------
# publicFieldsQty_max | publicFieldsQty_stdev | 0.93
# publicFieldsQty_max: 0.005
# publicFieldsQty_stdev: -0.035
# dropped: publicFieldsQty_max
# -----------------------------------------------------------------------------
# lambdasQty_stdev | lambdasQty_average | 0.93
# lambdasQty_stdev: -0.023
# lambdasQty_average: 0.055
# dropped: lambdasQty_stdev
# -----------------------------------------------------------------------------
# logStatementsQty_sum | staticFieldsQty_sum | 0.9
# logStatementsQty_sum: 0.099
# staticFieldsQty_sum: 0.129
# dropped: logStatementsQty_sum
# -----------------------------------------------------------------------------
# tryCatchQty_sum | staticFieldsQty_sum | 0.92
# tryCatchQty_sum: 0.043
# staticFieldsQty_sum: 0.129
# dropped: tryCatchQty_sum
# -----------------------------------------------------------------------------
# maxNestedBlocksQty_sum | parenthesizedExpsQty_sum | 0.9
# maxNestedBlocksQty_sum: 0.098
# parenthesizedExpsQty_sum: 0.106
# dropped: maxNestedBlocksQty_sum
# -----------------------------------------------------------------------------
# wmc_sum | parenthesizedExpsQty_sum | 0.91
# wmc_sum: 0.108
# parenthesizedExpsQty_sum: 0.106
# dropped: parenthesizedExpsQty_sum
# -----------------------------------------------------------------------------
# wmc_sum | staticFieldsQty_sum | 0.97
# wmc_sum: 0.108
# staticFieldsQty_sum: 0.129
# dropped: wmc_sum
# -----------------------------------------------------------------------------
# rfc_sum | staticFieldsQty_sum | 0.97
# rfc_sum: 0.122
# staticFieldsQty_sum: 0.129
# dropped: rfc_sum
# -----------------------------------------------------------------------------
# privateMethodsQty_sum | staticFieldsQty_sum | 0.93
# privateMethodsQty_sum: 0.155
# staticFieldsQty_sum: 0.129
# dropped: staticFieldsQty_sum
# -----------------------------------------------------------------------------
# visibleFieldsQty_max | visibleFieldsQty_stdev | 0.98
# visibleFieldsQty_max: 0.019
# visibleFieldsQty_stdev: 0.033
# dropped: visibleFieldsQty_max
# -----------------------------------------------------------------------------
# uniqueWordsQty_sum | privateMethodsQty_sum | 0.93
# uniqueWordsQty_sum: 0.093
# privateMethodsQty_sum: 0.155
# dropped: uniqueWordsQty_sum
# -----------------------------------------------------------------------------
# stringLiteralsQty_sum | privateMethodsQty_sum | 0.92
# stringLiteralsQty_sum: 0.088
# privateMethodsQty_sum: 0.155
# dropped: stringLiteralsQty_sum
# -----------------------------------------------------------------------------
# returnQty_sum | mathOperationsQty_sum | 0.92
# returnQty_sum: 0.139
# mathOperationsQty_sum: 0.057
# dropped: mathOperationsQty_sum
# -----------------------------------------------------------------------------
# modifiers_sum | privateMethodsQty_sum | 0.91
# modifiers_sum: 0.067
# privateMethodsQty_sum: 0.155
# dropped: modifiers_sum
# -----------------------------------------------------------------------------
# lcc_sum | privateMethodsQty_sum | 0.92
# lcc_sum: -0.102
# privateMethodsQty_sum: 0.155
# dropped: lcc_sum
# -----------------------------------------------------------------------------
# abstractMethodsQty_sum | privateMethodsQty_sum | 0.94
# abstractMethodsQty_sum: 0.117
# privateMethodsQty_sum: 0.155
# dropped: abstractMethodsQty_sum
# -----------------------------------------------------------------------------
# abstractMethodsQty_average | publicMethodsQty_average | 0.97
# abstractMethodsQty_average: 0.067
# publicMethodsQty_average: 0.05
# dropped: publicMethodsQty_average
# -----------------------------------------------------------------------------
# abstractMethodsQty_stdev | lcom_average | 0.91
# abstractMethodsQty_stdev: 0.084
# lcom_average: 0.083
# dropped: lcom_average
# -----------------------------------------------------------------------------
# abstractMethodsQty_median | publicMethodsQty_median | 0.93
# abstractMethodsQty_median: -0.007
# publicMethodsQty_median: -0.033
# dropped: abstractMethodsQty_median
# -----------------------------------------------------------------------------
# abstractMethodsQty_max | publicMethodsQty_max | 0.99
# abstractMethodsQty_max: 0.106
# publicMethodsQty_max: 0.08
# dropped: publicMethodsQty_max
# -----------------------------------------------------------------------------
# protectedFieldsQty_sum | privateMethodsQty_sum | 0.95
# protectedFieldsQty_sum: 0.133
# privateMethodsQty_sum: 0.155
# dropped: protectedFieldsQty_sum
# -----------------------------------------------------------------------------
# staticMethodsQty_sum | returnQty_sum | 0.91
# staticMethodsQty_sum: 0.12
# returnQty_sum: 0.139
# dropped: staticMethodsQty_sum
# -----------------------------------------------------------------------------
# staticMethodsQty_median | logStatementsQty_median | 0.9
# staticMethodsQty_median: -0.024
# logStatementsQty_median: nan
# dropped: logStatementsQty_median
# -----------------------------------------------------------------------------
# assignmentsQty_sum | privateMethodsQty_sum | 0.92
# assignmentsQty_sum: 0.097
# privateMethodsQty_sum: 0.155
# dropped: assignmentsQty_sum
# -----------------------------------------------------------------------------
# assignmentsQty_average | wmc_average | 0.92
# assignmentsQty_average: 0.102
# wmc_average: 0.149
# dropped: assignmentsQty_average
# -----------------------------------------------------------------------------
# finalFieldsQty_sum | privateMethodsQty_sum | 0.96
# finalFieldsQty_sum: 0.092
# privateMethodsQty_sum: 0.155
# dropped: finalFieldsQty_sum
# -----------------------------------------------------------------------------
# finalFieldsQty_stdev | publicFieldsQty_stdev | 0.98
# finalFieldsQty_stdev: -0.03
# publicFieldsQty_stdev: -0.035
# dropped: finalFieldsQty_stdev
# -----------------------------------------------------------------------------
# finalFieldsQty_max | publicFieldsQty_stdev | 0.94
# finalFieldsQty_max: 0.009
# publicFieldsQty_stdev: -0.035
# dropped: finalFieldsQty_max
# -----------------------------------------------------------------------------
# dit_sum | privateMethodsQty_sum | 0.94
# dit_sum: 0.124
# privateMethodsQty_sum: 0.155
# dropped: dit_sum
# -----------------------------------------------------------------------------
# totalMethodsQty_sum | privateMethodsQty_sum | 0.95
# totalMethodsQty_sum: 0.12
# privateMethodsQty_sum: 0.155
# dropped: totalMethodsQty_sum
# -----------------------------------------------------------------------------
# totalMethodsQty_average | abstractMethodsQty_average | 0.98
# totalMethodsQty_average: 0.104
# abstractMethodsQty_average: 0.067
# dropped: abstractMethodsQty_average
# -----------------------------------------------------------------------------
# totalMethodsQty_stdev | abstractMethodsQty_stdev | 0.99
# totalMethodsQty_stdev: 0.101
# abstractMethodsQty_stdev: 0.084
# dropped: abstractMethodsQty_stdev
# -----------------------------------------------------------------------------
# totalMethodsQty_max | abstractMethodsQty_max | 1.0
# totalMethodsQty_max: 0.102
# abstractMethodsQty_max: 0.106
# dropped: totalMethodsQty_max
# -----------------------------------------------------------------------------
# defaultFieldsQty_stdev | defaultFieldsQty_average | 0.9
# defaultFieldsQty_stdev: 0.109
# defaultFieldsQty_average: 0.055
# dropped: defaultFieldsQty_average
# -----------------------------------------------------------------------------
# loc_sum | privateMethodsQty_sum | 0.94
# loc_sum: 0.127
# privateMethodsQty_sum: 0.155
# dropped: loc_sum
# -----------------------------------------------------------------------------
# loc_average | wmc_average | 0.93
# loc_average: 0.171
# wmc_average: 0.149
# dropped: wmc_average
# -----------------------------------------------------------------------------
# loc_median | wmc_median | 0.97
# loc_median: 0.165
# wmc_median: 0.142
# dropped: wmc_median
# -----------------------------------------------------------------------------
# loc_median | assignmentsQty_median | 0.92
# loc_median: 0.165
# assignmentsQty_median: 0.115
# dropped: assignmentsQty_median
# -----------------------------------------------------------------------------
# cbo_sum | privateMethodsQty_sum | 0.96
# cbo_sum: 0.126
# privateMethodsQty_sum: 0.155
# dropped: cbo_sum
# -----------------------------------------------------------------------------
# variablesQty_sum | privateMethodsQty_sum | 0.94
# variablesQty_sum: 0.096
# privateMethodsQty_sum: 0.155
# dropped: variablesQty_sum
# -----------------------------------------------------------------------------
# variablesQty_median | loc_median | 0.92
# variablesQty_median: 0.132
# loc_median: 0.165
# dropped: variablesQty_median
# -----------------------------------------------------------------------------
# variablesQty_max | staticFieldsQty_max | 0.95
# variablesQty_max: -0.002
# staticFieldsQty_max: 0.028
# dropped: variablesQty_max
# -----------------------------------------------------------------------------
# protectedMethodsQty_sum | privateMethodsQty_sum | 0.91
# protectedMethodsQty_sum: 0.1
# privateMethodsQty_sum: 0.155
# dropped: protectedMethodsQty_sum
# -----------------------------------------------------------------------------
# tcc_sum | privateMethodsQty_sum | 0.92
# tcc_sum: -0.102
# privateMethodsQty_sum: 0.155
# dropped: tcc_sum
# -----------------------------------------------------------------------------
# tcc_average | lcc_average | 1.0
# tcc_average: 0.031
# lcc_average: 0.031
# dropped: lcc_average
# -----------------------------------------------------------------------------
# tcc_stdev | lcc_stdev | 1.0
# tcc_stdev: -0.008
# lcc_stdev: -0.008
# dropped: lcc_stdev
# -----------------------------------------------------------------------------
# tcc_median | lcc_median | 1.0
# tcc_median: -0.037
# lcc_median: -0.037
# dropped: lcc_median
# -----------------------------------------------------------------------------
# tcc_min | lcc_min | 1.0
# tcc_min: -0.058
# lcc_min: -0.058
# dropped: lcc_min
# -----------------------------------------------------------------------------
# privateFieldsQty_stdev | staticFieldsQty_max | 0.94
# privateFieldsQty_stdev: 0.014
# staticFieldsQty_max: 0.028
# dropped: privateFieldsQty_stdev
# -----------------------------------------------------------------------------
# privateFieldsQty_max | staticFieldsQty_max | 0.95
# privateFieldsQty_max: 0.026
# staticFieldsQty_max: 0.028
# dropped: privateFieldsQty_max
# -----------------------------------------------------------------------------
# finalMethodsQty_median | modifiers_median | 1.0
# finalMethodsQty_median: -0.108
# modifiers_median: -0.109
# dropped: finalMethodsQty_median
# -----------------------------------------------------------------------------
# innerClassesQty_sum | privateMethodsQty_sum | 0.95
# innerClassesQty_sum: 0.102
# privateMethodsQty_sum: 0.155
# dropped: innerClassesQty_sum
# -----------------------------------------------------------------------------
# comparisonsQty_sum | cbo_max | 0.91
# comparisonsQty_sum: 0.096
# cbo_max: 0.052
# dropped: cbo_max
# -----------------------------------------------------------------------------
# dropped columns:
# ['lcom_average', 'totalMethodsQty_sum', 'rfc_sum', 'modifiers_sum', 'assignmentsQty_sum', 'finalMethodsQty_median', 'publicFieldsQty_sum', 'publicMethodsQty_max', 'staticMethodsQty_sum', 'innerClassesQty_sum', 'uniqueWordsQty_sum', 'mathOperationsQty_sum', 'abstractMethodsQty_average', 'cbo_max', 'lcc_min', 'lcc_sum', 'assignmentsQty_average', 'variablesQty_max', 'dit_sum', 'visibleFieldsQty_max', 'wmc_sum', 'abstractMethodsQty_stdev', 'lcc_stdev', 'tcc_sum', 'publicMethodsQty_sum', 'maxNestedBlocksQty_sum', 'defaultFieldsQty_average', 'wmc_median', 'finalFieldsQty_stdev', 'tryCatchQty_sum', 'variablesQty_median', 'staticFieldsQty_stdev', 'abstractMethodsQty_sum', 'finalFieldsQty_max', 'totalMethodsQty_max', 'finalFieldsQty_sum', 'loc_sum', 'logStatementsQty_sum', 'lambdasQty_stdev', 'protectedFieldsQty_sum', 'publicMethodsQty_average', 'lcc_median', 'lcc_average', 'protectedMethodsQty_sum', 'abstractMethodsQty_median', 'variablesQty_sum', 'cbo_sum', 'parenthesizedExpsQty_sum', 'assignmentsQty_median', 'publicMethodsQty_stdev', 'stringLiteralsQty_sum', 'privateFieldsQty_stdev', 'privateFieldsQty_max', 'staticFieldsQty_sum', 'logStatementsQty_median', 'wmc_average', 'publicFieldsQty_max']
# -----------------------------------------------------------------------------
# used columns:
# ['synchronizedMethodsQty_sum', 'synchronizedMethodsQty_average', 'synchronizedMethodsQty_stdev', 'synchronizedMethodsQty_max', 'parenthesizedExpsQty_average', 'parenthesizedExpsQty_stdev', 'parenthesizedExpsQty_median', 'parenthesizedExpsQty_max', 'lcom_sum', 'lcom_stdev', 'lcom_median', 'lcom_max', 'publicMethodsQty_median', 'staticFieldsQty_average', 'staticFieldsQty_median', 'staticFieldsQty_max', 'publicFieldsQty_average', 'publicFieldsQty_stdev', 'publicFieldsQty_median', 'lambdasQty_sum', 'lambdasQty_average', 'lambdasQty_max', 'logStatementsQty_average', 'logStatementsQty_stdev', 'logStatementsQty_max', 'tryCatchQty_average', 'tryCatchQty_stdev', 'tryCatchQty_median', 'tryCatchQty_max', 'maxNestedBlocksQty_average', 'maxNestedBlocksQty_stdev', 'maxNestedBlocksQty_median', 'maxNestedBlocksQty_max', 'wmc_stdev', 'wmc_max', 'rfc_average', 'rfc_stdev', 'rfc_median', 'rfc_max', 'privateMethodsQty_sum', 'privateMethodsQty_average', 'privateMethodsQty_stdev', 'privateMethodsQty_median', 'privateMethodsQty_max', 'defaultMethodsQty_sum', 'defaultMethodsQty_average', 'defaultMethodsQty_stdev', 'defaultMethodsQty_median', 'defaultMethodsQty_max', 'nosi_sum', 'nosi_average', 'nosi_stdev', 'nosi_median', 'nosi_max', 'visibleFieldsQty_sum', 'visibleFieldsQty_average', 'visibleFieldsQty_stdev', 'uniqueWordsQty_average', 'uniqueWordsQty_stdev', 'uniqueWordsQty_median', 'uniqueWordsQty_max', 'stringLiteralsQty_average', 'stringLiteralsQty_stdev', 'stringLiteralsQty_median', 'stringLiteralsQty_max', 'anonymousClassesQty_sum', 'anonymousClassesQty_average', 'anonymousClassesQty_stdev', 'anonymousClassesQty_max', 'mathOperationsQty_average', 'mathOperationsQty_stdev', 'mathOperationsQty_median', 'mathOperationsQty_max', 'returnQty_sum', 'returnQty_average', 'returnQty_stdev', 'returnQty_median', 'returnQty_max', 'modifiers_average', 'modifiers_stdev', 'modifiers_median', 'modifiers_min', 'modifiers_max', 'abstractMethodsQty_max', 'protectedFieldsQty_average', 'protectedFieldsQty_stdev', 'protectedFieldsQty_median', 'protectedFieldsQty_max', 'numbersQty_sum', 'numbersQty_average', 'numbersQty_stdev', 'numbersQty_median', 'numbersQty_max', 'staticMethodsQty_average', 'staticMethodsQty_stdev', 'staticMethodsQty_median', 'staticMethodsQty_max', 'assignmentsQty_stdev', 'assignmentsQty_max', 'finalFieldsQty_average', 'finalFieldsQty_median', 'dit_average', 'dit_stdev', 'dit_median', 'dit_max', 'totalMethodsQty_average', 'totalMethodsQty_stdev', 'totalMethodsQty_median', 'loopQty_sum', 'loopQty_average', 'loopQty_stdev', 'loopQty_median', 'loopQty_max', 'defaultFieldsQty_sum', 'defaultFieldsQty_stdev', 'defaultFieldsQty_max', 'loc_average', 'loc_stdev', 'loc_median', 'loc_max', 'totalFieldsQty_sum', 'totalFieldsQty_average', 'totalFieldsQty_stdev', 'totalFieldsQty_median', 'totalFieldsQty_max', 'cbo_average', 'cbo_stdev', 'cbo_median', 'variablesQty_average', 'variablesQty_stdev', 'protectedMethodsQty_average', 'protectedMethodsQty_stdev', 'protectedMethodsQty_max', 'tcc_average', 'tcc_stdev', 'tcc_median', 'tcc_min', 'privateFieldsQty_sum', 'privateFieldsQty_average', 'privateFieldsQty_median', 'finalMethodsQty_sum', 'finalMethodsQty_average', 'finalMethodsQty_stdev', 'finalMethodsQty_max', 'innerClassesQty_average', 'innerClassesQty_stdev', 'innerClassesQty_max', 'comparisonsQty_sum', 'comparisonsQty_average', 'comparisonsQty_stdev', 'comparisonsQty_median', 'comparisonsQty_max', 'maven_reuse']
# knn accuracy:
# 0.6444444444444445
# 0.30434782608695654
#               precision    recall  f1-score   support
#
#          1.0       0.20      0.50      0.29         6
#          2.0       0.50      0.31      0.38        13
#          3.0       0.00      0.00      0.00         4
#
#     accuracy                           0.30        23
#    macro avg       0.23      0.27      0.22        23
# weighted avg       0.33      0.30      0.29        23
#
# wkn accuracy:
# 0.6444444444444445
# 0.30434782608695654
#               precision    recall  f1-score   support
#
#          1.0       0.20      0.50      0.29         6
#          2.0       0.50      0.31      0.38        13
#          3.0       0.00      0.00      0.00         4
#
#     accuracy                           0.30        23
#    macro avg       0.23      0.27      0.22        23
# weighted avg       0.33      0.30      0.29        23
#
# decision tree accuracy:
# 0.9666666666666667
# 0.4782608695652174
#               precision    recall  f1-score   support
#
#          1.0       0.14      0.17      0.15         6
#          2.0       0.64      0.69      0.67        13
#          3.0       0.50      0.25      0.33         4
#
#     accuracy                           0.48        23
#    macro avg       0.43      0.37      0.38        23
# weighted avg       0.49      0.48      0.47        23
#
# svm accuracy:
# 0.6444444444444445
# 0.4782608695652174
#               precision    recall  f1-score   support
#
#          1.0       0.17      0.17      0.17         6
#          2.0       0.59      0.77      0.67        13
#          3.0       0.00      0.00      0.00         4
#
#     accuracy                           0.48        23
#    macro avg       0.25      0.31      0.28        23
# weighted avg       0.38      0.48      0.42        23
#
# LMNN accuracy on train set of 90 points: 0.9556
# LMNN accuracy on test set of 23 points: 0.3913

# %%
# for decision tree, after pca and variance removal 
def describe_data():
    data = data_loader.load_real_dataset(only_dt=True)
    #pre_training_analysis_tools.all_model_score(data['train_x'],data['train_y'],data['test_x'],data['test_y'])
    
describe_data()

def main():
    data = data_loader.load_real_dataset(remove_multicollinearity=False, only_dt=True)
    # determine which model we are using.
    model = DecisionTree(data, normalize=True)
    #model.hyperparameter_tuning()
    model.train()
    model.describe()
    model.test()
    
main()
# Out:
# >> initialising model...
# >> training model...
# >> describing model...
# [0.1988119  0.17499966 0.09070767 0.07860006 0.21395062 0.11124857
#  0.13168152]
# >> predicting test data...
# >> assessing prediction performance...
# ESS: 65
# RSS: 8
# TSS: 72
# R-squared: 0.89
# correlation: -0.05
# 0.48148148148148145
#               precision    recall  f1-score   support
#
#          1.0       0.46      0.33      0.39        18
#          2.0       0.52      0.71      0.60        24
#          3.0       0.38      0.25      0.30        12
#
#     accuracy                           0.48        54
#    macro avg       0.45      0.43      0.43        54
# weighted avg       0.47      0.48      0.46        54

# %%
# using cfs after removing variance of zero
def main():
    # get data to use in this analysis.
    data = data_loader.load_real_dataset(remove_multicollinearity=False, cfs_mi=True)
    # determine which model we are using.
    model = KNearestNeighbors(data, normalize=True)
    model.hyperparameter_tuning()
    #model.train()
    #model.describe()
    #model.test()
    
    data = data_loader.load_real_dataset(remove_multicollinearity=False, only_proposed=True)
    # determine which model we are using.
    model = DecisionTree(data, normalize=True)
    model.hyperparameter_tuning()
    #model.train()
    #model.describe()
    #model.test()
    
    data = data_loader.load_real_dataset(remove_multicollinearity=False, only_proposed=True)
    # determine which model we are using.
    model = SupportVectorMachine(data, normalize=True)
    model.hyperparameter_tuning()
    #model.train()
    #model.describe()
    #model.test()
    
    data = data_loader.load_real_dataset(remove_multicollinearity=False, only_proposed=True)
    # determine which model we are using.
    model = LMNN(data, normalize=True)
    model.find_hyperparams()
    #model.train()
    #model.describe()
    #model.test()

main()
# Out:
# >> initialising model...
# The best parameters are OrderedDict([('leaf_size', 60), ('metric', 'manhattan'), ('n_neighbors', 2), ('p', 20), ('weights', 'distance')]) with a score of 0.52
# <bound method NDFrame.head of     leaf_size     metric  n_neighbors   p   weights  Accuracy
# 37         60  manhattan            2  20  distance  0.518519
# 49          1  manhattan            1  17  distance  0.515873
# 32          1  manhattan            1  20  distance  0.515873
# 47          1  manhattan            1   1  distance  0.515873
# 23          1  manhattan            1  20  distance  0.515873
# 22         15  manhattan            1  20  distance  0.515873
# 45          1  manhattan            1  20  distance  0.515873
# 33          1  manhattan            1  20  distance  0.515873
# 42          1  manhattan            1  20  distance  0.515873
# 40          1  manhattan            1  20   uniform  0.515873
# 39         10  manhattan            1  19   uniform  0.515873
# 36          1  manhattan            3  20  distance  0.515873
# 28         60  manhattan            1   3   uniform  0.513228
# 26         48  manhattan            1   3   uniform  0.513228
# 31         60  manhattan            1   1   uniform  0.513228
# 18         50  manhattan            1   1  distance  0.513228
# 38         60  manhattan            1  20  distance  0.513228
# 44         60  manhattan            1  20   uniform  0.513228
# 5          15  manhattan            8  12  distance  0.502646
# 48         60  manhattan           44   2  distance  0.500000
# 46         60  manhattan            4  20  distance  0.497354
# 41         23  euclidean           12   3  distance  0.494709
# 19         48  manhattan           50   4  distance  0.494709
# 4           1  manhattan           10  15  distance  0.494709
# 27          1  manhattan           50  17  distance  0.494709
# 29         46  euclidean           27   2  distance  0.492063
# 3          25  manhattan           37  17  distance  0.489418
# 8          31  minkowski            3   7  distance  0.486772
# 30         50  euclidean           34  19  distance  0.484127
# 34          1  manhattan           28  20  distance  0.484127
# 0          59  manhattan           19   2  distance  0.484127
# 16         60  euclidean           25  20  distance  0.484127
# 43          1  euclidean           19   4  distance  0.481481
# 14         48  minkowski           50  19  distance  0.478836
# 6          14  minkowski           35   3  distance  0.476190
# 1          38  euclidean           48   7  distance  0.468254
# 17          1  minkowski           25  20  distance  0.468254
# 2           5  minkowski           16  17  distance  0.465608
# 12         58  euclidean            1  16  distance  0.462963
# 13         60  euclidean            1  18   uniform  0.462963
# 15         11  euclidean            1   2  distance  0.462963
# 7          46  manhattan           21   2   uniform  0.452381
# 9          10  manhattan           15  13   uniform  0.447090
# 24         54  minkowski            1   5   uniform  0.444444
# 25         35  euclidean           18   1   uniform  0.425926
# 35          1  manhattan           34  19   uniform  0.412698
# 10         12  minkowski           21   5   uniform  0.407407
# 20         38  manhattan           50  20   uniform  0.407407
# 21         47  minkowski           50   2   uniform  0.383598
# 11         60  euclidean           46  11   uniform  0.375661>
# >> initialising model...
# The best parameters are OrderedDict([('criterion', 'gini'), ('max_depth', 66), ('max_features', 1), ('min_samples_leaf', 2), ('min_samples_split', 2)]) with a score of 0.51
# <bound method NDFrame.head of    criterion  max_depth  max_features  min_samples_leaf  min_samples_split  \
# 33      gini         66             1                 2                  2
# 45      gini         67             3                 2                  2
# 43      gini         66             3                 2                  2
# 32   entropy         65             1                 2                  2
# 12      gini          1             7                 3                 17
# 41      gini         65             3                 2                  2
# 47      gini         59             3                 2                  2
# 23      gini        100             6                 2                  2
# 27      gini          1             7                 2                 44
# 21   entropy         62             7                 2                  2
# 19   entropy         58             1                 3                 69
# 26   entropy         45             1                 2                  2
# 37      gini         66             1                 2                  2
# 48      gini         59             2                 2                  2
# 49      gini         68             1                 2                  2
# 31   entropy         65             3                 2                  2
# 20   entropy         11             3                 2                  2
# 39   entropy         64             1                 2                  2
# 40      gini        100             1                 2                  2
# 4       gini         44             2                40                 12
# 14      gini         27             5                 2                 23
# 46      gini         76             4                 5                  3
# 29   entropy        100             6                 2                  2
# 10      gini         18             7                 2                  2
# 15      gini         93             1                 4                 52
# 28      gini         52             7                 2                 38
# 38   entropy          1             1               200                200
# 36      gini        100             1                 2                200
# 42   entropy         11             7               196                197
# 35      gini          1             7               200                  2
# 34   entropy         77             1               148                  2
# 44   entropy         98             1               198                152
# 0       gini         71             2               116                149
# 11   entropy         16             1                53                  2
# 9    entropy         89             6               121                 73
# 2       gini         34             3                46                141
# 3       gini         23             6                54                118
# 5       gini         85             5                50                 89
# 6       gini         18             2               107                 41
# 7    entropy         17             7                50                167
# 8    entropy          1             4               122                  9
# 25   entropy         82             6               200                107
# 1    entropy         52             6                61                148
# 13      gini         72             7               196                 22
# 16   entropy         93             5               199                200
# 17      gini         38             4               199                199
# 18      gini         10             2                 6                200
# 22   entropy         82             5               152                199
# 24      gini         92             7                 2                114
# 30   entropy          1             1                 2                  2
#
#     Accuracy
# 33  0.505291
# 45  0.497354
# 43  0.492063
# 32  0.486772
# 12  0.484127
# 41  0.481481
# 47  0.476190
# 23  0.470899
# 27  0.468254
# 21  0.468254
# 19  0.468254
# 26  0.462963
# 37  0.460317
# 48  0.457672
# 49  0.455026
# 31  0.455026
# 20  0.449735
# 39  0.449735
# 40  0.447090
# 4   0.447090
# 14  0.444444
# 46  0.444444
# 29  0.439153
# 10  0.436508
# 15  0.425926
# 28  0.423280
# 38  0.394180
# 36  0.394180
# 42  0.394180
# 35  0.394180
# 34  0.394180
# 44  0.394180
# 0   0.394180
# 11  0.394180
# 9   0.394180
# 2   0.394180
# 3   0.394180
# 5   0.394180
# 6   0.394180
# 7   0.394180
# 8   0.394180
# 25  0.394180
# 1   0.394180
# 13  0.394180
# 16  0.394180
# 17  0.394180
# 18  0.394180
# 22  0.394180
# 24  0.394180
# 30  0.351852  >
# >> initialising model...
# The best parameters are OrderedDict([('C', 139), ('decision_function_shape', 'ovr'), ('gamma', 30.0), ('kernel', 'linear')]) with a score of 0.49
# <bound method NDFrame.head of       C decision_function_shape      gamma   kernel  Accuracy
# 45  140                     ovr   9.377337   linear  0.492063
# 35  143                     ovr  30.000000   linear  0.492063
# 18  139                     ovr  30.000000   linear  0.492063
# 27  128                     ovr  17.950332   linear  0.492063
# 44  129                     ovr   9.103410   linear  0.492063
# 39  180                     ovr  30.000000   linear  0.492063
# 8   165                     ovo   5.483159   linear  0.489418
# 21  148                     ovr   0.001000   linear  0.489418
# 42  161                     ovr  17.893544   linear  0.489418
# 19  120                     ovo  30.000000   linear  0.489418
# 5   474                     ovr  17.139368   linear  0.486772
# 47  310                     ovr  30.000000   linear  0.486772
# 46  111                     ovr  16.713032   linear  0.486772
# 12   77                     ovr  29.981735   linear  0.486772
# 48  299                     ovr  30.000000   linear  0.486772
# 33  114                     ovo  30.000000   linear  0.486772
# 2   467                     ovr   0.296278   linear  0.486772
# 26  301                     ovr   0.001000   linear  0.486772
# 36  385                     ovr   7.897099   linear  0.484127
# 38  500                     ovr  30.000000   linear  0.484127
# 22  371                     ovr  27.781851   linear  0.484127
# 16  500                     ovr  30.000000   linear  0.484127
# 41  390                     ovr  30.000000   linear  0.484127
# 30  386                     ovr   3.802718   linear  0.484127
# 31  375                     ovr   0.001000   linear  0.484127
# 13  492                     ovo   0.332012   linear  0.484127
# 34   98                     ovo   0.001000   linear  0.481481
# 32  212                     ovr   0.264512   linear  0.481481
# 4   222                     ovo  25.900894   linear  0.478836
# 6   411                     ovr   1.685614      rbf  0.473545
# 37  500                     ovo  30.000000      rbf  0.465608
# 40   74                     ovr  30.000000      rbf  0.465608
# 0   497                     ovr  15.910102      rbf  0.465608
# 25  173                     ovr  30.000000      rbf  0.465608
# 29  378                     ovr   6.476702      rbf  0.465608
# 1   109                     ovo  15.066041      rbf  0.465608
# 11    1                     ovr  30.000000      rbf  0.465608
# 9   317                     ovo  14.625019      rbf  0.465608
# 7   345                     ovo  16.099877      rbf  0.465608
# 3   381                     ovo   7.585449      rbf  0.465608
# 49  374                     ovr  29.638085      rbf  0.465608
# 28  500                     ovo   0.001000      rbf  0.460317
# 17    1                     ovo  30.000000   linear  0.455026
# 14    1                     ovr   9.634709   linear  0.455026
# 23  126                     ovr   0.001000      rbf  0.439153
# 24    1                     ovo   0.001000      rbf  0.394180
# 15   36                     ovo   0.178793  sigmoid  0.362434
# 20  500                     ovo   6.515251  sigmoid  0.351852
# 43    2                     ovo  28.279249  sigmoid  0.330688
# 10  271                     ovr  24.344338  sigmoid  0.306878>
# >> initialising model...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-2657d219151c> in <module>
#      34     #model.test()
#      35
# ---> 36 main()
#
# <ipython-input-25-2657d219151c> in main()
#      28     data = data_loader.load_real_dataset(remove_multicollinearity=False, only_proposed=True)
#      29     # determine which model we are using.
# ---> 30     model = LMNN(data, normalize=True)
#      31     model.find_hyperparams()
#      32     #model.train()
#
# ~/Desktop/FIT4003/ProjectCodeBase/model/lmnn.py in __init__(self, data, normalize)
#      33         # Reference to the library used: https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.ExtraTreesClassifier.html
#      34         # Selecting the most important features using a tress classifer algorithm# initialise a statsmodels OLS instance.
# ---> 35         self.model = LMNN()
#      36         self.knnmodel = KNeighborsClassifier()
#      37
#
# TypeError: __init__() missing 1 required positional argument: 'data'

# %%
# using cfs after removing variance of zero
def main():
    # get data to use in this analysis.
    data = data_loader.load_real_dataset(remove_multicollinearity=False, cfs_mi=True)
    # determine which model we are using.
    model = KNearestNeighbors(data, normalize=True)
    #model.hyperparameter_tuning()
    model.train()
    model.describe()
    model.test()
    
    data = data_loader.load_real_dataset(remove_multicollinearity=False, only_proposed=True)
    # determine which model we are using.
    model = DecisionTree(data, normalize=True)
    #model.hyperparameter_tuning()
    model.train()
    model.describe()
    model.test()
    
    data = data_loader.load_real_dataset(remove_multicollinearity=False, only_proposed=True)
    # determine which model we are using.
    model = SupportVectorMachine(data, normalize=True)
    #model.hyperparameter_tuning()
    model.train()
    model.describe()
    model.test()
    
    data = data_loader.load_real_dataset(remove_multicollinearity=False, only_proposed=True)
    # determine which model we are using.
    model = LMNN(data, normalize=True)
    #model.find_hyperparams()
    model.train()
    model.describe()
    model.test()

main()
# Out:
# >> initialising model...
# >> training model...
# >> describing model...
# KNeighborsClassifier(metric='manhattan', weights='distance')
# >> predicting test data...
# >> assessing prediction performance...
# ESS: 65
# RSS: 13
# TSS: 124
# R-squared: 0.90
# correlation: -0.08
# 0.37037037037037035
#               precision    recall  f1-score   support
#
#          1.0       0.20      0.22      0.21        23
#          2.0       0.42      0.61      0.49        36
#          3.0       1.00      0.14      0.24        22
#
#     accuracy                           0.37        81
#    macro avg       0.54      0.32      0.31        81
# weighted avg       0.51      0.37      0.34        81
#
# >> initialising model...
# >> training model...
# >> describing model...
# [0.13528895 0.         0.04968276 0.15285404 0.         0.01298933
#  0.08615642 0.01125742 0.0285929  0.01298933 0.         0.
#  0.04580905 0.10752505 0.1573552  0.         0.06486008 0.
#  0.13463945 0.        ]
# >> predicting test data...
# >> assessing prediction performance...
# ESS: 85
# RSS: 15
# TSS: 124
# R-squared: 0.88
# correlation: -0.06
# 0.38271604938271603
#               precision    recall  f1-score   support
#
#          1.0       0.24      0.17      0.20        23
#          2.0       0.40      0.64      0.49        36
#          3.0       0.57      0.18      0.28        22
#
#     accuracy                           0.38        81
#    macro avg       0.40      0.33      0.32        81
# weighted avg       0.40      0.38      0.35        81
#
# >> initialising model...
# >> training model...
# >> describing model...
# >> predicting test data...
# >> assessing prediction performance...
# ESS: 63
# RSS: 12
# TSS: 124
# R-squared: 0.90
# correlation: 0.09
# 0.3950617283950617
#               precision    recall  f1-score   support
#
#          1.0       0.33      0.30      0.32        23
#          2.0       0.42      0.69      0.53        36
#          3.0       0.00      0.00      0.00        22
#
#     accuracy                           0.40        81
#    macro avg       0.25      0.33      0.28        81
# weighted avg       0.28      0.40      0.32        81
#
# >> initialising model...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-22bf705a909d> in <module>
#      34     model.test()
#      35
# ---> 36 main()
#
# <ipython-input-26-22bf705a909d> in main()
#      28     data = data_loader.load_real_dataset(remove_multicollinearity=False, only_proposed=True)
#      29     # determine which model we are using.
# ---> 30     model = LMNN(data, normalize=True)
#      31     #model.find_hyperparams()
#      32     model.train()
#
# ~/Desktop/FIT4003/ProjectCodeBase/model/lmnn.py in __init__(self, data, normalize)
#      33         # Reference to the library used: https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.ExtraTreesClassifier.html
#      34         # Selecting the most important features using a tress classifer algorithm# initialise a statsmodels OLS instance.
# ---> 35         self.model = LMNN()
#      36         self.knnmodel = KNeighborsClassifier()
#      37
#
# TypeError: __init__() missing 1 required positional argument: 'data'

# %%
# removing variance and highly correlated ones
def describe_data():
    data = data_loader.load_real_dataset(sqaured=False, remove_multicollinearity=False)
    output_xy = pre_training_analysis_tools.variance_threshold(data['train_x'],data['train_y'])
    output_xy = pre_training_analysis_tools.remove_collinear_features(output_xy, 'maven_reuse', 0.90, 'True')
    data = pre_training_analysis_tools.generate_train_test_xy(output_xy)

    display(data)
    
    # determine which model we are using.
    model = KNearestNeighbors(data, normalize=True)
    model.hyperparameter_tuning()
    #model.train()
    #model.describe()
    #model.test()
    
    data = data_loader.load_real_dataset(remove_multicollinearity=False, only_proposed=True)
    # determine which model we are using.
    model = DecisionTree(data, normalize=True)
    model.hyperparameter_tuning()
    #model.train()
    #model.describe()
    #model.test()
    
    data = data_loader.load_real_dataset(remove_multicollinearity=False, only_proposed=True)
    # determine which model we are using.
    model = SupportVectorMachine(data, normalize=True)
    model.hyperparameter_tuning()
    #model.train()
    #model.describe()
    #model.test()
    
    data = data_loader.load_real_dataset(remove_multicollinearity=False, only_proposed=True)
    # determine which model we are using.
    model = LMNN(data, normalize=True)
    model.find_hyperparams()
    #model.train()
    #model.describe()
    #model.test()

describe_data()
# Out:
# Original feature shape: (189, 265)
# Transformed feature shape: (189, 208)
# synchronizedMethodsQty_stdev | synchronizedMethodsQty_average | 0.9
# synchronizedMethodsQty_stdev: -0.013
# synchronizedMethodsQty_average: 0.104
# dropped: synchronizedMethodsQty_stdev
# -----------------------------------------------------------------------------
# publicMethodsQty_stdev | lcom_average | 0.93
# publicMethodsQty_stdev: 0.099
# lcom_average: 0.108
# dropped: publicMethodsQty_stdev
# -----------------------------------------------------------------------------
# staticFieldsQty_sum | publicMethodsQty_sum | 0.98
# staticFieldsQty_sum: 0.147
# publicMethodsQty_sum: 0.14
# dropped: publicMethodsQty_sum
# -----------------------------------------------------------------------------
# staticFieldsQty_max | staticFieldsQty_stdev | 0.91
# staticFieldsQty_max: 0.047
# staticFieldsQty_stdev: 0.052
# dropped: staticFieldsQty_max
# -----------------------------------------------------------------------------
# publicFieldsQty_sum | staticFieldsQty_sum | 0.94
# publicFieldsQty_sum: 0.106
# staticFieldsQty_sum: 0.147
# dropped: publicFieldsQty_sum
# -----------------------------------------------------------------------------
# publicFieldsQty_max | publicFieldsQty_stdev | 0.93
# publicFieldsQty_max: 0.026
# publicFieldsQty_stdev: 0.008
# dropped: publicFieldsQty_stdev
# -----------------------------------------------------------------------------
# lambdasQty_stdev | lambdasQty_average | 0.92
# lambdasQty_stdev: -0.047
# lambdasQty_average: 0.032
# dropped: lambdasQty_average
# -----------------------------------------------------------------------------
# lambdasQty_max | lambdasQty_stdev | 0.91
# lambdasQty_max: -0.066
# lambdasQty_stdev: -0.047
# dropped: lambdasQty_stdev
# -----------------------------------------------------------------------------
# logStatementsQty_median | logStatementsQty_average | 0.93
# logStatementsQty_median: nan
# logStatementsQty_average: -0.052
# dropped: logStatementsQty_average
# -----------------------------------------------------------------------------
# tryCatchQty_sum | staticFieldsQty_sum | 0.93
# tryCatchQty_sum: 0.046
# staticFieldsQty_sum: 0.147
# dropped: tryCatchQty_sum
# -----------------------------------------------------------------------------
# maxNestedBlocksQty_sum | parenthesizedExpsQty_sum | 0.9
# maxNestedBlocksQty_sum: 0.107
# parenthesizedExpsQty_sum: 0.144
# dropped: maxNestedBlocksQty_sum
# -----------------------------------------------------------------------------
# wmc_sum | parenthesizedExpsQty_sum | 0.91
# wmc_sum: 0.122
# parenthesizedExpsQty_sum: 0.144
# dropped: wmc_sum
# -----------------------------------------------------------------------------
# rfc_sum | staticFieldsQty_sum | 0.97
# rfc_sum: 0.126
# staticFieldsQty_sum: 0.147
# dropped: rfc_sum
# -----------------------------------------------------------------------------
# privateMethodsQty_sum | staticFieldsQty_sum | 0.93
# privateMethodsQty_sum: 0.147
# staticFieldsQty_sum: 0.147
# dropped: staticFieldsQty_sum
# -----------------------------------------------------------------------------
# defaultMethodsQty_sum | lambdasQty_sum | 0.92
# defaultMethodsQty_sum: 0.045
# lambdasQty_sum: 0.105
# dropped: defaultMethodsQty_sum
# -----------------------------------------------------------------------------
# nosi_sum | logStatementsQty_sum | 0.94
# nosi_sum: 0.064
# logStatementsQty_sum: 0.123
# dropped: nosi_sum
# -----------------------------------------------------------------------------
# visibleFieldsQty_max | visibleFieldsQty_stdev | 0.98
# visibleFieldsQty_max: 0.069
# visibleFieldsQty_stdev: 0.068
# dropped: visibleFieldsQty_stdev
# -----------------------------------------------------------------------------
# uniqueWordsQty_sum | logStatementsQty_sum | 0.9
# uniqueWordsQty_sum: 0.099
# logStatementsQty_sum: 0.123
# dropped: uniqueWordsQty_sum
# -----------------------------------------------------------------------------
# stringLiteralsQty_sum | logStatementsQty_sum | 0.94
# stringLiteralsQty_sum: 0.081
# logStatementsQty_sum: 0.123
# dropped: stringLiteralsQty_sum
# -----------------------------------------------------------------------------
# anonymousClassesQty_sum | logStatementsQty_sum | 0.9
# anonymousClassesQty_sum: 0.08
# logStatementsQty_sum: 0.123
# dropped: anonymousClassesQty_sum
# -----------------------------------------------------------------------------
# mathOperationsQty_median | stringLiteralsQty_median | 0.91
# mathOperationsQty_median: 0.103
# stringLiteralsQty_median: 0.188
# dropped: mathOperationsQty_median
# -----------------------------------------------------------------------------
# returnQty_sum | parenthesizedExpsQty_sum | 0.95
# returnQty_sum: 0.153
# parenthesizedExpsQty_sum: 0.144
# dropped: parenthesizedExpsQty_sum
# -----------------------------------------------------------------------------
# returnQty_sum | mathOperationsQty_sum | 0.92
# returnQty_sum: 0.153
# mathOperationsQty_sum: 0.078
# dropped: mathOperationsQty_sum
# -----------------------------------------------------------------------------
# returnQty_average | wmc_average | 0.91
# returnQty_average: 0.256
# wmc_average: 0.224
# dropped: wmc_average
# -----------------------------------------------------------------------------
# modifiers_sum | privateMethodsQty_sum | 0.92
# modifiers_sum: 0.058
# privateMethodsQty_sum: 0.147
# dropped: modifiers_sum
# -----------------------------------------------------------------------------
# lcc_sum | privateMethodsQty_sum | 0.93
# lcc_sum: -0.094
# privateMethodsQty_sum: 0.147
# dropped: lcc_sum
# -----------------------------------------------------------------------------
# abstractMethodsQty_sum | logStatementsQty_sum | 0.91
# abstractMethodsQty_sum: 0.128
# logStatementsQty_sum: 0.123
# dropped: logStatementsQty_sum
# -----------------------------------------------------------------------------
# abstractMethodsQty_sum | privateMethodsQty_sum | 0.95
# abstractMethodsQty_sum: 0.128
# privateMethodsQty_sum: 0.147
# dropped: abstractMethodsQty_sum
# -----------------------------------------------------------------------------
# abstractMethodsQty_average | publicMethodsQty_average | 0.97
# abstractMethodsQty_average: 0.113
# publicMethodsQty_average: 0.097
# dropped: publicMethodsQty_average
# -----------------------------------------------------------------------------
# abstractMethodsQty_stdev | lcom_average | 0.92
# abstractMethodsQty_stdev: 0.107
# lcom_average: 0.108
# dropped: abstractMethodsQty_stdev
# -----------------------------------------------------------------------------
# abstractMethodsQty_median | publicMethodsQty_median | 0.91
# abstractMethodsQty_median: 0.019
# publicMethodsQty_median: 0.029
# dropped: abstractMethodsQty_median
# -----------------------------------------------------------------------------
# abstractMethodsQty_max | publicMethodsQty_max | 0.98
# abstractMethodsQty_max: 0.107
# publicMethodsQty_max: 0.07
# dropped: publicMethodsQty_max
# -----------------------------------------------------------------------------
# protectedFieldsQty_sum | privateMethodsQty_sum | 0.95
# protectedFieldsQty_sum: 0.144
# privateMethodsQty_sum: 0.147
# dropped: protectedFieldsQty_sum
# -----------------------------------------------------------------------------
# staticMethodsQty_sum | synchronizedMethodsQty_sum | 0.9
# staticMethodsQty_sum: 0.138
# synchronizedMethodsQty_sum: 0.146
# dropped: staticMethodsQty_sum
# -----------------------------------------------------------------------------
# staticMethodsQty_median | logStatementsQty_median | 0.9
# staticMethodsQty_median: -0.009
# logStatementsQty_median: nan
# dropped: logStatementsQty_median
# -----------------------------------------------------------------------------
# assignmentsQty_sum | privateMethodsQty_sum | 0.93
# assignmentsQty_sum: 0.118
# privateMethodsQty_sum: 0.147
# dropped: assignmentsQty_sum
# -----------------------------------------------------------------------------
# finalFieldsQty_sum | privateMethodsQty_sum | 0.96
# finalFieldsQty_sum: 0.094
# privateMethodsQty_sum: 0.147
# dropped: finalFieldsQty_sum
# -----------------------------------------------------------------------------
# finalFieldsQty_max | publicFieldsQty_max | 0.96
# finalFieldsQty_max: 0.029
# publicFieldsQty_max: 0.026
# dropped: publicFieldsQty_max
# -----------------------------------------------------------------------------
# finalFieldsQty_max | finalFieldsQty_stdev | 0.95
# finalFieldsQty_max: 0.029
# finalFieldsQty_stdev: -0.003
# dropped: finalFieldsQty_stdev
# -----------------------------------------------------------------------------
# dit_sum | privateMethodsQty_sum | 0.95
# dit_sum: 0.128
# privateMethodsQty_sum: 0.147
# dropped: dit_sum
# -----------------------------------------------------------------------------
# totalMethodsQty_sum | privateMethodsQty_sum | 0.95
# totalMethodsQty_sum: 0.129
# privateMethodsQty_sum: 0.147
# dropped: totalMethodsQty_sum
# -----------------------------------------------------------------------------
# totalMethodsQty_average | abstractMethodsQty_average | 0.98
# totalMethodsQty_average: 0.17
# abstractMethodsQty_average: 0.113
# dropped: abstractMethodsQty_average
# -----------------------------------------------------------------------------
# totalMethodsQty_stdev | lcom_average | 0.91
# totalMethodsQty_stdev: 0.133
# lcom_average: 0.108
# dropped: lcom_average
# -----------------------------------------------------------------------------
# totalMethodsQty_max | abstractMethodsQty_max | 1.0
# totalMethodsQty_max: 0.103
# abstractMethodsQty_max: 0.107
# dropped: totalMethodsQty_max
# -----------------------------------------------------------------------------
# defaultFieldsQty_stdev | defaultFieldsQty_average | 0.91
# defaultFieldsQty_stdev: 0.162
# defaultFieldsQty_average: 0.051
# dropped: defaultFieldsQty_average
# -----------------------------------------------------------------------------
# loc_sum | privateMethodsQty_sum | 0.95
# loc_sum: 0.145
# privateMethodsQty_sum: 0.147
# dropped: loc_sum
# -----------------------------------------------------------------------------
# loc_average | assignmentsQty_average | 0.93
# loc_average: 0.259
# assignmentsQty_average: 0.188
# dropped: assignmentsQty_average
# -----------------------------------------------------------------------------
# loc_median | wmc_median | 0.97
# loc_median: 0.262
# wmc_median: 0.236
# dropped: wmc_median
# -----------------------------------------------------------------------------
# loc_median | assignmentsQty_median | 0.93
# loc_median: 0.262
# assignmentsQty_median: 0.234
# dropped: assignmentsQty_median
# -----------------------------------------------------------------------------
# cbo_sum | privateMethodsQty_sum | 0.97
# cbo_sum: 0.123
# privateMethodsQty_sum: 0.147
# dropped: cbo_sum
# -----------------------------------------------------------------------------
# variablesQty_sum | privateMethodsQty_sum | 0.94
# variablesQty_sum: 0.11
# privateMethodsQty_sum: 0.147
# dropped: variablesQty_sum
# -----------------------------------------------------------------------------
# variablesQty_median | loc_median | 0.92
# variablesQty_median: 0.229
# loc_median: 0.262
# dropped: variablesQty_median
# -----------------------------------------------------------------------------
# protectedMethodsQty_sum | privateMethodsQty_sum | 0.92
# protectedMethodsQty_sum: 0.103
# privateMethodsQty_sum: 0.147
# dropped: protectedMethodsQty_sum
# -----------------------------------------------------------------------------
# tcc_sum | privateMethodsQty_sum | 0.93
# tcc_sum: -0.094
# privateMethodsQty_sum: 0.147
# dropped: tcc_sum
# -----------------------------------------------------------------------------
# tcc_average | lcc_average | 1.0
# tcc_average: 0.026
# lcc_average: 0.026
# dropped: lcc_average
# -----------------------------------------------------------------------------
# tcc_stdev | lcc_stdev | 1.0
# tcc_stdev: -0.005
# lcc_stdev: -0.005
# dropped: lcc_stdev
# -----------------------------------------------------------------------------
# tcc_median | lcc_median | 1.0
# tcc_median: -0.056
# lcc_median: -0.056
# dropped: lcc_median
# -----------------------------------------------------------------------------
# tcc_min | lcc_min | 1.0
# tcc_min: -0.023
# lcc_min: -0.023
# dropped: lcc_min
# -----------------------------------------------------------------------------
# privateFieldsQty_stdev | variablesQty_max | 0.9
# privateFieldsQty_stdev: 0.039
# variablesQty_max: 0.016
# dropped: variablesQty_max
# -----------------------------------------------------------------------------
# privateFieldsQty_max | privateFieldsQty_stdev | 0.94
# privateFieldsQty_max: 0.044
# privateFieldsQty_stdev: 0.039
# dropped: privateFieldsQty_stdev
# -----------------------------------------------------------------------------
# finalMethodsQty_median | modifiers_median | 1.0
# finalMethodsQty_median: -0.115
# modifiers_median: -0.119
# dropped: finalMethodsQty_median
# -----------------------------------------------------------------------------
# innerClassesQty_sum | lambdasQty_sum | 0.91
# innerClassesQty_sum: 0.092
# lambdasQty_sum: 0.105
# dropped: innerClassesQty_sum
# -----------------------------------------------------------------------------
# comparisonsQty_sum | returnQty_sum | 0.9
# comparisonsQty_sum: 0.127
# returnQty_sum: 0.153
# dropped: comparisonsQty_sum
# -----------------------------------------------------------------------------
# dropped columns:
# ['modifiers_sum', 'abstractMethodsQty_median', 'lcc_median', 'privateFieldsQty_stdev', 'assignmentsQty_sum', 'publicMethodsQty_stdev', 'defaultFieldsQty_average', 'lcc_min', 'anonymousClassesQty_sum', 'publicMethodsQty_average', 'staticFieldsQty_sum', 'mathOperationsQty_sum', 'tcc_sum', 'publicFieldsQty_stdev', 'nosi_sum', 'abstractMethodsQty_sum', 'finalMethodsQty_median', 'visibleFieldsQty_stdev', 'lcc_sum', 'mathOperationsQty_median', 'wmc_median', 'uniqueWordsQty_sum', 'rfc_sum', 'lcom_average', 'cbo_sum', 'lambdasQty_average', 'tryCatchQty_sum', 'publicMethodsQty_sum', 'variablesQty_max', 'publicFieldsQty_max', 'loc_sum', 'protectedMethodsQty_sum', 'synchronizedMethodsQty_stdev', 'maxNestedBlocksQty_sum', 'wmc_sum', 'logStatementsQty_average', 'abstractMethodsQty_stdev', 'finalFieldsQty_stdev', 'wmc_average', 'finalFieldsQty_sum', 'staticFieldsQty_max', 'dit_sum', 'publicFieldsQty_sum', 'parenthesizedExpsQty_sum', 'lcc_stdev', 'stringLiteralsQty_sum', 'lcc_average', 'protectedFieldsQty_sum', 'abstractMethodsQty_average', 'comparisonsQty_sum', 'assignmentsQty_median', 'assignmentsQty_average', 'logStatementsQty_sum', 'publicMethodsQty_max', 'variablesQty_sum', 'innerClassesQty_sum', 'variablesQty_median', 'defaultMethodsQty_sum', 'lambdasQty_stdev', 'logStatementsQty_median', 'totalMethodsQty_sum', 'staticMethodsQty_sum', 'totalMethodsQty_max']
# -----------------------------------------------------------------------------
# used columns:
# ['synchronizedMethodsQty_sum', 'synchronizedMethodsQty_average', 'synchronizedMethodsQty_max', 'parenthesizedExpsQty_average', 'parenthesizedExpsQty_stdev', 'parenthesizedExpsQty_median', 'parenthesizedExpsQty_max', 'lcom_sum', 'lcom_stdev', 'lcom_median', 'lcom_max', 'publicMethodsQty_median', 'staticFieldsQty_average', 'staticFieldsQty_stdev', 'staticFieldsQty_median', 'publicFieldsQty_average', 'publicFieldsQty_median', 'lambdasQty_sum', 'lambdasQty_max', 'logStatementsQty_stdev', 'logStatementsQty_max', 'tryCatchQty_average', 'tryCatchQty_stdev', 'tryCatchQty_median', 'tryCatchQty_max', 'maxNestedBlocksQty_average', 'maxNestedBlocksQty_stdev', 'maxNestedBlocksQty_median', 'maxNestedBlocksQty_max', 'wmc_stdev', 'wmc_max', 'rfc_average', 'rfc_stdev', 'rfc_median', 'rfc_max', 'privateMethodsQty_sum', 'privateMethodsQty_average', 'privateMethodsQty_stdev', 'privateMethodsQty_median', 'privateMethodsQty_max', 'defaultMethodsQty_average', 'defaultMethodsQty_stdev', 'defaultMethodsQty_median', 'defaultMethodsQty_max', 'nosi_average', 'nosi_stdev', 'nosi_median', 'nosi_max', 'visibleFieldsQty_sum', 'visibleFieldsQty_average', 'visibleFieldsQty_max', 'uniqueWordsQty_average', 'uniqueWordsQty_stdev', 'uniqueWordsQty_median', 'uniqueWordsQty_max', 'stringLiteralsQty_average', 'stringLiteralsQty_stdev', 'stringLiteralsQty_median', 'stringLiteralsQty_max', 'anonymousClassesQty_average', 'anonymousClassesQty_stdev', 'anonymousClassesQty_max', 'mathOperationsQty_average', 'mathOperationsQty_stdev', 'mathOperationsQty_max', 'returnQty_sum', 'returnQty_average', 'returnQty_stdev', 'returnQty_median', 'returnQty_max', 'modifiers_average', 'modifiers_stdev', 'modifiers_median', 'modifiers_min', 'modifiers_max', 'abstractMethodsQty_max', 'protectedFieldsQty_average', 'protectedFieldsQty_stdev', 'protectedFieldsQty_median', 'protectedFieldsQty_max', 'numbersQty_sum', 'numbersQty_average', 'numbersQty_stdev', 'numbersQty_median', 'numbersQty_max', 'staticMethodsQty_average', 'staticMethodsQty_stdev', 'staticMethodsQty_median', 'staticMethodsQty_max', 'assignmentsQty_stdev', 'assignmentsQty_max', 'finalFieldsQty_average', 'finalFieldsQty_median', 'finalFieldsQty_max', 'dit_average', 'dit_stdev', 'dit_median', 'dit_max', 'totalMethodsQty_average', 'totalMethodsQty_stdev', 'totalMethodsQty_median', 'loopQty_sum', 'loopQty_average', 'loopQty_stdev', 'loopQty_median', 'loopQty_max', 'defaultFieldsQty_sum', 'defaultFieldsQty_stdev', 'defaultFieldsQty_max', 'loc_average', 'loc_stdev', 'loc_median', 'loc_max', 'totalFieldsQty_sum', 'totalFieldsQty_average', 'totalFieldsQty_stdev', 'totalFieldsQty_median', 'totalFieldsQty_max', 'cbo_average', 'cbo_stdev', 'cbo_median', 'cbo_max', 'variablesQty_average', 'variablesQty_stdev', 'protectedMethodsQty_average', 'protectedMethodsQty_stdev', 'protectedMethodsQty_max', 'tcc_average', 'tcc_stdev', 'tcc_median', 'tcc_min', 'privateFieldsQty_sum', 'privateFieldsQty_average', 'privateFieldsQty_max', 'finalMethodsQty_sum', 'finalMethodsQty_average', 'finalMethodsQty_stdev', 'finalMethodsQty_max', 'innerClassesQty_average', 'innerClassesQty_stdev', 'innerClassesQty_max', 'comparisonsQty_average', 'comparisonsQty_stdev', 'comparisonsQty_median', 'comparisonsQty_max', 'maven_reuse']
# {'train_x':      synchronizedMethodsQty_sum  synchronizedMethodsQty_average  \
#  3                      0.108974                        0.099065
#  20                     0.024038                        0.026423
#  117                    0.000000                        0.000000
#  89                     0.000000                        0.000000
#  159                    0.004808                        0.020268
#  73                     0.004808                        0.022770
#  98                     0.009615                        0.016467
#  92                     0.772436                        0.021187
#  131                    0.000000                        0.000000
#  183                    0.016827                        0.040599
#  8                      0.000000                        0.000000
#  62                     0.000000                        0.000000
#  79                     0.024840                        0.033436
#  140                    0.108974                        0.099065
#  10                     0.058494                        0.056099
#  25                     0.013622                        0.168570
#  55                     0.000801                        0.001897
#  129                    1.000000                        0.129385
#  148                    0.000801                        0.000765
#  91                     0.000000                        0.000000
#  45                     0.000801                        0.001787
#  7                      0.007212                        0.003221
#  138                    0.024038                        0.044766
#  109                    0.772436                        0.021210
#  150                    0.032853                        0.050615
#  118                    0.001603                        0.004099
#  164                    0.070513                        0.036754
#  163                    0.003205                        0.005911
#  166                    0.403846                        0.016783
#  4                      0.058494                        0.037029
#  139                    0.002404                        0.003390
#  155                    0.004006                        0.035743
#  67                     0.010417                        0.007554
#  35                     0.772436                        0.021187
#  111                    0.271635                        0.091010
#  112                    0.017628                        0.084533
#  153                    0.000000                        0.000000
#  161                    0.036058                        0.066185
#  128                    0.158654                        0.011558
#  5                      0.000801                        0.000159
#  24                     0.048878                        0.029811
#  29                     0.000801                        0.005692
#  87                     0.012821                        0.043913
#  85                     0.001603                        0.122957
#  6                      0.007212                        0.005372
#  165                    0.748397                        0.021831
#  168                    0.064904                        0.021727
#  0                      0.000000                        0.000000
#  80                     0.009615                        0.013365
#  69                     0.000000                        0.000000
#  17                     0.000801                        0.000159
#  81                     0.312500                        0.210322
#  50                     0.000000                        0.000000
#  115                    0.007212                        0.001438
#  16                     0.121795                        0.019899
#  75                     0.024038                        0.074974
#  137                    0.000000                        0.000000
#  151                    0.000000                        0.000000
#  2                      0.017628                        0.054101
#  76                     0.024840                        0.202749
#  156                    0.003205                        0.002120
#  23                     0.003205                        0.025093
#  144                    0.031250                        0.130308
#  36                     0.000000                        0.000000
#  72                     0.020032                        0.005217
#  110                    0.006410                        0.175653
#  170                    0.000000                        0.000000
#  181                    0.403846                        0.016783
#  37                     0.000000                        0.000000
#
#       synchronizedMethodsQty_max  parenthesizedExpsQty_average  \
#  3                      0.184211                      0.162392
#  20                     0.087719                      0.041716
#  117                    0.000000                      0.016968
#  89                     0.000000                      0.017825
#  159                    0.052632                      0.025856
#  73                     0.017544                      0.027233
#  98                     0.017544                      0.009519
#  92                     0.245614                      0.038847
#  131                    0.000000                      0.033649
#  183                    0.087719                      0.203940
#  8                      0.000000                      0.028887
#  62                     0.000000                      0.101211
#  79                     0.140351                      0.088751
#  140                    0.184211                      0.162392
#  10                     0.271930                      0.047426
#  25                     0.043860                      0.360531
#  55                     0.008772                      0.008624
#  129                    0.184211                      0.217067
#  148                    0.008772                      0.009328
#  91                     0.000000                      0.000000
#  45                     0.008772                      0.005130
#  7                      0.035088                      0.008645
#  138                    0.070175                      0.030697
#  109                    0.245614                      0.038930
#  150                    0.166667                      0.139972
#  118                    0.008772                      0.001961
#  164                    0.596491                      0.008092
#  163                    0.017544                      0.007777
#  166                    0.377193                      0.035558
#  4                      0.578947                      0.050112
#  139                    0.008772                      0.063257
#  155                    0.026316                      0.056430
#  67                     0.043860                      0.124124
#  35                     0.245614                      0.039067
#  111                    0.070175                      0.157655
#  112                    0.052632                      0.131434
#  153                    0.000000                      0.153509
#  161                    0.061404                      0.003518
#  128                    0.359649                      0.025832
#  5                      0.008772                      0.026721
#  24                     0.456140                      0.051903
#  29                     0.008772                      0.089869
#  87                     0.070175                      0.000657
#  85                     0.017544                      1.000000
#  6                      0.026316                      0.184752
#  165                    0.245614                      0.038143
#  168                    0.280702                      0.024253
#  0                      0.000000                      0.073529
#  80                     0.017544                      0.079390
#  69                     0.000000                      0.059618
#  17                     0.008772                      0.026721
#  81                     0.263158                      0.071465
#  50                     0.000000                      0.156863
#  115                    0.026316                      0.014981
#  16                     0.157895                      0.041556
#  75                     0.131579                      0.035868
#  137                    0.000000                      0.055147
#  151                    0.000000                      0.036014
#  2                      0.087719                      0.114118
#  76                     0.070175                      0.028160
#  156                    0.035088                      0.019397
#  23                     0.026316                      0.256603
#  144                    0.026316                      0.000000
#  36                     0.000000                      0.032169
#  72                     0.131579                      0.029002
#  110                    0.061404                      0.414916
#  170                    0.000000                      0.053476
#  181                    0.377193                      0.035558
#  37                     0.000000                      0.037707
#
#       parenthesizedExpsQty_stdev  parenthesizedExpsQty_median  \
#  3                      0.640273                          0.0
#  20                     0.202527                          0.0
#  117                    0.017447                          0.0
#  89                     0.023056                          0.0
#  159                    0.032880                          0.0
#  73                     0.036673                          0.0
#  98                     0.029136                          0.0
#  92                     0.064946                          0.0
#  131                    0.041294                          0.0
#  183                    0.325779                          0.0
#  8                      0.027840                          0.0
#  62                     0.129992                          0.0
#  79                     0.182595                          0.0
#  140                    0.640273                          0.0
#  10                     0.072679                          0.0
#  25                     0.258858                          0.0
#  55                     0.017594                          0.0
#  129                    0.334854                          0.0
#  148                    0.024871                          0.0
#  91                     0.000000                          0.0
#  45                     0.012824                          0.0
#  7                      0.033078                          0.0
#  138                    0.087762                          0.0
#  109                    0.065038                          0.0
#  150                    0.138097                          0.0
#  118                    0.005791                          0.0
#  164                    0.038847                          0.0
#  163                    0.020206                          0.0
#  166                    0.063862                          0.0
#  4                      0.078668                          0.0
#  139                    0.181573                          0.0
#  155                    0.055701                          0.0
#  67                     0.175567                          0.0
#  35                     0.065123                          0.0
#  111                    0.204452                          0.0
#  112                    0.131432                          0.0
#  153                    0.170265                          0.0
#  161                    0.007424                          0.0
#  128                    0.171677                          0.0
#  5                      0.035554                          0.0
#  24                     0.080275                          0.0
#  29                     0.101768                          0.0
#  87                     0.002752                          0.0
#  85                     0.820942                          1.0
#  6                      0.302871                          0.0
#  165                    0.065093                          0.0
#  168                    0.054272                          0.0
#  0                      0.041181                          0.5
#  80                     0.115364                          0.0
#  69                     0.073230                          0.0
#  17                     0.035554                          0.0
#  81                     0.082845                          0.0
#  50                     0.107763                          0.5
#  115                    0.042881                          0.0
#  16                     0.165275                          0.0
#  75                     0.040046                          0.0
#  137                    0.021950                          0.5
#  151                    0.039928                          0.0
#  2                      0.242659                          0.0
#  76                     0.033008                          0.0
#  156                    0.057717                          0.0
#  23                     0.239102                          0.0
#  144                    0.000000                          0.0
#  36                     0.058057                          0.0
#  72                     0.059481                          0.0
#  110                    0.253242                          0.0
#  170                    0.034678                          0.0
#  181                    0.063862                          0.0
#  37                     0.096834                          0.0
#
#       parenthesizedExpsQty_max  lcom_sum  lcom_stdev  lcom_median  ...  \
#  3                    1.000000  0.015980    0.027982     0.000000  ...
#  20                   0.301402  0.025496    0.030910     0.017021  ...
#  117                  0.004673  0.000495    0.005363     0.008511  ...
#  89                   0.009346  0.000507    0.003893     0.008511  ...
#  159                  0.021028  0.002164    0.004909     0.000000  ...
#  73                   0.021028  0.002912    0.008032     0.000000  ...
#  98                   0.032710  0.001980    0.001362     0.008511  ...
#  92                   0.158879  0.585039    0.029817     0.000000  ...
#  131                  0.028037  0.005503    0.036074     0.000000  ...
#  183                  0.203271  0.025007    0.052734     0.051064  ...
#  8                    0.009346  0.001357    0.011147     0.000000  ...
#  62                   0.053738  0.148164    0.549664     0.008511  ...
#  79                   0.165888  0.014182    0.021940     0.008511  ...
#  140                  1.000000  0.015980    0.027982     0.000000  ...
#  10                   0.053738  0.029361    0.038499     0.008511  ...
#  25                   0.084112  0.001405    0.007315     0.017021  ...
#  55                   0.011682  0.003085    0.009047     0.000000  ...
#  129                  1.000000  0.297207    0.032774     0.000000  ...
#  148                  0.030374  0.044878    0.080898     0.025532  ...
#  91                   0.000000  0.000137    0.005552     0.004255  ...
#  45                   0.009346  0.000602    0.001571     0.000000  ...
#  7                    0.056075  0.020258    0.042190     0.000000  ...
#  138                  0.098131  0.003437    0.004616     0.000000  ...
#  109                  0.158879  0.585610    0.030009     0.000000  ...
#  150                  0.074766  0.029002    0.040344     0.051064  ...
#  118                  0.004673  0.001080    0.001870     0.000000  ...
#  164                  0.081776  0.013877    0.020600     0.000000  ...
#  163                  0.018692  0.009567    0.035340     0.000000  ...
#  166                  0.261682  0.722760    0.109699     0.008511  ...
#  4                    0.098131  0.076696    0.087974     0.000000  ...
#  139                  0.231308  0.017639    0.052270     0.000000  ...
#  155                  0.025701  0.000512    0.003240     0.000000  ...
#  67                   0.158879  0.118874    0.162003     0.008511  ...
#  35                   0.158879  0.586172    0.030021     0.000000  ...
#  111                  0.168224  0.073862    0.018047     0.000000  ...
#  112                  0.077103  0.002164    0.004795     0.008511  ...
#  153                  0.079439  0.012057    0.069554     0.034043  ...
#  161                  0.004673  0.004460    0.006522     0.008511  ...
#  128                  0.789720  0.824228    0.362396     0.000000  ...
#  5                    0.035047  0.073081    0.033069     0.000000  ...
#  24                   0.093458  0.098882    0.134259     0.000000  ...
#  29                   0.049065  0.007142    0.026410     0.051064  ...
#  87                   0.002336  0.001264    0.003739     0.000000  ...
#  85                   0.149533  0.000326    0.011510     0.025532  ...
#  6                    0.336449  0.227744    0.721694     0.000000  ...
#  165                  0.158879  0.531873    0.028290     0.000000  ...
#  168                  0.088785  0.034185    0.015476     0.000000  ...
#  0                    0.004673  0.000004    0.000227     0.012766  ...
#  80                   0.091121  0.008118    0.007971     0.000000  ...
#  69                   0.032710  0.003450    0.032752     0.000000  ...
#  17                   0.035047  0.073081    0.033069     0.000000  ...
#  81                   0.060748  0.065342    0.046964     0.008511  ...
#  50                   0.032710  0.002116    0.029398     0.000000  ...
#  115                  0.079439  0.090712    0.030750     0.008511  ...
#  16                   0.532710  0.047347    0.009011     0.008511  ...
#  75                   0.018692  0.037902    0.182443     0.000000  ...
#  137                  0.004673  0.000168    0.002619     0.025532  ...
#  151                  0.018692  0.000549    0.002259     0.000000  ...
#  2                    0.200935  0.010828    0.031403     0.008511  ...
#  76                   0.014019  0.001378    0.007209     0.000000  ...
#  156                  0.093458  0.305385    0.331541     0.000000  ...
#  23                   0.095794  0.000939    0.005156     0.000000  ...
#  144                  0.000000  0.000210    0.000514     0.000000  ...
#  36                   0.035047  0.005163    0.015361     0.008511  ...
#  72                   0.086449  0.097951    0.035670     0.000000  ...
#  110                  0.051402  0.001584    0.015606     0.068085  ...
#  170                  0.007009  0.003945    0.083765     0.127660  ...
#  181                  0.261682  0.722760    0.109699     0.008511  ...
#  37                   0.067757  0.018774    0.152066     0.008511  ...
#
#       finalMethodsQty_average  finalMethodsQty_stdev  finalMethodsQty_max  \
#  3                   0.048143               0.118090             0.084112
#  20                  0.056305               0.205102             0.168224
#  117                 0.000000               0.000000             0.000000
#  89                  0.010093               0.028425             0.009346
#  159                 0.029280               0.067319             0.028037
#  73                  0.037006               0.093090             0.037383
#  98                  0.017842               0.045556             0.018692
#  92                  0.013407               0.058523             0.130841
#  131                 0.036693               0.092529             0.046729
#  183                 0.004189               0.018256             0.009346
#  8                   0.000000               0.000000             0.000000
#  62                  0.000000               0.000000             0.000000
#  79                  0.109850               0.418000             0.383178
#  140                 0.048143               0.118090             0.084112
#  10                  0.011657               0.037914             0.028037
#  25                  0.075206               0.109211             0.028037
#  55                  0.002056               0.012829             0.009346
#  129                 0.005055               0.063080             0.186916
#  148                 1.000000               1.000000             0.607477
#  91                  0.000000               0.000000             0.000000
#  45                  0.034855               0.050130             0.009346
#  7                   0.000775               0.007875             0.009346
#  138                 0.021018               0.048627             0.018692
#  109                 0.013421               0.058554             0.130841
#  150                 0.032102               0.125155             0.084112
#  118                 0.006661               0.039998             0.028037
#  164                 0.015838               0.050153             0.028037
#  163                 0.001601               0.011322             0.009346
#  166                 0.015226               0.106588             0.308411
#  4                   0.012641               0.085050             0.112150
#  139                 0.013469               0.040359             0.018692
#  155                 0.054219               0.086774             0.018692
#  67                  0.009444               0.037987             0.037383
#  35                  0.013407               0.058523             0.130841
#  111                 0.003491               0.020411             0.028037
#  112                 0.074938               0.110154             0.028037
#  153                 0.017529               0.048016             0.018692
#  161                 0.015936               0.050025             0.028037
#  128                 0.001644               0.032602             0.130841
#  5                   0.012086               0.059902             0.093458
#  24                  0.013238               0.084960             0.112150
#  29                  0.012335               0.031128             0.009346
#  87                  0.011895               0.061718             0.037383
#  85                  0.000000               0.000000             0.000000
#  6                   0.001293               0.014391             0.018692
#  165                 0.013499               0.058494             0.130841
#  168                 0.011334               0.057032             0.074766
#  0                   0.000000               0.000000             0.000000
#  80                  0.016894               0.081966             0.074766
#  69                  0.054009               0.161069             0.056075
#  17                  0.012086               0.059902             0.093458
#  81                  0.055510               0.194967             0.149533
#  50                  0.000000               0.000000             0.000000
#  115                 0.008828               0.059538             0.093458
#  16                  0.013617               0.063603             0.093458
#  75                  0.016247               0.074957             0.046729
#  137                 0.000000               0.000000             0.000000
#  151                 0.000000               0.000000             0.000000
#  2                   0.002664               0.014605             0.009346
#  76                  0.014173               0.047637             0.018692
#  156                 0.006317               0.027808             0.018692
#  23                  0.047580               0.141414             0.056075
#  144                 0.000000               0.000000             0.000000
#  36                  0.017347               0.043493             0.018692
#  72                  0.035273               0.170958             0.242991
#  110                 0.000000               0.000000             0.000000
#  170                 0.030278               0.049234             0.009346
#  181                 0.015226               0.106588             0.308411
#  37                  0.000000               0.000000             0.000000
#
#       innerClassesQty_average  innerClassesQty_stdev  innerClassesQty_max  \
#  3                   0.395441               0.172680             0.045752
#  20                  0.146802               0.097715             0.032680
#  117                 0.112602               0.052288             0.006536
#  89                  0.133075               0.098454             0.019608
#  159                 0.096516               0.054800             0.013072
#  73                  0.072288               0.050773             0.013072
#  98                  0.326747               0.163067             0.052288
#  92                  0.614481               0.517888             0.823529
#  131                 0.359754               0.343259             0.124183
#  183                 0.266987               0.128768             0.026144
#  8                   0.627354               0.248357             0.032680
#  62                  0.137772               0.094816             0.019608
#  79                  0.431444               0.184920             0.052288
#  140                 0.395441               0.172680             0.045752
#  10                  0.113447               0.058636             0.019608
#  25                  0.141661               0.056659             0.006536
#  55                  0.578302               0.395542             0.104575
#  129                 0.877308               0.484400             0.313725
#  148                 0.495225               0.221989             0.124183
#  91                  0.000000               0.000000             0.000000
#  45                  0.672339               0.336478             0.091503
#  7                   0.572579               1.000000             1.000000
#  138                 0.170543               0.106324             0.045752
#  109                 0.615769               0.518339             0.823529
#  150                 0.346850               0.121508             0.026144
#  118                 0.302524               0.181823             0.052288
#  164                 0.373912               0.168045             0.071895
#  163                 0.605236               0.527800             0.222222
#  166                 0.197746               0.147638             0.156863
#  4                   0.033818               0.030347             0.013072
#  139                 0.209887               0.117577             0.045752
#  155                 0.544680               0.174653             0.032680
#  67                  0.160495               0.090488             0.026144
#  35                  0.616260               0.518218             0.823529
#  111                 0.692920               0.363177             0.222222
#  112                 0.365957               0.118097             0.026144
#  153                 0.077043               0.042471             0.006536
#  161                 0.028016               0.025892             0.006536
#  128                 0.626004               0.170274             0.169935
#  5                   0.242833               0.150269             0.091503
#  24                  0.046545               0.037888             0.013072
#  29                  0.216863               0.180929             0.045752
#  87                  0.117629               0.062698             0.013072
#  85                  0.585531               0.168622             0.013072
#  6                   0.136434               0.178256             0.104575
#  165                 0.590272               0.480146             0.679739
#  168                 0.367873               0.178079             0.098039
#  0                   0.000000               0.000000             0.000000
#  80                  0.106074               0.058579             0.019608
#  69                  0.356066               0.195747             0.039216
#  17                  0.242833               0.150269             0.091503
#  81                  0.184904               0.105120             0.039216
#  50                  0.683119               0.186721             0.019608
#  115                 0.146839               0.112571             0.071895
#  16                  0.367203               0.268518             0.346405
#  75                  0.249922               0.107157             0.026144
#  137                 0.487942               0.167340             0.019608
#  151                 0.029874               0.026932             0.006536
#  2                   0.199080               0.093787             0.026144
#  76                  0.498324               0.153645             0.019608
#  156                 0.040381               0.036378             0.013072
#  23                  0.448110               0.181335             0.039216
#  144                 0.143200               0.084125             0.019608
#  36                  0.259219               0.116037             0.019608
#  72                  0.228568               0.170932             0.163399
#  110                 0.104559               0.050386             0.006536
#  170                 0.000000               0.000000             0.000000
#  181                 0.197746               0.147638             0.156863
#  37                  0.187670               0.102402             0.026144
#
#       comparisonsQty_average  comparisonsQty_stdev  comparisonsQty_median  \
#  3                  0.055643              0.219961               0.000000
#  20                 0.025181              0.083955               0.000000
#  117                0.021325              0.032694               0.000000
# ...
#  83                     0.061404                      0.030732
#  86                     0.175439                      0.013416
#  93                     0.026316                      0.008635
#  100                    0.017544                      0.009519
#  102                    0.035088                      0.019537
#  134                    0.114035                      0.020425
#  145                    0.087719                      0.292573
#  147                    0.263158                      0.019889
#  149                    0.043860                      0.014383
#  152                    0.000000                      0.013339
#  167                    0.280702                      0.025912
#  169                    0.122807                      0.348719
#
#       parenthesizedExpsQty_stdev  parenthesizedExpsQty_median  \
#  12                     0.035372                          0.0
#  19                     0.095267                          0.0
#  44                     0.062980                          0.0
#  61                     0.048214                          0.0
#  82                     0.026928                          0.0
#  83                     0.061855                          0.0
#  86                     0.039061                          0.0
#  93                     0.023938                          0.0
#  100                    0.029136                          0.0
#  102                    0.032486                          0.0
#  134                    0.033420                          0.0
#  145                    0.631261                          0.0
#  147                    0.073218                          0.0
#  149                    0.026828                          0.0
#  152                    0.026728                          0.0
#  167                    0.056328                          0.0
#  169                    0.490973                          0.0
#
#       parenthesizedExpsQty_max  lcom_sum  lcom_stdev  lcom_median  ...  \
#  12                   0.079439  0.220618    0.197520     0.000000  ...
#  19                   0.067757  0.004601    0.017074     0.000000  ...
#  44                   0.116822  0.020906    0.012151     0.000000  ...
#  61                   0.046729  0.002855    0.006690     0.000000  ...
#  82                   0.049065  0.103131    0.008917     0.000000  ...
#  83                   0.088785  0.033322    0.022381     0.000000  ...
#  86                   0.116822  0.049895    0.005337     0.000000  ...
#  93                   0.051402  0.036767    0.024115     0.000000  ...
#  100                  0.032710  0.001980    0.001362     0.008511  ...
#  102                  0.025701  0.011079    0.035879     0.000000  ...
#  134                  0.042056  0.050253    0.047990     0.000000  ...
#  145                  0.771028  0.038429    0.035282     0.000000  ...
#  147                  0.175234  0.032585    0.017151     0.000000  ...
#  149                  0.049065  0.103410    0.008921     0.000000  ...
#  152                  0.021028  0.004095    0.007485     0.000000  ...
#  167                  0.088785  0.035946    0.015875     0.000000  ...
#  169                  0.313084  0.019823    0.035845     0.025532  ...
#
#       finalMethodsQty_average  finalMethodsQty_stdev  finalMethodsQty_max  \
#  12                  0.007606               0.040822             0.065421
#  19                  0.010154               0.038044             0.018692
#  44                  0.006241               0.028442             0.018692
#  61                  0.009760               0.036735             0.018692
#  82                  0.004351               0.026844             0.056075
#  83                  0.009600               0.055810             0.084112
#  86                  0.004566               0.023977             0.028037
#  93                  0.006150               0.042705             0.065421
#  100                 0.017842               0.045556             0.018692
#  102                 0.017699               0.043196             0.018692
#  134                 0.024489               0.126328             0.121495
#  145                 0.033586               0.159141             0.158879
#  147                 0.005733               0.029815             0.037383
#  149                 0.004346               0.026830             0.056075
#  152                 0.002947               0.015327             0.009346
#  167                 0.010924               0.056000             0.074766
#  169                 0.001649               0.011489             0.009346
#
#       innerClassesQty_average  innerClassesQty_stdev  innerClassesQty_max  \
#  12                  0.414329               0.325828             0.359477
#  19                  0.410585               0.259611             0.078431
#  44                  0.159599               0.114680             0.071895
#  61                  0.557648               0.377809             0.137255
#  82                  0.649180               0.346341             0.490196
#  83                  0.374882               0.230583             0.163399
#  86                  0.510661               0.324070             0.274510
#  93                  0.168654               0.119764             0.084967
#  100                 0.326747               0.163067             0.052288
#  102                 0.169719               0.082258             0.026144
#  134                 0.220052               0.103504             0.032680
#  145                 0.504344               0.261729             0.091503
#  147                 0.400752               0.152206             0.045752
#  149                 0.652972               0.348189             0.490196
#  152                 0.764299               0.339669             0.143791
#  167                 0.371805               0.178356             0.098039
#  169                 0.137687               0.097002             0.032680
#
#       comparisonsQty_average  comparisonsQty_stdev  comparisonsQty_median  \
#  12                 0.025267              0.060183                    0.0
#  19                 0.111060              0.254916                    0.0
#  44                 0.023850              0.041107                    0.0
#  61                 0.031277              0.059662                    0.0
#  82                 0.012372              0.028730                    0.0
#  83                 0.028491              0.070132                    0.0
#  86                 0.017036              0.041126                    0.0
#  93                 0.024774              0.069199                    0.0
#  100                0.010025              0.030988                    0.0
#  102                0.029732              0.048472                    0.0
#  134                0.024507              0.054010                    0.0
#  145                0.102155              0.212128                    0.0
#  147                0.023360              0.056482                    0.0
#  149                0.012370              0.028708                    0.0
#  152                0.018155              0.040946                    0.0
#  167                0.048987              0.091474                    0.0
#  169                0.168395              0.434578                    0.0
#
#       comparisonsQty_max
#  12             0.140234
#  19             0.212020
#  44             0.076795
#  61             0.056761
#  82             0.055092
#  83             0.091820
#  86             0.116861
#  93             0.170284
#  100            0.040067
#  102            0.043406
#  134            0.066778
#  145            0.203673
#  147            0.106845
#  149            0.055092
#  152            0.033389
#  167            0.125209
#  169            0.507513
#
#  [17 rows x 145 columns],
#  'train_y': 3      1.0
#  20     1.0
#  117    1.0
#  89     1.0
#  159    1.0
#  73     2.0
#  98     3.0
#  92     1.0
#  131    3.0
#  183    3.0
#  8      1.0
#  62     2.0
#  79     1.0
#  140    1.0
#  10     2.0
#  25     1.0
#  55     1.0
#  129    3.0
#  148    1.0
#  91     1.0
#  45     1.0
#  7      1.0
#  138    2.0
#  109    3.0
#  150    2.0
#  118    2.0
#  164    1.0
#  163    2.0
#  166    3.0
#  4      2.0
#  139    1.0
#  155    1.0
#  67     1.0
#  35     2.0
#  111    2.0
#  112    2.0
#  153    3.0
#  161    1.0
#  128    2.0
#  5      2.0
#  24     2.0
#  29     2.0
#  87     2.0
#  85     3.0
#  6      2.0
#  165    1.0
#  168    1.0
#  0      1.0
#  80     1.0
#  69     2.0
#  17     2.0
#  81     1.0
#  50     1.0
#  115    2.0
#  16     1.0
#  75     2.0
#  137    2.0
#  151    2.0
#  2      2.0
#  76     2.0
#  156    2.0
#  23     2.0
#  144    3.0
#  36     2.0
#  72     1.0
#  110    3.0
#  170    2.0
#  181    2.0
#  37     3.0
#  Name: maven_reuse, dtype: float64,
#  'test_y': 12     1.0
#  19     1.0
#  44     2.0
#  61     3.0
#  82     2.0
#  83     2.0
#  86     3.0
#  93     2.0
#  100    1.0
#  102    1.0
#  134    2.0
#  145    1.0
#  147    2.0
#  149    2.0
#  152    2.0
#  167    1.0
#  169    1.0
#  Name: maven_reuse, dtype: float64}
# >> initialising model...
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 431, in _process_worker
#     r = call_item()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 285, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/joblib/_parallel_backends.py", line 595, in __call__
#     return self.func(*args, **kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/joblib/parallel.py", line 253, in __call__
#     for func, args, kwargs in self.items]
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/joblib/parallel.py", line 253, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/neighbors/_base.py", line 1132, in fit
#     multi_output=True)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py", line 645, in check_array
#     allow_nan=force_all_finite == 'allow-nan')
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py", line 99, in _assert_all_finite
#     msg_dtype if msg_dtype is not None else X.dtype)
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-d53dbf0d8598> in <module>
#      39     #model.test()
#      40
# ---> 41 describe_data()
#
# <ipython-input-3-d53dbf0d8598> in describe_data()
#      10     # determine which model we are using.
#      11     model = KNearestNeighbors(data, normalize=True)
# ---> 12     model.hyperparameter_tuning()
#      13     #model.train()
#      14     #model.describe()
#
# ~/Desktop/FIT4003/ProjectCodeBase/model/k_nearest_neigbors.py in hyperparameter_tuning(self)
#      50         # Calls the parent function - finds the combination of parameters from the given param_space that
#      51         # yields the highest score - set to accuracy currently
# ---> 52         BaseModel.hyperparameter_tuning(self, 'Bayesian', param_space)
#      53
#      54         # Plotting decision region
#
# ~/Desktop/FIT4003/ProjectCodeBase/model/base_model.py in hyperparameter_tuning(self, type, param_space)
#      75
#      76         # perform the search - i.e. it fits the model on the training data set for the different hyper-parameter settings
# ---> 77         search_result = search.fit(self.train_x, self.train_y)
#      78
#      79         # Prints the results - optimal hyper-parameters and the accuracy score
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/skopt/searchcv.py in fit(self, X, y, groups, callback)
#     692                 optim_result = self._step(
#     693                     X, y, search_space, optimizer,
# --> 694                     groups=groups, n_points=n_points_adjusted
#     695                 )
#     696                 n_iter -= n_points
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/skopt/searchcv.py in _step(self, X, y, search_space, optimizer, groups, n_points)
#     577         refit = self.refit
#     578         self.refit = False
# --> 579         self._fit(X, y, groups, params_dict)
#     580         self.refit = refit
#     581
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/skopt/searchcv.py in _fit(self, X, y, groups, parameter_iterable)
#     421                 error_score=self.error_score
#     422             )
# --> 423             for parameters in parameter_iterable
#     424             for train, test in cv_iter)
#     425
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1040
#    1041             with self._backend.retrieval_context():
# -> 1042                 self.retrieve()
#    1043             # Make sure that we get a last message telling us we are done
#    1044             elapsed_time = time.time() - self._start_time
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/joblib/parallel.py in retrieve(self)
#     919             try:
#     920                 if getattr(self._backend, 'supports_timeout', False):
# --> 921                     self._output.extend(job.get(timeout=self.timeout))
#     922                 else:
#     923                     self._output.extend(job.get())
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py in result(self, timeout)
#     433                 raise CancelledError()
#     434             elif self._state == FINISHED:
# --> 435                 return self.__get_result()
#     436             else:
#     437                 raise TimeoutError()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/concurrent/futures/_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
# something esle?  
def describe_data():
    data = data_loader.load_real_dataset(sqaured=False, only_pca=True)
    pre_training_analysis_tools.all_model_score(data['train_x'],data['train_y'],data['test_x'],data['test_y'])
    

def main():
    # get data to use in this analysis.
    data = data_loader.load_real_dataset(remove_multicollinearity=False, only_pca=True)
    # determine which model we are using.
    model = KNearestNeighbors(data, normalize=True)
    model.hyperparameter_tuning()
    #model.train()
    #model.describe()
    #model.test()
    
    data = data_loader.load_real_dataset(remove_multicollinearity=False, only_proposed=True)
    # determine which model we are using.
    model = DecisionTree(data, normalize=True)
    model.hyperparameter_tuning()
    #model.train()
    #model.describe()
    #model.test()
    
    data = data_loader.load_real_dataset(remove_multicollinearity=False, only_proposed=True)
    # determine which model we are using.
    model = SupportVectorMachine(data, normalize=True)
    model.hyperparameter_tuning()
    #model.train()
    #model.describe()
    #model.test()
    
    data = data_loader.load_real_dataset(remove_multicollinearity=False, only_proposed=True)
    # determine which model we are using.
    model = LMNN(data, normalize=True)
    model.find_hyperparams()
    #model.train()
    #model.describe()
    #model.test()

describe_data()

# %%
# printing pca - after removing all 0 variance metrics, then doing pca
def describe_data():
    data = data_loader.load_real_dataset(sqaured=False, remove_multicollinearity=False)
    output = pre_training_analysis_tools.variance_threshold(data['train_x'],data['train_y'])
    output = pre_training_analysis_tools.split_dataxy(output)
    display(output)
    data_x = pre_training_analysis_tools.pca(output)
    
    data = data_loader.load_real_dataset(only_pca=True)
    pre_training_analysis_tools.all_model_score(data['train_x'],data['train_y'],data['test_x'],data['test_y'])
    #data_xy = pre_training_analysis_tools.join_dataxy(data_x, data['train_y'])
    #display(data_xy)
    #data = pre_training_analysis_tools.generate_train_test_xy(data_xy)
    #pre_training_analysis_tools.all_model_score(data['train_x'],data['train_y'],data['test_x'],data['test_y'])

def main():
    # get data to use in this analysis.
    data = data_loader.load_real_dataset(remove_multicollinearity=False, only_pca=True)
    # determine which model we are using.
    model = KNearestNeighbors(data, normalize=True)
    model.hyperparameter_tuning()
    #model.train()
    #model.describe()
    #model.test()
    
    data = data_loader.load_real_dataset(remove_multicollinearity=False, only_proposed=True)
    # determine which model we are using.
    model = DecisionTree(data, normalize=True)
    model.hyperparameter_tuning()
    #model.train()
    #model.describe()
    #model.test()
    
    data = data_loader.load_real_dataset(remove_multicollinearity=False, only_proposed=True)
    # determine which model we are using.
    model = SupportVectorMachine(data, normalize=True)
    model.hyperparameter_tuning()
    #model.train()
    #model.describe()
    #model.test()
    
    data = data_loader.load_real_dataset(remove_multicollinearity=False, only_proposed=True)
    # determine which model we are using.
    model = LMNN(data, normalize=True)
    model.find_hyperparams()
    #model.train()
    #model.describe()
    #model.test()

    
main()

# %%
describe_data()
# Out:
# Original feature shape: (216, 265)
# Transformed feature shape: (216, 209)
#      synchronizedMethodsQty_sum  synchronizedMethodsQty_average  \
# 0                      0.000000                        0.000000
# 1                      0.098558                        0.050956
# 2                      0.017628                        0.054101
# 3                      0.108974                        0.099065
# 4                      0.058494                        0.037029
# 5                      0.000801                        0.000159
# 6                      0.007212                        0.005372
# 7                      0.007212                        0.003221
# 8                      0.000000                        0.000000
# 10                     0.058494                        0.056099
# 11                     0.020833                        0.003581
# 12                     0.018429                        0.004893
# 16                     0.121795                        0.019899
# 17                     0.000801                        0.000159
# 19                     0.000000                        0.000000
# 20                     0.024038                        0.026423
# 21                     0.003205                        0.000796
# 23                     0.003205                        0.025093
# 24                     0.048878                        0.029811
# 25                     0.013622                        0.168570
# 29                     0.000801                        0.005692
# 35                     0.772436                        0.021187
# 36                     0.000000                        0.000000
# 37                     0.000000                        0.000000
# 44                     0.127404                        0.041632
# 45                     0.000801                        0.001787
# 50                     0.000000                        0.000000
# 55                     0.000801                        0.001897
# 57                     0.000000                        0.000000
# 60                     0.004006                        0.001793
# 61                     0.000000                        0.000000
# 62                     0.000000                        0.000000
# 65                     0.012019                        0.006273
# 67                     0.010417                        0.007554
# 69                     0.000000                        0.000000
# 71                     0.198718                        0.090217
# 72                     0.020032                        0.005217
# 73                     0.004808                        0.022770
# 75                     0.024038                        0.074974
# 76                     0.024840                        0.202749
# 79                     0.024840                        0.033436
# 80                     0.009615                        0.013365
# 81                     0.312500                        0.210322
# 82                     0.134615                        0.006884
# 83                     0.032051                        0.013632
# 84                     0.217949                        0.155990
# 85                     0.001603                        0.122957
# 86                     0.220353                        0.019979
# 87                     0.012821                        0.043913
# 88                     0.000000                        0.000000
# 89                     0.000000                        0.000000
# 91                     0.000000                        0.000000
# 92                     0.772436                        0.021187
# 93                     0.004808                        0.001362
# 98                     0.009615                        0.016467
# 100                    0.009615                        0.016467
# 102                    0.007212                        0.013365
# 106                    0.076122                        0.019745
# 109                    0.772436                        0.021210
# 110                    0.006410                        0.175653
# 111                    0.271635                        0.091010
# 112                    0.017628                        0.084533
# 115                    0.007212                        0.001438
# 117                    0.000000                        0.000000
# 118                    0.001603                        0.004099
# 128                    0.158654                        0.011558
# 129                    1.000000                        0.129385
# 131                    0.000000                        0.000000
# 134                    0.037660                        0.023607
# 137                    0.000000                        0.000000
# 138                    0.024038                        0.044766
# 139                    0.002404                        0.003390
# 140                    0.108974                        0.099065
# 144                    0.031250                        0.130308
# 145                    0.054487                        0.043913
# 146                    0.001603                        0.006831
# 147                    0.056090                        0.017637
# 148                    0.000801                        0.000765
# 149                    0.134615                        0.006876
# 150                    0.032853                        0.050615
# 151                    0.000000                        0.000000
# 152                    0.000000                        0.000000
# 153                    0.000000                        0.000000
# 155                    0.004006                        0.035743
# 156                    0.003205                        0.002120
# 158                    0.002404                        0.017734
# 159                    0.004808                        0.020268
# 161                    0.036058                        0.066185
# 162                    0.411859                        1.000000
# 163                    0.003205                        0.005911
# 164                    0.070513                        0.036754
# 165                    0.748397                        0.021831
# 166                    0.403846                        0.016783
# 167                    0.064904                        0.020941
# 168                    0.064904                        0.021727
# 169                    0.037660                        0.071522
# 170                    0.000000                        0.000000
# 181                    0.403846                        0.016783
# 183                    0.016827                        0.040599
# 189                    0.134615                        0.006876
# 190                    0.000801                        0.009606
# 192                    0.000000                        0.000000
# 194                    0.000000                        0.000000
# 195                    0.002404                        0.010134
# 196                    0.008013                        0.153696
# 197                    0.000000                        0.000000
# 198                    0.000000                        0.000000
# 204                    0.020833                        0.029063
# 205                    0.000801                        0.002180
# 206                    0.012019                        0.003088
# 209                    0.076122                        0.019745
# 213                    0.134615                        0.006832
# 214                    0.004006                        0.006431
#
#      synchronizedMethodsQty_stdev  synchronizedMethodsQty_max  \
# 0                        0.000000                    0.000000
# 1                        0.283577                    0.763158
# 2                        0.091959                    0.087719
# 3                        0.156196                    0.184211
# 4                        0.230749                    0.578947
# 5                        0.001956                    0.008772
# 6                        0.017297                    0.026316
# 7                        0.015766                    0.035088
# 8                        0.000000                    0.000000
# 10                       0.163725                    0.271930
# 11                       0.031899                    0.131579
# 12                       0.019788                    0.043860
# 16                       0.050528                    0.157895
# 17                       0.001956                    0.008772
# 19                       0.000000                    0.000000
# 20                       0.068205                    0.087719
# 21                       0.005350                    0.017544
# 23                       0.038560                    0.026316
# 24                       0.178795                    0.456140
# 25                       0.110531                    0.043860
# 29                       0.011689                    0.008772
# 35                       0.050025                    0.245614
# 36                       0.000000                    0.000000
# 37                       0.000000                    0.000000
# 44                       0.075132                    0.114035
# 45                       0.006549                    0.008772
# 50                       0.000000                    0.000000
# 55                       0.006749                    0.008772
# 57                       0.000000                    0.000000
# 60                       0.006545                    0.008772
# 61                       0.000000                    0.000000
# 62                       0.000000                    0.000000
# 65                       0.035686                    0.096491
# 67                       0.023248                    0.043860
# 69                       0.000000                    0.000000
# 71                       0.135399                    0.184211
# 72                       0.039199                    0.131579
# 73                       0.026397                    0.017544
# 75                       0.141414                    0.131579
# 76                       0.135547                    0.070175
# 79                       0.088520                    0.140351
# 80                       0.022860                    0.017544
# 81                       0.247733                    0.263158
# 82                       0.018823                    0.043860
# 83                       0.037554                    0.061404
# 84                       0.267890                    0.535088
# 85                       0.076826                    0.017544
# 86                       0.052415                    0.175439
# 87                       0.082223                    0.070175
# 88                       0.000000                    0.000000
# 89                       0.000000                    0.000000
# 91                       0.000000                    0.000000
# 92                       0.050025                    0.245614
# 93                       0.008080                    0.026316
# 98                       0.025307                    0.017544
# 100                      0.025307                    0.017544
# 102                      0.034174                    0.035088
# 106                      0.065934                    0.201754
# 109                      0.050051                    0.245614
# 110                      0.160568                    0.061404
# 111                      0.074414                    0.070175
# 112                      0.089593                    0.052632
# 115                      0.008967                    0.026316
# 117                      0.000000                    0.000000
# 118                      0.009885                    0.008772
# 128                      0.064105                    0.359649
# 129                      0.101203                    0.184211
# 131                      0.000000                    0.000000
# 134                      0.074964                    0.114035
# 137                      0.000000                    0.000000
# 138                      0.066162                    0.070175
# 139                      0.008987                    0.008772
# 140                      0.156196                    0.184211
# 144                      0.090252                    0.026316
# 145                      0.079243                    0.087719
# 146                      0.012732                    0.008772
# 147                      0.082332                    0.263158
# 148                      0.004284                    0.008772
# 149                      0.018814                    0.043860
# 150                      0.136057                    0.166667
# 151                      0.000000                    0.000000
# 152                      0.000000                    0.000000
# 153                      0.000000                    0.000000
# 155                      0.046706                    0.026316
# 156                      0.014266                    0.035088
# 158                      0.035734                    0.026316
# 159                      0.054025                    0.052632
# 161                      0.061696                    0.061404
# 162                      1.000000                    1.000000
# 163                      0.016805                    0.017544
# 164                      0.216592                    0.596491
# 165                      0.050601                    0.245614
# 166                      0.073847                    0.377193
# 167                      0.093692                    0.280702
# 168                      0.095428                    0.280702
# 169                      0.123876                    0.122807
# 170                      0.000000                    0.000000
# 181                      0.073847                    0.377193
# 183                      0.075547                    0.087719
# 189                      0.018814                    0.043860
# 190                      0.015184                    0.008772
# 192                      0.000000                    0.000000
# 194                      0.000000                    0.000000
# 195                      0.020044                    0.017544
# 196                      0.119864                    0.052632
# 197                      0.000000                    0.000000
# 198                      0.000000                    0.000000
# 204                      0.055293                    0.078947
# 205                      0.007234                    0.008772
# 206                      0.011085                    0.026316
# 209                      0.065934                    0.201754
# 213                      0.018753                    0.043860
# 214                      0.018378                    0.026316
#
#      parenthesizedExpsQty_sum  parenthesizedExpsQty_average  \
# 0                    0.000099                      0.073529
# 1                    0.042442                      0.085223
# 2                    0.009574                      0.114118
# 3                    0.045995                      0.162392
# 4                    0.020382                      0.050112
# 5                    0.034595                      0.026721
# 6                    0.063860                      0.184752
# 7                    0.004984                      0.008645
# 8                    0.000543                      0.028887
# 10                   0.012733                      0.047426
# 11                   0.046390                      0.030967
# 12                   0.015398                      0.015876
# 16                   0.065489                      0.041556
# 17                   0.034595                      0.026721
# 19                   0.006268                      0.056940
# 20                   0.009772                      0.041716
# 21                   0.001135                      0.001095
# 23                   0.008439                      0.256603
# 24                   0.021912                      0.051903
# 25                   0.007501                      0.360531
# 29                   0.003257                      0.089869
# 35                   0.366728                      0.039067
# 36                   0.002073                      0.032169
# 37                   0.001974                      0.037707
# 44                   0.027834                      0.035324
# 45                   0.000592                      0.005130
# 50                   0.001579                      0.156863
# 55                   0.000938                      0.008624
# 57                   0.002023                      0.034652
# 60                   0.003751                      0.006521
# 61                   0.002862                      0.015622
# 62                   0.005774                      0.101211
# 65                   0.002468                      0.005002
# 67                   0.044070                      0.124124
# 69                   0.001481                      0.059618
# 71                   0.078123                      0.137748
# 72                   0.028673                      0.029002
# 73                   0.001481                      0.027233
# 75                   0.002961                      0.035868
# 76                   0.000888                      0.028160
# 79                   0.016977                      0.088751
# 80                   0.014707                      0.079390
# 81                   0.027340                      0.071465
# 82                   0.072743                      0.014447
# 83                   0.018605                      0.030732
# 84                   0.044909                      0.124835
# 85                   0.003356                      1.000000
# 86                   0.038099                      0.013416
# 87                   0.000049                      0.000657
# 88                   0.003701                      0.061275
# 89                   0.000395                      0.017825
# 91                   0.000000                      0.000000
# 92                   0.364655                      0.038847
# 93                   0.007847                      0.008635
# 98                   0.001431                      0.009519
# 100                  0.001431                      0.009519
# 102                  0.002714                      0.019537
# 106                  0.002862                      0.002884
# 109                  0.365050                      0.038930
# 110                  0.003899                      0.414916
# 111                  0.121157                      0.157655
# 112                  0.007057                      0.131434
# 115                  0.019346                      0.014981
# 117                  0.000148                      0.016968
# 118                  0.000197                      0.001961
# 128                  0.091299                      0.025832
# 129                  0.431970                      0.217067
# 131                  0.002665                      0.033649
# 134                  0.008390                      0.020425
# 137                  0.000444                      0.055147
# 138                  0.004244                      0.030697
# 139                  0.011548                      0.063257
# 140                  0.045995                      0.162392
# 144                  0.000000                      0.000000
# 145                  0.093471                      0.292573
# 146                  0.000740                      0.012255
# 147                  0.016286                      0.019889
# 148                  0.002517                      0.009328
# 149                  0.072497                      0.014383
# 150                  0.023392                      0.139972
# 151                  0.001184                      0.036014
# 152                  0.002023                      0.013339
# 153                  0.005873                      0.153509
# 155                  0.001629                      0.056430
# 156                  0.007551                      0.019397
# 158                  0.000888                      0.025452
# 159                  0.001579                      0.025856
# 161                  0.000494                      0.003518
# 162                  0.086068                      0.811616
# 163                  0.001086                      0.007777
# 164                  0.003997                      0.008092
# 165                  0.336673                      0.038143
# 166                  0.220303                      0.035558
# 167                  0.020678                      0.025912
# 168                  0.018655                      0.024253
# 169                  0.047278                      0.348719
# 170                  0.000395                      0.053476
# 181                  0.220303                      0.035558
# 183                  0.021764                      0.203940
# 189                  0.072497                      0.014383
# 190                  0.000099                      0.004596
# 192                  0.001875                      0.068149
# 194                  0.000000                      0.000000
# 195                  0.002270                      0.037169
# 196                  0.009475                      0.705882
# 197                  0.005725                      0.022154
# 198                  0.000000                      0.000000
# 204                  0.024527                      0.132888
# 205                  0.000444                      0.004693
# 206                  0.035928                      0.035854
# 209                  0.002862                      0.002884
# 213                  0.073237                      0.014435
# 214                  0.008094                      0.050455
#
#      parenthesizedExpsQty_stdev  parenthesizedExpsQty_median  \
# 0                      0.041181                         0.50
# 1                      0.152778                         0.00
# 2                      0.242659                         0.00
# 3                      0.640273                         0.00
# 4                      0.078668                         0.00
# 5                      0.035554                         0.00
# 6                      0.302871                         0.00
# 7                      0.033078                         0.00
# 8                      0.027840                         0.00
# 10                     0.072679                         0.00
# 11                     0.055983                         0.00
# 12                     0.035372                         0.00
# 16                     0.165275                         0.00
# 17                     0.035554                         0.00
# 19                     0.095267                         0.00
# 20                     0.202527                         0.00
# 21                     0.005275                         0.00
# 23                     0.239102                         0.00
# 24                     0.080275                         0.00
# 25                     0.258858                         0.00
# 29                     0.101768                         0.00
# 35                     0.065123                         0.00
# 36                     0.058057                         0.00
# 37                     0.096834                         0.00
# 44                     0.062980                         0.00
# 45                     0.012824                         0.00
# 50                     0.107763                         0.50
# 55                     0.017594                         0.00
# 57                     0.037638                         0.00
# 60                     0.015266                         0.00
# 61                     0.048214                         0.00
# 62                     0.129992                         0.00
# 65                     0.016810                         0.00
# 67                     0.175567                         0.00
# 69                     0.073230                         0.00
# 71                     0.451537                         0.00
# 72                     0.059481                         0.00
# 73                     0.036673                         0.00
# 75                     0.040046                         0.00
# 76                     0.033008                         0.00
# 79                     0.182595                         0.00
# 80                     0.115364                         0.00
# 81                     0.082845                         0.00
# 82                     0.026928                         0.00
# 83                     0.061855                         0.00
# 84                     0.128579                         0.00
# 85                     0.820942                         1.00
# 86                     0.039061                         0.00
# 87                     0.002752                         0.00
# 88                     0.116335                         0.00
# 89                     0.023056                         0.00
# 91                     0.000000                         0.00
# 92                     0.064946                         0.00
# 93                     0.023938                         0.00
# 98                     0.029136                         0.00
# 100                    0.029136                         0.00
# 102                    0.032486                         0.00
# 106                    0.009632                         0.00
# 109                    0.065038                         0.00
# 110                    0.253242                         0.00
# 111                    0.204452                         0.00
# 112                    0.131432                         0.00
# 115                    0.042881                         0.00
# 117                    0.017447                         0.00
# 118                    0.005791                         0.00
# 128                    0.171677                         0.00
# 129                    0.334854                         0.00
# 131                    0.041294                         0.00
# 134                    0.033420                         0.00
# 137                    0.021950                         0.50
# 138                    0.087762                         0.00
# 139                    0.181573                         0.00
# 140                    0.640273                         0.00
# 144                    0.000000                         0.00
# 145                    0.631261                         0.00
# 146                    0.021935                         0.00
# 147                    0.073218                         0.00
# 148                    0.024871                         0.00
# 149                    0.026828                         0.00
# 150                    0.138097                         0.00
# 151                    0.039928                         0.00
# 152                    0.026728                         0.00
# 153                    0.170265                         0.00
# 155                    0.055701                         0.00
# 156                    0.057717                         0.00
# 158                    0.033068                         0.00
# 159                    0.032880                         0.00
# 161                    0.007424                         0.00
# 162                    1.000000                         0.00
# 163                    0.020206                         0.00
# 164                    0.038847                         0.00
# 165                    0.065093                         0.00
# 166                    0.063862                         0.00
# 167                    0.056328                         0.00
# 168                    0.054272                         0.00
# 169                    0.490973                         0.00
# 170                    0.034678                         0.00
# 181                    0.063862                         0.00
# 183                    0.325779                         0.00
# 189                    0.026828                         0.00
# 190                    0.010295                         0.00
# 192                    0.098187                         0.00
# 194                    0.000000                         0.00
# 195                    0.068824                         0.00
# 196                    0.755950                         0.25
# 197                    0.030492                         0.00
# 198                    0.000000                         0.00
# 204                    0.166060                         0.00
# 205                    0.011654                         0.00
# 206                    0.097978                         0.00
# 209                    0.009632                         0.00
# 213                    0.026931                         0.00
# 214                    0.068303                         0.00
#
#      parenthesizedExpsQty_max  lcom_sum  ...  finalMethodsQty_max  \
# 0                    0.004673  0.000002  ...             0.000000
# 1                    0.207944  0.137882  ...             0.056075
# 2                    0.200935  0.005994  ...             0.009346
# 3                    1.000000  0.008846  ...             0.084112
# 4                    0.098131  0.042455  ...             0.112150
# 5                    0.035047  0.040454  ...             0.093458
# 6                    0.336449  0.126066  ...             0.018692
# 7                    0.056075  0.011214  ...             0.009346
# 8                    0.009346  0.000751  ...             0.000000
# 10                   0.053738  0.016253  ...             0.028037
# 11                   0.086449  0.104552  ...             0.261682
# 12                   0.079439  0.122122  ...             0.065421
# 16                   0.532710  0.026209  ...             0.093458
# 17                   0.035047  0.040454  ...             0.093458
# 19                   0.067757  0.002547  ...             0.018692
# 20                   0.301402  0.014113  ...             0.168224
# 21                   0.009346  0.013781  ...             0.028037
# 23                   0.095794  0.000520  ...             0.056075
# 24                   0.093458  0.054735  ...             0.112150
# 25                   0.084112  0.000778  ...             0.028037
# 29                   0.049065  0.003953  ...             0.009346
# 35                   0.158879  0.324472  ...             0.130841
# 36                   0.035047  0.002858  ...             0.018692
# 37                   0.067757  0.010392  ...             0.000000
# 44                   0.116822  0.011572  ...             0.018692
# 45                   0.009346  0.000333  ...             0.009346
# 50                   0.032710  0.001171  ...             0.000000
# 55                   0.011682  0.001708  ...             0.009346
# 57                   0.016355  0.003568  ...             0.037383
# 60                   0.021028  0.003032  ...             0.065421
# 61                   0.046729  0.001580  ...             0.018692
# 62                   0.053738  0.082015  ...             0.000000
# 65                   0.023364  0.032749  ...             0.009346
# 67                   0.158879  0.065802  ...             0.037383
# 69                   0.032710  0.001910  ...             0.056075
# 71                   0.843458  0.014647  ...             0.065421
# 72                   0.086449  0.054220  ...             0.242991
# 73                   0.021028  0.001612  ...             0.037383
# 75                   0.018692  0.020981  ...             0.046729
# 76                   0.014019  0.000763  ...             0.018692
# 79                   0.165888  0.007851  ...             0.383178
# 80                   0.091121  0.004494  ...             0.074766
# 81                   0.060748  0.036170  ...             0.149533
# 82                   0.049065  0.057087  ...             0.056075
# 83                   0.088785  0.018445  ...             0.084112
# 84                   0.079439  0.021041  ...             0.046729
# 85                   0.149533  0.000180  ...             0.000000
# 86                   0.116822  0.027619  ...             0.028037
# 87                   0.002336  0.000699  ...             0.037383
# 88                   0.084112  0.001065  ...             0.009346
# 89                   0.009346  0.000281  ...             0.009346
# 91                   0.000000  0.000076  ...             0.000000
# 92                   0.158879  0.323845  ...             0.130841
# 93                   0.051402  0.020352  ...             0.065421
# 98                   0.032710  0.001096  ...             0.018692
# 100                  0.032710  0.001096  ...             0.018692
# 102                  0.025701  0.006133  ...             0.018692
# 106                  0.021028  0.013753  ...             0.168224
# 109                  0.158879  0.324161  ...             0.130841
# 110                  0.051402  0.000877  ...             0.000000
# 111                  0.168224  0.040886  ...             0.028037
# 112                  0.077103  0.001198  ...             0.028037
# 115                  0.079439  0.050213  ...             0.093458
# 117                  0.004673  0.000274  ...             0.000000
# 118                  0.004673  0.000598  ...             0.028037
# 128                  0.789720  0.456246  ...             0.130841
# 129                  1.000000  0.164517  ...             0.186916
# 131                  0.028037  0.003046  ...             0.046729
# 134                  0.042056  0.027817  ...             0.121495
# 137                  0.004673  0.000093  ...             0.000000
# 138                  0.098131  0.001903  ...             0.018692
# 139                  0.231308  0.009764  ...             0.018692
# 140                  1.000000  0.008846  ...             0.084112
# 144                  0.000000  0.000116  ...             0.000000
# 145                  0.771028  0.021272  ...             0.158879
# 146                  0.011682  0.002862  ...             0.009346
# 147                  0.175234  0.018037  ...             0.037383
# 148                  0.030374  0.024842  ...             0.607477
# 149                  0.049065  0.057242  ...             0.056075
# 150                  0.074766  0.016054  ...             0.084112
# 151                  0.018692  0.000304  ...             0.000000
# 152                  0.021028  0.002267  ...             0.009346
# 153                  0.079439  0.006674  ...             0.018692
# 155                  0.025701  0.000283  ...             0.018692
# 156                  0.093458  0.169044  ...             0.018692
# 158                  0.014019  0.000257  ...             0.009346
# 159                  0.021028  0.001198  ...             0.028037
# 161                  0.004673  0.002469  ...             0.028037
# 162                  0.602804  0.019743  ...             0.261682
# 163                  0.018692  0.005296  ...             0.009346
# 164                  0.081776  0.007682  ...             0.028037
# 165                  0.158879  0.294415  ...             0.130841
# 166                  0.261682  0.400079  ...             0.308411
# 167                  0.088785  0.019898  ...             0.074766
# 168                  0.088785  0.018923  ...             0.074766
# 169                  0.313084  0.010973  ...             0.009346
# 170                  0.007009  0.002184  ...             0.009346
# 181                  0.261682  0.400079  ...             0.308411
# 183                  0.203271  0.013843  ...             0.009346
# 189                  0.049065  0.057242  ...             0.056075
# 190                  0.004673  0.014744  ...             0.018692
# 192                  0.049065  0.001245  ...             0.000000
# 194                  0.000000  0.018447  ...             0.000000
# 195                  0.037383  0.003190  ...             0.018692
# 196                  0.271028  0.000169  ...             0.000000
# 197                  0.030374  0.006797  ...             0.186916
# 198                  0.000000  0.000099  ...             0.000000
# 204                  0.105140  0.006802  ...             0.046729
# 205                  0.009346  0.001948  ...             0.046729
# 206                  0.219626  0.025431  ...             0.056075
# 209                  0.021028  0.013753  ...             0.168224
# 213                  0.049065  0.057854  ...             0.056075
# 214                  0.049065  0.002793  ...             0.009346
#
#      innerClassesQty_sum  innerClassesQty_average  innerClassesQty_stdev  \
# 0               0.000000                 0.000000               0.000000
# 1               0.030488                 0.315819               0.130509
# 2               0.002879                 0.177055               0.067168
# 3               0.019309                 0.351691               0.123669
# 4               0.002371                 0.030076               0.021734
# 5               0.054201                 0.215967               0.107619
# 6               0.008130                 0.121340               0.127663
# 7               0.056911                 0.509232               0.716177
# 8               0.002033                 0.557946               0.177867
# 10              0.005251                 0.100895               0.041994
# 11              0.052337                 0.180233               0.109754
# 12              0.069275                 0.368489               0.233350
# 16              0.099763                 0.326578               0.192307
# 17              0.054201                 0.215967               0.107619
# 19              0.007791                 0.365160               0.185928
# 20              0.005928                 0.130561               0.069981
# 21              0.001524                 0.007584               0.013285
# 23              0.002541                 0.398533               0.129868
# 24              0.003388                 0.041395               0.027134
# 25              0.000508                 0.125988               0.040578
# 29              0.001355                 0.192870               0.129577
# 35              0.997290                 0.548080               0.371136
# 36              0.002879                 0.230540               0.083103
# 37              0.001694                 0.166907               0.073338
# 44              0.021680                 0.141942               0.082131
# 45              0.013381                 0.597954               0.240978
# 50              0.001186                 0.607542               0.133725
# 55              0.010840                 0.514321               0.283278
# 57              0.001524                 0.134677               0.050580
# 60              0.040481                 0.363067               0.161079
# 61              0.017615                 0.495952               0.270578
# 62              0.001355                 0.122529               0.067905
# 65              0.020664                 0.216094               0.064930
# 67              0.009824                 0.142739               0.064806
# 69              0.001524                 0.316672               0.140189
# 71              0.037602                 0.342031               0.324183
# 72              0.038957                 0.203280               0.122418
# 73              0.000678                 0.064290               0.036362
# 75              0.003557                 0.222271               0.076743
# 76              0.002710                 0.443191               0.110037
# 79              0.014228                 0.383711               0.132436
# 80              0.003388                 0.094339               0.041953
# 81              0.012195                 0.164447               0.075284
# 82              0.563516                 0.577358               0.248041
# 83              0.039126                 0.333407               0.165138
# 84              0.010840                 0.155448               0.096335
# 85              0.000339                 0.520750               0.120763
# 86              0.250000                 0.454164               0.232092
# 87              0.001524                 0.104615               0.044903
# 88              0.000169                 0.014465               0.014232
# 89              0.000508                 0.118352               0.070511
# 91              0.000000                 0.000000               0.000000
# 92              0.994411                 0.546497               0.370899
# 93              0.026423                 0.149994               0.085773
# 98              0.008469                 0.290597               0.116785
# 100             0.008469                 0.290597               0.116785
# 102             0.004065                 0.150942               0.058911
# 106             0.111280                 0.578318               0.400446
# 109             0.995427                 0.547643               0.371222
# 110             0.000169                 0.092991               0.036085
# 111             0.091802                 0.616259               0.260099
# 112             0.003388                 0.325469               0.084578
# 115             0.032690                 0.130593               0.080621
# 117             0.000169                 0.100144               0.037447
# 118             0.005251                 0.269054               0.130217
# 128             0.381436                 0.556746               0.121946
# 129             0.300982                 0.780247               0.346916
# 131             0.004912                 0.319952               0.245834
# 134             0.015583                 0.195707               0.074127
# 137             0.000678                 0.433958               0.119845
# 138             0.004065                 0.151675               0.076147
# 139             0.006606                 0.186666               0.084206
# 140             0.019309                 0.351691               0.123669
# 144             0.001524                 0.127357               0.060248
# 145             0.027778                 0.448545               0.187444
# 146             0.000508                 0.043396               0.024372
# 147             0.056572                 0.356415               0.109006
# 148             0.023035                 0.440435               0.158983
# 149             0.567412                 0.580730               0.249365
# 150             0.009993                 0.308476               0.087021
# 151             0.000169                 0.026569               0.019288
# 152             0.019986                 0.679740               0.243263
# 153             0.000508                 0.068520               0.030417
# 155             0.002710                 0.484419               0.125083
# 156             0.002710                 0.035914               0.026053
# 158             0.000508                 0.075108               0.041537
# 159             0.001016                 0.085838               0.039247
# 161             0.000678                 0.024916               0.018544
# 162             0.002710                 0.131835               0.046197
# 163             0.014566                 0.538275               0.377998
# 164             0.031843                 0.332544               0.120350
# 165             0.898205                 0.524967               0.343869
# 166             0.211213                 0.175868               0.105735
# 167             0.051152                 0.330670               0.127735
# 168             0.048780                 0.327173               0.127536
# 169             0.003218                 0.122454               0.069471
# 170             0.000000                 0.000000               0.000000
# 181             0.211213                 0.175868               0.105735
# 183             0.004912                 0.237449               0.092220
# 189             0.567412                 0.580730               0.249365
# 190             0.000339                 0.081367               0.033205
# 192             0.000000                 0.000000               0.000000
# 194             0.000847                 0.283016               0.099355
# 195             0.000508                 0.042919               0.031508
# 196             0.000678                 0.260375               0.070634
# 197             0.030318                 0.605287               0.312097
# 198             0.000000                 0.000000               0.000000
# 204             0.012703                 0.355057               0.139988
# 205             0.007453                 0.406259               0.110793
# 206             0.073848                 0.380186               0.144658
# 209             0.111280                 0.578318               0.400446
# 213             0.571138                 0.580754               0.249737
# 214             0.002879                 0.092602               0.040854
#
#      innerClassesQty_max  comparisonsQty_sum  comparisonsQty_average  \
# 0               0.000000            0.000045                0.055446
# 1               0.065217            0.021395                0.070615
# 2               0.021739            0.003951                0.077402
# 3               0.038043            0.009588                0.055643
# 4               0.010870            0.013448                0.054348
# 5               0.076087            0.015984                0.020293
# 6               0.086957            0.024474                0.116382
# 7               0.831522            0.003475                0.009908
# 8               0.027174            0.000170                0.014851
# 10              0.016304            0.004279                0.026198
# 11              0.141304            0.047091                0.051670
# 12              0.298913            0.014908                0.025267
# 16              0.288043            0.031175                0.032516
# 17              0.076087            0.015984                0.020293
# 19              0.065217            0.007437                0.111060
# 20              0.027174            0.003588                0.025181
# 21              0.010870            0.002287                0.003625
# 23              0.032609            0.002921                0.145969
# 24              0.010870            0.013652                0.053154
# 25              0.005435            0.001053                0.083168
# 29              0.038043            0.002819                0.127833
# 35              0.684783            0.180181                0.031550
# 36              0.016304            0.002864                0.073061
# 37              0.021739            0.000498                0.015638
# ...
# [pca] >Outlier detection using SPE/DmodX with n_std=[2]
#         PC                         feature   loading  type
# 0      PC1           privateMethodsQty_sum  0.199945  best
# 1      PC2       maxNestedBlocksQty_median  0.171254  best
# 2      PC3                         lcc_min  0.412124  best
# 3      PC4        abstractMethodsQty_stdev  0.228420  best
# 4      PC5        parenthesizedExpsQty_max -0.282020  best
# 5      PC6                 modifiers_stdev -0.236244  best
# 6      PC7                   modifiers_min  0.407590  best
# 7      PC8                      dit_median  0.349625  best
# 8      PC9                       loc_stdev  0.255174  best
# 9     PC10               modifiers_average  0.257019  best
# 10    PC11            totalFieldsQty_stdev  0.378982  best
# 11    PC12           defaultMethodsQty_max  0.270719  best
# 12    PC13              lambdasQty_average  0.289119  best
# 13    PC14                 modifiers_stdev  0.343818  best
# 14    PC15            staticMethodsQty_max -0.366740  best
# 15    PC16        parenthesizedExpsQty_max  0.261768  best
# 16    PC17     anonymousClassesQty_average -0.225604  best
# 17    PC18                         loc_max  0.232155  best
# 18    PC19       anonymousClassesQty_stdev -0.284652  best
# 19    PC20                      lcc_median -0.452260  best
# 20    PC21         stringLiteralsQty_stdev  0.270861  best
# 21    PC22        defaultMethodsQty_median  0.374927  best
# 22    PC23                      dit_median  0.383379  best
# 23    PC24        defaultMethodsQty_median -0.261491  best
# 24    PC25                      dit_median  0.247079  best
# 25    PC26           finalFieldsQty_median  0.305402  best
# 26    PC27                   modifiers_max  0.323166  best
# 27    PC28     anonymousClassesQty_average -0.243459  best
# 28    PC29           stringLiteralsQty_max  0.326862  best
# 29    PC30                returnQty_median  0.262619  best
# 30    PC31          maxNestedBlocksQty_max  0.292644  best
# 31    PC32            staticMethodsQty_max -0.254217  best
# 32    PC33                   returnQty_max  0.331695  best
# 33    PC34                returnQty_median -0.391552  best
# 34    PC35      synchronizedMethodsQty_max -0.285135  best
# 35    PC36                     dit_average  0.298290  best
# 36    PC37         innerClassesQty_average -0.316964  best
# 37    PC38       maxNestedBlocksQty_median  0.284734  best
# 38    PC39       anonymousClassesQty_stdev -0.258599  best
# 39    PC40          maxNestedBlocksQty_max  0.241454  best
# 40    PC41       anonymousClassesQty_stdev  0.236963  best
# 41    PC42             publicFieldsQty_max  0.203382  best
# 42    PC43         innerClassesQty_average  0.246220  best
# 43    PC44           privateMethodsQty_max  0.348142  best
# 44    PC45       maxNestedBlocksQty_median -0.261097  best
# 45    PC46              totalFieldsQty_sum  0.252221  best
# 46    PC47           finalFieldsQty_median  0.267359  best
# 47    PC48     parenthesizedExpsQty_median -0.234114  best
# 48    PC49                      cbo_median -0.258277  best
# 49    PC50        protectedFieldsQty_stdev -0.219535  best
# 50    PC51                     dit_average  0.213481  best
# 51    PC52                  lambdasQty_sum -0.323822  best
# 52    PC53       stringLiteralsQty_average  0.267978  best
# 53    PC54                returnQty_median  0.204319  best
# 54    PC55              totalFieldsQty_sum -0.248853  best
# 55    PC56          finalFieldsQty_average  0.298406  best
# 56    PC57       protectedFieldsQty_median  0.213907  best
# 57    PC58                  lambdasQty_sum -0.241142  best
# 58    PC59           finalFieldsQty_median  0.280118  best
# 59    PC60       anonymousClassesQty_stdev -0.243899  best
# 60    PC61                 tryCatchQty_sum -0.201191  best
# 61    PC62            defaultFieldsQty_max  0.229049  best
# 62    PC63       stringLiteralsQty_average -0.247999  best
# 63    PC64       defaultMethodsQty_average  0.300487  best
# 64    PC65             tryCatchQty_average -0.207158  best
# 65    PC66          staticFieldsQty_median -0.279934  best
# 66    PC67          maxNestedBlocksQty_max  0.279510  best
# 67    PC68          staticFieldsQty_median  0.239391  best
# 68    PC69        defaultFieldsQty_average  0.334665  best
# 69    PC70        visibleFieldsQty_average -0.234655  best
# 70    PC71              totalFieldsQty_sum -0.313468  best
# 71    PC72                       cbo_stdev -0.331197  best
# 72    PC73                         dit_max -0.245426  best
# 73    PC74            uniqueWordsQty_stdev -0.293664  best
# 74    PC75                         dit_max -0.270351  best
# 75    PC76           uniqueWordsQty_median  0.225383  best
# 76    PC77     protectedMethodsQty_average  0.270555  best
# 77    PC78            logStatementsQty_sum -0.192260  best
# 78    PC79                   modifiers_max  0.190514  best
# 79    PC80    synchronizedMethodsQty_stdev  0.257153  best
# 80    PC81       protectedFieldsQty_median  0.284625  best
# 81    PC82       abstractMethodsQty_median  0.241447  best
# 82    PC83         publicFieldsQty_average -0.313218  best
# 83    PC84          totalMethodsQty_median  0.271328  best
# 84    PC85               numbersQty_median -0.256816  best
# 85    PC86         publicMethodsQty_median  0.308274  best
# 86    PC87             variablesQty_median  0.383340  best
# 87    PC88        maxNestedBlocksQty_stdev -0.258664  best
# 88    PC89               numbersQty_median  0.241161  best
# 89    PC90         protectedMethodsQty_sum -0.214123  best
# 90    PC91         publicMethodsQty_median -0.287765  best
# 91    PC92            defaultFieldsQty_sum -0.238264  best
# 92    PC93                      wmc_median  0.272823  best
# 93    PC94                 returnQty_stdev -0.229279  best
# 94    PC95        stringLiteralsQty_median -0.273667  best
# 95    PC96           innerClassesQty_stdev -0.222529  best
# 96    PC97                         cbo_max  0.276350  best
# 97    PC98                       dit_stdev -0.250500  best
# 98    PC99                      wmc_median  0.217349  best
# 99   PC100        stringLiteralsQty_median -0.199243  best
# 100  PC101                     nosi_median  0.231947  best
# 101  PC102                  lambdasQty_sum  0.339362  best
# 102  PC103             publicFieldsQty_sum -0.231152  best
# 103  PC104                  lambdasQty_max  0.297218  best
# 104  PC105         anonymousClassesQty_sum  0.303454  best
# 105  PC106                lambdasQty_stdev  0.355350  best
# 106  PC107    parenthesizedExpsQty_average  0.351066  best
# 107  PC108    parenthesizedExpsQty_average -0.606295  best
# 108  PC109                     rfc_average  0.320601  best
# 109  PC110                         rfc_max  0.325825  best
# 110  PC111    synchronizedMethodsQty_stdev -0.270243  best
# 111  PC112       mathOperationsQty_average -0.321184  best
# 112  PC113                     rfc_average  0.285692  best
# 113   PC16      synchronizedMethodsQty_sum  0.214906  weak
# 114   PC75  synchronizedMethodsQty_average  0.169622  weak
# 115  PC106        parenthesizedExpsQty_sum -0.161721  weak
# 116  PC108      parenthesizedExpsQty_stdev  0.324624  weak
# 117  PC107                        lcom_sum -0.147952  weak
# 118   PC93                    lcom_average  0.203702  weak
# 119   PC97                      lcom_stdev -0.254958  weak
# 120   PC73                     lcom_median  0.169440  weak
# 121  PC112                        lcom_max  0.137768  weak
# 122    PC1            publicMethodsQty_sum  0.137262  weak
# 123    PC4        publicMethodsQty_average  0.207299  weak
# 124    PC4          publicMethodsQty_stdev  0.213750  weak
# 125   PC52            publicMethodsQty_max  0.155752  weak
# 126    PC1             staticFieldsQty_sum  0.179887  weak
# 127   PC81         staticFieldsQty_average  0.186184  weak
# 128  PC110           staticFieldsQty_stdev -0.209157  weak
# 129    PC9             staticFieldsQty_max -0.137544  weak
# 130   PC42           publicFieldsQty_stdev  0.200264  weak
# 131   PC81          publicFieldsQty_median  0.201755  weak
# 132  PC111        logStatementsQty_average -0.185645  weak
# 133   PC14          logStatementsQty_stdev  0.178644  weak
# 134  PC112         logStatementsQty_median -0.180080  weak
# 135   PC62            logStatementsQty_max -0.202843  weak
# 136  PC110               tryCatchQty_stdev -0.239295  weak
# 137   PC23              tryCatchQty_median  0.246958  weak
# 138  PC104                 tryCatchQty_max -0.286114  weak
# 139  PC113          maxNestedBlocksQty_sum -0.133387  weak
# 140   PC30      maxNestedBlocksQty_average  0.230214  weak
# 141  PC110                         wmc_sum  0.127198  weak
# 142    PC2                     wmc_average  0.115013  weak
# 143   PC88                       wmc_stdev -0.147086  weak
# 144   PC82                         wmc_max -0.212216  weak
# 145    PC1                         rfc_sum  0.168643  weak
# 146  PC110                       rfc_stdev -0.242915  weak
# 147   PC49                      rfc_median  0.221166  weak
# 148   PC89       privateMethodsQty_average -0.168002  weak
# 149   PC44         privateMethodsQty_stdev  0.229784  weak
# 150   PC89        privateMethodsQty_median  0.230435  weak
# 151  PC102           defaultMethodsQty_sum -0.275198  weak
# 152  PC113         defaultMethodsQty_stdev  0.245678  weak
# 153   PC62                        nosi_sum -0.170922  weak
# 154   PC19                    nosi_average -0.186517  weak
# 155   PC91                      nosi_stdev  0.193848  weak
# 156  PC105                        nosi_max  0.184031  weak
# 157   PC92            visibleFieldsQty_sum  0.192065  weak
# 158  PC112          visibleFieldsQty_stdev -0.244430  weak
# 159  PC113            visibleFieldsQty_max -0.120819  weak
# 160    PC1              uniqueWordsQty_sum  0.160845  weak
# 161   PC91          uniqueWordsQty_average -0.206860  weak
# 162  PC113              uniqueWordsQty_max -0.201651  weak
# 163  PC103           stringLiteralsQty_sum  0.198822  weak
# 164  PC105         anonymousClassesQty_max -0.213469  weak
# 165  PC100           mathOperationsQty_sum -0.080105  weak
# 166   PC42         mathOperationsQty_stdev  0.182408  weak
# 167   PC94        mathOperationsQty_median -0.155664  weak
# 168   PC77           mathOperationsQty_max -0.209826  weak
# 169  PC112                   returnQty_sum  0.120299  weak
# 170   PC98               returnQty_average  0.178578  weak
# 171  PC106                   modifiers_sum  0.170511  weak
# 172   PC10                modifiers_median  0.226730  weak
# 173   PC61                         lcc_sum  0.192591  weak
# 174    PC6                     lcc_average -0.196931  weak
# 175    PC3                       lcc_stdev -0.213058  weak
# 176    PC1          abstractMethodsQty_sum  0.164031  weak
# 177    PC4      abstractMethodsQty_average  0.223932  weak
# 178  PC100          abstractMethodsQty_max  0.159724  weak
# 179    PC1          protectedFieldsQty_sum  0.156411  weak
# 180  PC109      protectedFieldsQty_average -0.206743  weak
# 181   PC63          protectedFieldsQty_max  0.199504  weak
# 182   PC77                  numbersQty_sum  0.151896  weak
# 183   PC51              numbersQty_average -0.157500  weak
# 184   PC64                numbersQty_stdev  0.216652  weak
# 185   PC64                  numbersQty_max  0.201411  weak
# 186   PC68            staticMethodsQty_sum -0.173371  weak
# 187   PC96        staticMethodsQty_average -0.161713  weak
# 188   PC80          staticMethodsQty_stdev  0.196658  weak
# 189   PC94         staticMethodsQty_median -0.092032  weak
# 190    PC1              assignmentsQty_sum  0.155698  weak
# 191    PC2          assignmentsQty_average  0.122473  weak
# 192   PC67            assignmentsQty_stdev  0.169543  weak
# 193   PC89           assignmentsQty_median -0.201083  weak
# 194   PC16              assignmentsQty_max -0.143299  weak
# 195  PC102              finalFieldsQty_sum -0.212304  weak
# 196   PC42            finalFieldsQty_stdev  0.169562  weak
# 197   PC42              finalFieldsQty_max  0.200451  weak
# 198  PC107                         dit_sum -0.213367  weak
# 199    PC1             totalMethodsQty_sum  0.173211  weak
# 200    PC4         totalMethodsQty_average  0.204027  weak
# 201    PC4           totalMethodsQty_stdev  0.211436  weak
# 202  PC100             totalMethodsQty_max  0.184905  weak
# 203   PC90                     loopQty_sum  0.159830  weak
# 204   PC55                 loopQty_average -0.161787  weak
# 205   PC16                   loopQty_stdev -0.171503  weak
# 206   PC86                  loopQty_median -0.222340  weak
# 207   PC16                     loopQty_max -0.154963  weak
# 208   PC34          defaultFieldsQty_stdev  0.186981  weak
# 209    PC1                         loc_sum  0.180242  weak
# 210   PC93                     loc_average -0.138606  weak
# 211   PC87                      loc_median -0.212606  weak
# 212   PC11          totalFieldsQty_average  0.206168  weak
# 213   PC47           totalFieldsQty_median -0.168824  weak
# 214   PC35              totalFieldsQty_max  0.224938  weak
# 215    PC1                         cbo_sum  0.184407  weak
# 216   PC14                     cbo_average -0.234531  weak
# 217    PC1                variablesQty_sum  0.175752  weak
# 218  PC107            variablesQty_average  0.170388  weak
# 219   PC60              variablesQty_stdev -0.182983  weak
# 220   PC11                variablesQty_max -0.122539  weak
# 221   PC15       protectedMethodsQty_stdev  0.203639  weak
# 222   PC82         protectedMethodsQty_max -0.204770  weak
# 223   PC61                         tcc_sum  0.192591  weak
# 224    PC6                     tcc_average -0.196931  weak
# 225    PC3                       tcc_stdev -0.213058  weak
# 226   PC20                      tcc_median -0.452260  weak
# 227    PC3                         tcc_min  0.412124  weak
# 228    PC9            privateFieldsQty_sum -0.135530  weak
# 229   PC45        privateFieldsQty_average -0.221869  weak
# 230  PC100          privateFieldsQty_stdev -0.184110  weak
# 231    PC1         privateFieldsQty_median  0.000000  weak
# 232    PC9            privateFieldsQty_max -0.139885  weak
# 233   PC10             finalMethodsQty_sum  0.244114  weak
# 234   PC10         finalMethodsQty_average  0.228913  weak
# 235   PC10           finalMethodsQty_stdev  0.229037  weak
# 236   PC10          finalMethodsQty_median  0.226255  weak
# 237   PC59             finalMethodsQty_max  0.231670  weak
# 238   PC97             innerClassesQty_sum -0.237304  weak
# 239   PC39             innerClassesQty_max  0.236931  weak
# 240   PC97              comparisonsQty_sum -0.069933  weak
# 241   PC98          comparisonsQty_average  0.146076  weak
# 242   PC82            comparisonsQty_stdev  0.140979  weak
# 243   PC96           comparisonsQty_median -0.207909  weak
# 244    PC5              comparisonsQty_max -0.216716  weak
# 0.9768518518518519
# 0.4074074074074074
#               precision    recall  f1-score   support
#
#          1.0       0.36      0.22      0.28        18
#          2.0       0.45      0.71      0.55        24
#          3.0       0.20      0.08      0.12        12
#
#     accuracy                           0.41        54
#    macro avg       0.34      0.34      0.31        54
# weighted avg       0.36      0.41      0.36        54
#
# 0.7037037037037037
# 0.42592592592592593
#               precision    recall  f1-score   support
#
#          1.0       0.38      0.61      0.47        18
#          2.0       0.48      0.42      0.44        24
#          3.0       0.50      0.17      0.25        12
#
#     accuracy                           0.43        54
#    macro avg       0.45      0.40      0.39        54
# weighted avg       0.45      0.43      0.41        54
#
# 0.9212962962962963
# 0.3333333333333333
#               precision    recall  f1-score   support
#
#          1.0       0.38      0.83      0.53        18
#          2.0       0.50      0.04      0.08        24
#          3.0       0.15      0.17      0.16        12
#
#     accuracy                           0.33        54
#    macro avg       0.35      0.35      0.25        54
# weighted avg       0.38      0.33      0.25        54
#
# LMNN accuracy on train set of 216 points: 0.7361
# LMNN accuracy on test set of 54 points: 0.2222

# %%
main()
# Out:
# >> initialising model...
# The best parameters are {'leaf_size': 1, 'metric': 'minkowski', 'n_neighbors': 7, 'p': 4, 'weights': 'distance'} with a score of 0.50
# <bound method NDFrame.head of       leaf_size     metric  n_neighbors  p   weights  Accuracy
# 901           2  minkowski           13  3  distance  0.500000
# 1381          3  minkowski           13  3  distance  0.500000
# 1815          4  minkowski            7  4  distance  0.500000
# 855           2  minkowski            7  4  distance  0.500000
# 421           1  minkowski           13  3  distance  0.500000
# 1861          4  minkowski           13  3  distance  0.500000
# 1335          3  minkowski            7  4  distance  0.500000
# 375           1  minkowski            7  4  distance  0.500000
# 447           1  minkowski           16  4  distance  0.495370
# 927           2  minkowski           16  4  distance  0.495370
# 1887          4  minkowski           16  4  distance  0.495370
# 1407          3  minkowski           16  4  distance  0.495370
# 1363          3  minkowski           11  2  distance  0.493056
# 1365          3  minkowski           11  3  distance  0.493056
# 1373          3  minkowski           12  3  distance  0.493056
# 1877          4  minkowski           15  3  distance  0.493056
# 563           2  euclidean           11  2  distance  0.493056
# 1397          3  minkowski           15  3  distance  0.493056
# 567           2  euclidean           11  4  distance  0.493056
# 565           2  euclidean           11  3  distance  0.493056
# 561           2  euclidean           11  1  distance  0.493056
# 1025          3  euclidean            9  1  distance  0.493056
# 1347          3  minkowski            9  2  distance  0.493056
# 867           2  minkowski            9  2  distance  0.493056
# 1309          3  minkowski            4  3  distance  0.493056
# 829           2  minkowski            4  3  distance  0.493056
# 549           2  euclidean            9  3  distance  0.493056
# 883           2  minkowski           11  2  distance  0.493056
# 65            1  euclidean            9  1  distance  0.493056
# 885           2  minkowski           11  3  distance  0.493056
# 67            1  euclidean            9  2  distance  0.493056
# 893           2  minkowski           12  3  distance  0.493056
# 69            1  euclidean            9  3  distance  0.493056
# 71            1  euclidean            9  4  distance  0.493056
# 917           2  minkowski           15  3  distance  0.493056
# 1789          4  minkowski            4  3  distance  0.493056
# 1827          4  minkowski            9  2  distance  0.493056
# 551           2  euclidean            9  4  distance  0.493056
# 1845          4  minkowski           11  3  distance  0.493056
# 1027          3  euclidean            9  2  distance  0.493056
# 387           1  minkowski            9  2  distance  0.493056
# 1043          3  euclidean           11  2  distance  0.493056
# 1507          4  euclidean            9  2  distance  0.493056
# 1505          4  euclidean            9  1  distance  0.493056
# 1041          3  euclidean           11  1  distance  0.493056
# 547           2  euclidean            9  2  distance  0.493056
# 1047          3  euclidean           11  4  distance  0.493056
# 1509          4  euclidean            9  3  distance  0.493056
# 1511          4  euclidean            9  4  distance  0.493056
# 349           1  minkowski            4  3  distance  0.493056
# 1045          3  euclidean           11  3  distance  0.493056
# 405           1  minkowski           11  3  distance  0.493056
# 1031          3  euclidean            9  4  distance  0.493056
# 413           1  minkowski           12  3  distance  0.493056
# 1029          3  euclidean            9  3  distance  0.493056
# 545           2  euclidean            9  1  distance  0.493056
# 437           1  minkowski           15  3  distance  0.493056
# 919           2  minkowski           15  4  distance  0.493056
# 423           1  minkowski           13  4  distance  0.493056
# 1863          4  minkowski           13  4  distance  0.493056
# 439           1  minkowski           15  4  distance  0.493056
# 1399          3  minkowski           15  4  distance  0.493056
# 909           2  minkowski           14  3  distance  0.490741
# 1853          4  minkowski           12  3  distance  0.490741
# 429           1  minkowski           14  3  distance  0.490741
# 1383          3  minkowski           13  4  distance  0.490741
# 903           2  minkowski           13  4  distance  0.490741
# 1389          3  minkowski           14  3  distance  0.490741
# 403           1  minkowski           11  2  distance  0.490741
# 1843          4  minkowski           11  2  distance  0.490741
# 1497          4  euclidean            8  1  distance  0.490741
# 1819          4  minkowski            8  2  distance  0.490741
# 87            1  euclidean           11  4  distance  0.490741
# 543           2  euclidean            8  4  distance  0.490741
# 541           2  euclidean            8  3  distance  0.490741
# 1339          3  minkowski            8  2  distance  0.490741
# 1503          4  euclidean            8  4  distance  0.490741
# 379           1  minkowski            8  2  distance  0.490741
# 1527          4  euclidean           11  4  distance  0.490741
# 1525          4  euclidean           11  3  distance  0.490741
# 1523          4  euclidean           11  2  distance  0.490741
# 1521          4  euclidean           11  1  distance  0.490741
# 539           2  euclidean            8  2  distance  0.490741
# 537           2  euclidean            8  1  distance  0.490741
# 1501          4  euclidean            8  3  distance  0.490741
# 859           2  minkowski            8  2  distance  0.490741
# 1499          4  euclidean            8  2  distance  0.490741
# 59            1  euclidean            8  2  distance  0.490741
# 63            1  euclidean            8  4  distance  0.490741
# 1019          3  euclidean            8  2  distance  0.490741
# 1017          3  euclidean            8  1  distance  0.490741
# 85            1  euclidean           11  3  distance  0.490741
# 57            1  euclidean            8  1  distance  0.490741
# 83            1  euclidean           11  2  distance  0.490741
# 81            1  euclidean           11  1  distance  0.490741
# 1021          3  euclidean            8  3  distance  0.490741
# 1879          4  minkowski           15  4  distance  0.490741
# 61            1  euclidean            8  3  distance  0.490741
# 1023          3  euclidean            8  4  distance  0.490741
# 1869          4  minkowski           14  3  distance  0.488426
# 381           1  minkowski            8  3  distance  0.488426
# 1821          4  minkowski            8  3  distance  0.488426
# 373           1  minkowski            7  3  distance  0.488426
# 1813          4  minkowski            7  3  distance  0.488426
# 1333          3  minkowski            7  3  distance  0.488426
# 853           2  minkowski            7  3  distance  0.488426
# 1341          3  minkowski            8  3  distance  0.488426
# 861           2  minkowski            8  3  distance  0.488426
# 53            1  euclidean            7  3  distance  0.486111
# 55            1  euclidean            7  4  distance  0.486111
# 371           1  minkowski            7  2  distance  0.486111
# 1811          4  minkowski            7  2  distance  0.486111
# 529           2  euclidean            7  1  distance  0.486111
# 531           2  euclidean            7  2  distance  0.486111
# 533           2  euclidean            7  3  distance  0.486111
# 1495          4  euclidean            7  4  distance  0.486111
# 535           2  euclidean            7  4  distance  0.486111
# 1493          4  euclidean            7  3  distance  0.486111
# 1491          4  euclidean            7  2  distance  0.486111
# 1489          4  euclidean            7  1  distance  0.486111
# 1013          3  euclidean            7  3  distance  0.486111
# 851           2  minkowski            7  2  distance  0.486111
# 49            1  euclidean            7  1  distance  0.486111
# 1015          3  euclidean            7  4  distance  0.486111
# 51            1  euclidean            7  2  distance  0.486111
# 1331          3  minkowski            7  2  distance  0.486111
# 1011          3  euclidean            7  2  distance  0.486111
# 1009          3  euclidean            7  1  distance  0.486111
# 185           1  manhattan            4  1  distance  0.486111
# 665           2  manhattan            4  1  distance  0.486111
# 667           2  manhattan            4  2  distance  0.486111
# 669           2  manhattan            4  3  distance  0.486111
# 671           2  manhattan            4  4  distance  0.486111
# 1391          3  minkowski           14  4  distance  0.486111
# 1871          4  minkowski           14  4  distance  0.486111
# 187           1  manhattan            4  2  distance  0.486111
# 1785          4  minkowski            4  1  distance  0.486111
# 189           1  manhattan            4  3  distance  0.486111
# 191           1  manhattan            4  4  distance  0.486111
# 431           1  minkowski           14  4  distance  0.486111
# 825           2  minkowski            4  1  distance  0.486111
# 1305          3  minkowski            4  1  distance  0.486111
# 1147          3  manhattan            4  2  distance  0.486111
# 911           2  minkowski           14  4  distance  0.486111
# 1629          4  manhattan            4  3  distance  0.486111
# 345           1  minkowski            4  1  distance  0.486111
# 1151          3  manhattan            4  4  distance  0.486111
# 1631          4  manhattan            4  4  distance  0.486111
# 1625          4  manhattan            4  1  distance  0.486111
# 1149          3  manhattan            4  3  distance  0.486111
# 1145          3  manhattan            4  1  distance  0.486111
# 1627          4  manhattan            4  2  distance  0.486111
# 583           2  euclidean           13  4  distance  0.483796
# 101           1  euclidean           13  3  distance  0.483796
# 103           1  euclidean           13  4  distance  0.483796
# 1063          3  euclidean           13  4  distance  0.483796
# 1379          3  minkowski           13  2  distance  0.483796
# 1061          3  euclidean           13  3  distance  0.483796
# 1807          4  minkowski            6  4  distance  0.483796
# 367           1  minkowski            6  4  distance  0.483796
# 899           2  minkowski           13  2  distance  0.483796
# 419           1  minkowski           13  2  distance  0.483796
# 581           2  euclidean           13  3  distance  0.483796
# 577           2  euclidean           13  1  distance  0.483796
# 579           2  euclidean           13  2  distance  0.483796
# 99            1  euclidean           13  2  distance  0.483796
# 1059          3  euclidean           13  2  distance  0.483796
# 1057          3  euclidean           13  1  distance  0.483796
# 847           2  minkowski            6  4  distance  0.483796
# 97            1  euclidean           13  1  distance  0.483796
# 1327          3  minkowski            6  4  distance  0.483796
# 863           2  minkowski            8  4  distance  0.481481
# 1591          4  euclidean           19  4  distance  0.481481
# 1343          3  minkowski            8  4  distance  0.481481
# 1589          4  euclidean           19  3  distance  0.481481
# 1587          4  euclidean           19  2  distance  0.481481
# 1585          4  euclidean           19  1  distance  0.481481
# 383           1  minkowski            8  4  distance  0.481481
# 1907          4  minkowski           19  2  distance  0.481481
# 1105          3  euclidean           19  1  distance  0.481481
# 1885          4  minkowski           16  3  distance  0.481481
# 467           1  minkowski           19  2  distance  0.481481
# 151           1  euclidean           19  4  distance  0.481481
# 149           1  euclidean           19  3  distance  0.481481
# 625           2  euclidean           19  1  distance  0.481481
# 627           2  euclidean           19  2  distance  0.481481
# 629           2  euclidean           19  3  distance  0.481481
# 1111          3  euclidean           19  4  distance  0.481481
# 631           2  euclidean           19  4  distance  0.481481
# 1109          3  euclidean           19  3  distance  0.481481
# 1427          3  minkowski           19  2  distance  0.481481
# 947           2  minkowski           19  2  distance  0.481481
# 145           1  euclidean           19  1  distance  0.481481
# 147           1  euclidean           19  2  distance  0.481481
# 1823          4  minkowski            8  4  distance  0.481481
# 1107          3  euclidean           19  2  distance  0.481481
# 1891          4  minkowski           17  2  distance  0.481481
# 1095          3  euclidean           17  4  distance  0.481481
# 1575          4  euclidean           17  4  distance  0.481481
# 1539          4  euclidean           13  2  distance  0.481481
# 1541          4  euclidean           13  3  distance  0.481481
# 1571          4  euclidean           17  2  distance  0.481481
# 1543          4  euclidean           13  4  distance  0.481481
# 1573          4  euclidean           17  3  distance  0.481481
# 609           2  euclidean           17  1  distance  0.481481
# 1093          3  euclidean           17  3  distance  0.481481
# 611           2  euclidean           17  2  distance  0.481481
# 613           2  euclidean           17  3  distance  0.481481
# 615           2  euclidean           17  4  distance  0.481481
# 451           1  minkowski           17  2  distance  0.481481
# 1569          4  euclidean           17  1  distance  0.481481
# 1089          3  euclidean           17  1  distance  0.481481
# 1091          3  euclidean           17  2  distance  0.481481
# 1537          4  euclidean           13  1  distance  0.481481
# 1411          3  minkowski           17  2  distance  0.481481
# 133           1  euclidean           17  3  distance  0.481481
# 129           1  euclidean           17  1  distance  0.481481
# 1859          4  minkowski           13  2  distance  0.481481
# 931           2  minkowski           17  2  distance  0.481481
# 131           1  euclidean           17  2  distance  0.481481
# 135           1  euclidean           17  4  distance  0.481481
# 127           1  euclidean           16  4  distance  0.479167
# 1087          3  euclidean           16  4  distance  0.479167
# 125           1  euclidean           16  3  distance  0.479167
# 1085          3  euclidean           16  3  distance  0.479167
# 1083          3  euclidean           16  2  distance  0.479167
# 1403          3  minkowski           16  2  distance  0.479167
# 123           1  euclidean           16  2  distance  0.479167
# 121           1  euclidean           16  1  distance  0.479167
# 1081          3  euclidean           16  1  distance  0.479167
# 601           2  euclidean           16  1  distance  0.479167
# 605           2  euclidean           16  3  distance  0.479167
# 607           2  euclidean           16  4  distance  0.479167
# 923           2  minkowski           16  2  distance  0.479167
# 411           1  minkowski           12  2  distance  0.479167
# 603           2  euclidean           16  2  distance  0.479167
# 93            1  euclidean           12  3  distance  0.479167
# 95            1  euclidean           12  4  distance  0.479167
# 443           1  minkowski           16  2  distance  0.479167
# 91            1  euclidean           12  2  distance  0.479167
# 89            1  euclidean           12  1  distance  0.479167
# 1593          4  euclidean           20  1  distance  0.479167
# 77            1  euclidean           10  3  distance  0.479167
# 1517          4  euclidean           10  3  distance  0.479167
# 1033          3  euclidean           10  1  distance  0.479167
# 475           1  minkowski           20  2  distance  0.479167
# 73            1  euclidean           10  1  distance  0.479167
# 75            1  euclidean           10  2  distance  0.479167
# 407           1  minkowski           11  4  distance  0.479167
# 1117          3  euclidean           20  3  distance  0.479167
# 1035          3  euclidean           10  2  distance  0.479167
# 1797          4  minkowski            5  3  distance  0.479167
# 633           2  euclidean           20  1  distance  0.479167
# 1435          3  minkowski           20  2  distance  0.479167
# 395           1  minkowski           10  2  distance  0.479167
# 925           2  minkowski           16  3  distance  0.479167
# 153           1  euclidean           20  1  distance  0.479167
# 555           2  euclidean           10  2  distance  0.479167
# 43            1  euclidean            6  2  distance  0.479167
# 559           2  euclidean           10  4  distance  0.479167
# 79            1  euclidean           10  4  distance  0.479167
# 45            1  euclidean            6  3  distance  0.479167
# 557           2  euclidean           10  3  distance  0.479167
# 159           1  euclidean           20  4  distance  0.479167
# 837           2  minkowski            5  3  distance  0.479167
# 637           2  euclidean           20  3  distance  0.479167
# 1847          4  minkowski           11  4  distance  0.479167
# 553           2  euclidean           10  1  distance  0.479167
# 157           1  euclidean           20  3  distance  0.479167
# 1317          3  minkowski            5  3  distance  0.479167
# 155           1  euclidean           20  2  distance  0.479167
# 1915          4  minkowski           20  2  distance  0.479167
# 41            1  euclidean            6  1  distance  0.479167
# 635           2  euclidean           20  2  distance  0.479167
# 1115          3  euclidean           20  2  distance  0.479167
# 1113          3  euclidean           20  1  distance  0.479167
# 47            1  euclidean            6  4  distance  0.479167
# 357           1  minkowski            5  3  distance  0.479167
# 1405          3  minkowski           16  3  distance  0.479167
# 1513          4  euclidean           10  1  distance  0.479167
# 1519          4  euclidean           10  4  distance  0.479167
# 1599          4  euclidean           20  4  distance  0.479167
# 955           2  minkowski           20  2  distance  0.479167
# 1597          4  euclidean           20  3  distance  0.479167
# 1119          3  euclidean           20  4  distance  0.479167
# 363           1  minkowski            6  2  distance  0.479167
# 1039          3  euclidean           10  4  distance  0.479167
# 875           2  minkowski           10  2  distance  0.479167
# 1835          4  minkowski           10  2  distance  0.479167
# 1595          4  euclidean           20  2  distance  0.479167
# 1037          3  euclidean           10  3  distance  0.479167
# 445           1  minkowski           16  3  distance  0.479167
# 1355          3  minkowski           10  2  distance  0.479167
# 1515          4  euclidean           10  2  distance  0.479167
# 639           2  euclidean           20  4  distance  0.479167
# 1049          3  euclidean           12  1  distance  0.476852
# 1053          3  euclidean           12  3  distance  0.476852
# 1311          3  minkowski            4  4  distance  0.476852
# 1487          4  euclidean            6  4  distance  0.476852
# 1323          3  minkowski            6  2  distance  0.476852
# 1055          3  euclidean           12  4  distance  0.476852
# 1620          4  manhattan            3  3   uniform  0.476852
# 1893          4  minkowski           17  3  distance  0.476852
# 521           2  euclidean            6  1  distance  0.476852
# 1296          3  minkowski            3  1   uniform  0.476852
# 831           2  minkowski            4  4  distance  0.476852
# 351           1  minkowski            4  4  distance  0.476852
# 523           2  euclidean            6  2  distance  0.476852
# 816           2  minkowski            3  1   uniform  0.476852
# 336           1  minkowski            3  1   uniform  0.476852
# 1803          4  minkowski            6  2  distance  0.476852
# 525           2  euclidean            6  3  distance  0.476852
# 1622          4  manhattan            3  4   uniform  0.476852
# 527           2  euclidean            6  4  distance  0.476852
# 1051          3  euclidean           12  2  distance  0.476852
# 933           2  minkowski           17  3  distance  0.476852
# 1485          4  euclidean            6  3  distance  0.476852
# 573           2  euclidean           12  3  distance  0.476852
# 1483          4  euclidean            6  2  distance  0.476852
# 1883          4  minkowski           16  2  distance  0.476852
# 1481          4  euclidean            6  1  distance  0.476852
# 658           2  manhattan            3  2   uniform  0.476852
# 660           2  manhattan            3  3   uniform  0.476852
# 662           2  manhattan            3  4   uniform  0.476852
# 1413          3  minkowski           17  3  distance  0.476852
# 178           1  manhattan            3  2   uniform  0.476852
# 180           1  manhattan            3  3   uniform  0.476852
# 891           2  minkowski           12  2  distance  0.476852
# 182           1  manhattan            3  4   uniform  0.476852
# 1563          4  euclidean           16  2  distance  0.476852
# 887           2  minkowski           11  4  distance  0.476852
# 1776          4  minkowski            3  1   uniform  0.476852
# 415           1  minkowski           12  4  distance  0.476852
# 1567          4  euclidean           16  4  distance  0.476852
# 1001          3  euclidean            6  1  distance  0.476852
# 1003          3  euclidean            6  2  distance  0.476852
# 1371          3  minkowski           12  2  distance  0.476852
# 1367          3  minkowski           11  4  distance  0.476852
# 1565          4  euclidean           16  3  distance  0.476852
# 656           2  manhattan            3  1   uniform  0.476852
# 1561          4  euclidean           16  1  distance  0.476852
# 575           2  euclidean           12  4  distance  0.476852
# 1618          4  manhattan            3  2   uniform  0.476852
# 569           2  euclidean           12  1  distance  0.476852
# 1616          4  manhattan            3  1   uniform  0.476852
# 571           2  euclidean           12  2  distance  0.476852
# 176           1  manhattan            3  1   uniform  0.476852
# 1005          3  euclidean            6  3  distance  0.476852
# 1791          4  minkowski            4  4  distance  0.476852
# 843           2  minkowski            6  2  distance  0.476852
# 1007          3  euclidean            6  4  distance  0.476852
# 1140          3  manhattan            3  3   uniform  0.476852
# 1138          3  manhattan            3  2   uniform  0.476852
# 1136          3  manhattan            3  1   uniform  0.476852
# 1142          3  manhattan            3  4   uniform  0.476852
# 845           2  minkowski            6  3  distance  0.474537
# 1325          3  minkowski            6  3  distance  0.474537
# 1529          4  euclidean           12  1  distance  0.474537
# 1855          4  minkowski           12  4  distance  0.474537
# 1531          4  euclidean           12  2  distance  0.474537
# 1535          4  euclidean           12  4  distance  0.474537
# 1829          4  minkowski            9  3  distance  0.474537
# 453           1  minkowski           17  3  distance  0.474537
# 389           1  minkowski            9  3  distance  0.474537
# 455           1  minkowski           17  4  distance  0.474537
# 1533          4  euclidean           12  3  distance  0.474537
# 1851          4  minkowski           12  2  distance  0.474537
# 935           2  minkowski           17  4  distance  0.474537
# 895           2  minkowski           12  4  distance  0.474537
# 1415          3  minkowski           17  4  distance  0.474537
# 1375          3  minkowski           12  4  distance  0.474537
# 1895          4  minkowski           17  4  distance  0.474537
# 1187          3  manhattan            9  2  distance  0.472222
# 1667          4  manhattan            9  2  distance  0.472222
# 1669          4  manhattan            9  3  distance  0.472222
# 1671          4  manhattan            9  4  distance  0.472222
# 707           2  manhattan            9  2  distance  0.472222
# 1825          4  minkowski            9  1  distance  0.472222
# 1189          3  manhattan            9  3  distance  0.472222
# 711           2  manhattan            9  4  distance  0.472222
# 705           2  manhattan            9  1  distance  0.472222
# 865           2  minkowski            9  1  distance  0.472222
# 1191          3  manhattan            9  4  distance  0.472222
# 385           1  minkowski            9  1  distance  0.472222
# 709           2  manhattan            9  3  distance  0.472222
# 1665          4  manhattan            9  1  distance  0.472222
# 1185          3  manhattan            9  1  distance  0.472222
# 231           1  manhattan            9  4  distance  0.472222
# 1345          3  minkowski            9  1  distance  0.472222
# 229           1  manhattan            9  3  distance  0.472222
# 227           1  manhattan            9  2  distance  0.472222
# 225           1  manhattan            9  1  distance  0.472222
# 701           2  manhattan            8  3  distance  0.472222
# 1337          3  minkowski            8  1  distance  0.472222
# 1071          3  euclidean           14  4  distance  0.472222
# 995           3  euclidean            5  2  distance  0.472222
# 1387          3  minkowski           14  2  distance  0.472222
# 697           2  manhattan            8  1  distance  0.472222
# 869           2  minkowski            9  3  distance  0.472222
# 699           2  manhattan            8  2  distance  0.472222
# 999           3  euclidean            5  4  distance  0.472222
# 997           3  euclidean            5  3  distance  0.472222
# 857           2  minkowski            8  1  distance  0.472222
# 835           2  minkowski            5  2  distance  0.472222
# 703           2  manhattan            8  4  distance  0.472222
# 1349          3  minkowski            9  3  distance  0.472222
# 1065          3  euclidean           14  1  distance  0.472222
# 1431          3  minkowski           19  4  distance  0.472222
# 1429          3  minkowski           19  3  distance  0.472222
# 513           2  euclidean            5  1  distance  0.472222
# 1439          3  minkowski           20  4  distance  0.472222
# 907           2  minkowski           14  2  distance  0.472222
# 959           2  minkowski           20  4  distance  0.472222
# 517           2  euclidean            5  3  distance  0.472222
# 519           2  euclidean            5  4  distance  0.472222
# 951           2  minkowski           19  4  distance  0.472222
# 949           2  minkowski           19  3  distance  0.472222
# 1177          3  manhattan            8  1  distance  0.472222
# 1179          3  manhattan            8  2  distance  0.472222
# 1069          3  euclidean           14  3  distance  0.472222
# 1181          3  manhattan            8  3  distance  0.472222
# 1183          3  manhattan            8  4  distance  0.472222
# 1479          4  euclidean            5  4  distance  0.472222
# 1477          4  euclidean            5  3  distance  0.472222
# 1475          4  euclidean            5  2  distance  0.472222
# 1473          4  euclidean            5  1  distance  0.472222
# 585           2  euclidean           14  1  distance  0.472222
# 587           2  euclidean           14  2  distance  0.472222
# 589           2  euclidean           14  3  distance  0.472222
# 479           1  minkowski           20  4  distance  0.472222
# 591           2  euclidean           14  4  distance  0.472222
# 1545          4  euclidean           14  1  distance  0.472222
# 1547          4  euclidean           14  2  distance  0.472222
# 1549          4  euclidean           14  3  distance  0.472222
# 471           1  minkowski           19  4  distance  0.472222
# 515           2  euclidean            5  2  distance  0.472222
# 1551          4  euclidean           14  4  distance  0.472222
# 993           3  euclidean            5  1  distance  0.472222
# 469           1  minkowski           19  3  distance  0.472222
# 1315          3  minkowski            5  2  distance  0.472222
# 1067          3  euclidean           14  2  distance  0.472222
# 105           1  euclidean           14  1  distance  0.472222
# 217           1  manhattan            8  1  distance  0.472222
# 1795          4  minkowski            5  2  distance  0.472222
# 1799          4  minkowski            5  4  distance  0.472222
# 377           1  minkowski            8  1  distance  0.472222
# 33            1  euclidean            5  1  distance  0.472222
# 1805          4  minkowski            6  3  distance  0.472222
# 35            1  euclidean            5  2  distance  0.472222
# 37            1  euclidean            5  3  distance  0.472222
# 1817          4  minkowski            8  1  distance  0.472222
# 39            1  euclidean            5  4  distance  0.472222
# 365           1  minkowski            6  3  distance  0.472222
# 359           1  minkowski            5  4  distance  0.472222
# 223           1  manhattan            8  4  distance  0.472222
# 221           1  manhattan            8  3  distance  0.472222
# 219           1  manhattan            8  2  distance  0.472222
# 355           1  minkowski            5  2  distance  0.472222
# 1663          4  manhattan            8  4  distance  0.472222
# 1661          4  manhattan            8  3  distance  0.472222
# 107           1  euclidean           14  2  distance  0.472222
# 109           1  euclidean           14  3  distance  0.472222
# 111           1  euclidean           14  4  distance  0.472222
# 427           1  minkowski           14  2  distance  0.472222
# 1657          4  manhattan            8  1  distance  0.472222
# 1659          4  manhattan            8  2  distance  0.472222
# 1867          4  minkowski           14  2  distance  0.472222
# 1909          4  minkowski           19  3  distance  0.472222
# 879           2  minkowski           10  4  distance  0.469907
# 1788          4  minkowski            4  3   uniform  0.469907
# 1608          4  manhattan            2  1   uniform  0.469907
# 1308          3  minkowski            4  3   uniform  0.469907
# 348           1  minkowski            4  3   uniform  0.469907
# 1610          4  manhattan            2  2   uniform  0.469907
# 399           1  minkowski           10  4  distance  0.469907
# 828           2  minkowski            4  3   uniform  0.469907
# 1839          4  minkowski           10  4  distance  0.469907
# 1359          3  minkowski           10  4  distance  0.469907
# 1612          4  manhattan            2  3   uniform  0.469907
# 1768          4  minkowski            2  1   uniform  0.469907
# 1614          4  manhattan            2  4   uniform  0.469907
# 1423          3  minkowski           18  4  distance  0.469907
# 1673          4  manhattan           10  1  distance  0.469907
# 1679          4  manhattan           10  4  distance  0.469907
# 943           2  minkowski           18  4  distance  0.469907
# 1675          4  manhattan           10  2  distance  0.469907
# 1677          4  manhattan           10  3  distance  0.469907
# 1833          4  minkowski           10  1  distance  0.469907
# 1193          3  manhattan           10  1  distance  0.469907
# 1919          4  minkowski           20  4  distance  0.469907
# 1903          4  minkowski           18  4  distance  0.469907
# 239           1  manhattan           10  4  distance  0.469907
# 839           2  minkowski            5  4  distance  0.469907
# 1911          4  minkowski           19  4  distance  0.469907
# 1319          3  minkowski            5  4  distance  0.469907
# 463           1  minkowski           18  4  distance  0.469907
# 873           2  minkowski           10  1  distance  0.469907
# 233           1  manhattan           10  1  distance  0.469907
# 1353          3  minkowski           10  1  distance  0.469907
# 719           2  manhattan           10  4  distance  0.469907
# 1197          3  manhattan           10  3  distance  0.469907
# 717           2  manhattan           10  3  distance  0.469907
# 715           2  manhattan           10  2  distance  0.469907
# 235           1  manhattan           10  2  distance  0.469907
# 713           2  manhattan           10  1  distance  0.469907
# 237           1  manhattan           10  3  distance  0.469907
# 1195          3  manhattan           10  2  distance  0.469907
# 393           1  minkowski           10  1  distance  0.469907
# 1199          3  manhattan           10  4  distance  0.469907
# 1778          4  minkowski            3  2   uniform  0.467593
# 211           1  manhattan            7  2  distance  0.467593
# 215           1  manhattan            7  4  distance  0.467593
# 213           1  manhattan            7  3  distance  0.467593
# 1655          4  manhattan            7  4  distance  0.467593
# 1653          4  manhattan            7  3  distance  0.467593
# 1651          4  manhattan            7  2  distance  0.467593
# 1649          4  manhattan            7  1  distance  0.467593
# 691           2  manhattan            7  2  distance  0.467593
# 1288          3  minkowski            2  1   uniform  0.467593
# 808           2  minkowski            2  1   uniform  0.467593
# 1134          3  manhattan            2  4   uniform  0.467593
# 209           1  manhattan            7  1  distance  0.467593
# 1132          3  manhattan            2  3   uniform  0.467593
# 689           2  manhattan            7  1  distance  0.467593
# 849           2  minkowski            7  1  distance  0.467593
# 1809          4  minkowski            7  1  distance  0.467593
# 1329          3  minkowski            7  1  distance  0.467593
# 654           2  manhattan            2  4   uniform  0.467593
# 652           2  manhattan            2  3   uniform  0.467593
# 650           2  manhattan            2  2   uniform  0.467593
# 648           2  manhattan            2  1   uniform  0.467593
# 1462          4  euclidean            3  4   uniform  0.467593
# 1175          3  manhattan            7  4  distance  0.467593
# 693           2  manhattan            7  3  distance  0.467593
# 1458          4  euclidean            3  2   uniform  0.467593
# 1173          3  manhattan            7  3  distance  0.467593
# 1456          4  euclidean            3  1   uniform  0.467593
# 1171          3  manhattan            7  2  distance  0.467593
# 695           2  manhattan            7  4  distance  0.467593
# 1460          4  euclidean            3  3   uniform  0.467593
# 1169          3  manhattan            7  1  distance  0.467593
# 1130          3  manhattan            2  2   uniform  0.467593
# 369           1  minkowski            7  1  distance  0.467593
# 1128          3  manhattan            2  1   uniform  0.467593
# 277           1  manhattan           15  3  distance  0.467593
# 1393          3  minkowski           15  1  distance  0.467593
# 1421          3  minkowski           18  3  distance  0.467593
# 119           1  euclidean           15  4  distance  0.467593
# 117           1  euclidean           15  3  distance  0.467593
# 279           1  manhattan           15  4  distance  0.467593
# 913           2  minkowski           15  1  distance  0.467593
# 435           1  minkowski           15  2  distance  0.467593
# 1875          4  minkowski           15  2  distance  0.467593
# 915           2  minkowski           15  2  distance  0.467593
# 1395          3  minkowski           15  2  distance  0.467593
# 1075          3  euclidean           15  2  distance  0.467593
# 1719          4  manhattan           15  4  distance  0.467593
# 1073          3  euclidean           15  1  distance  0.467593
# 1717          4  manhattan           15  3  distance  0.467593
# 1715          4  manhattan           15  2  distance  0.467593
# 1713          4  manhattan           15  1  distance  0.467593
# 593           2  euclidean           15  1  distance  0.467593
# 595           2  euclidean           15  2  distance  0.467593
# 433           1  minkowski           15  1  distance  0.467593
# 597           2  euclidean           15  3  distance  0.467593
# 1901          4  minkowski           18  3  distance  0.467593
# 273           1  manhattan           15  1  distance  0.467593
# 1233          3  manhattan           15  1  distance  0.467593
# 1077          3  euclidean           15  3  distance  0.467593
# 1237          3  manhattan           15  3  distance  0.467593
# 753           2  manhattan           15  1  distance  0.467593
# 755           2  manhattan           15  2  distance  0.467593
# 1837          4  minkowski           10  3  distance  0.467593
# 461           1  minkowski           18  3  distance  0.467593
# 1559          4  euclidean           15  4  distance  0.467593
# 113           1  euclidean           15  1  distance  0.467593
# 757           2  manhattan           15  3  distance  0.467593
# 1557          4  euclidean           15  3  distance  0.467593
# 1239          3  manhattan           15  4  distance  0.467593
# 759           2  manhattan           15  4  distance  0.467593
# 115           1  euclidean           15  2  distance  0.467593
# 1555          4  euclidean           15  2  distance  0.467593
# 941           2  minkowski           18  3  distance  0.467593
# 599           2  euclidean           15  4  distance  0.467593
# 1079          3  euclidean           15  4  distance  0.467593
# 877           2  minkowski           10  3  distance  0.467593
# 1357          3  minkowski           10  3  distance  0.467593
# 1553          4  euclidean           15  1  distance  0.467593
# 275           1  manhattan           15  2  distance  0.467593
# 1873          4  minkowski           15  1  distance  0.467593
# 1235          3  manhattan           15  2  distance  0.467593
# 502           2  euclidean            3  4   uniform  0.465278
# 657           2  manhattan            3  1  distance  0.465278
# 1310          3  minkowski            4  4   uniform  0.465278
# 496           2  euclidean            3  1   uniform  0.465278
# 498           2  euclidean            3  2   uniform  0.465278
# 661           2  manhattan            3  3  distance  0.465278
# 500           2  euclidean            3  3   uniform  0.465278
# 663           2  manhattan            3  4  distance  0.465278
# 659           2  manhattan            3  2  distance  0.465278
# 449           1  minkowski           17  1  distance  0.465278
# 1782          4  minkowski            3  4   uniform  0.465278
# 1619          4  manhattan            3  2  distance  0.465278
# 1617          4  manhattan            3  1  distance  0.465278
# 177           1  manhattan            3  1  distance  0.465278
# 181           1  manhattan            3  3  distance  0.465278
# 183           1  manhattan            3  4  distance  0.465278
# 1729          4  manhattan           17  1  distance  0.465278
# 1731          4  manhattan           17  2  distance  0.465278
# 22            1  euclidean            3  4   uniform  0.465278
# 1733          4  manhattan           17  3  distance  0.465278
# 1735          4  manhattan           17  4  distance  0.465278
# 20            1  euclidean            3  3   uniform  0.465278
# 18            1  euclidean            3  2   uniform  0.465278
# 1777          4  minkowski            3  1  distance  0.465278
# 179           1  manhattan            3  2  distance  0.465278
# 16            1  euclidean            3  1   uniform  0.465278
# 976           3  euclidean            3  1   uniform  0.465278
# 1621          4  manhattan            3  3  distance  0.465278
# 1623          4  manhattan            3  4  distance  0.465278
# 1143          3  manhattan            3  4  distance  0.465278
# 1137          3  manhattan            3  1  distance  0.465278
# 289           1  manhattan           17  1  distance  0.465278
# 1141          3  manhattan            3  3  distance  0.465278
# 291           1  manhattan           17  2  distance  0.465278
# 978           3  euclidean            3  2   uniform  0.465278
# 1297          3  minkowski            3  1  distance  0.465278
# 1889          4  minkowski           17  1  distance  0.465278
# 980           3  euclidean            3  3   uniform  0.465278
# 293           1  manhattan           17  3  distance  0.465278
# 350           1  minkowski            4  4   uniform  0.465278
# 295           1  manhattan           17  4  distance  0.465278
# 830           2  minkowski            4  4   uniform  0.465278
# 982           3  euclidean            3  4   uniform  0.465278
# 1298          3  minkowski            3  2   uniform  0.465278
# 1139          3  manhattan            3  2  distance  0.465278
# 338           1  minkowski            3  2   uniform  0.465278
# 337           1  minkowski            3  1  distance  0.465278
# 817           2  minkowski            3  1  distance  0.465278
# 818           2  minkowski            3  2   uniform  0.465278
# 1780          4  minkowski            3  3   uniform  0.465278
# 397           1  minkowski           10  3  distance  0.465278
# 957           2  minkowski           20  3  distance  0.462963
# 1437          3  minkowski           20  3  distance  0.462963
# 769           2  manhattan           17  1  distance  0.462963
# 1755          4  manhattan           20  2  distance  0.462963
# 1409          3  minkowski           17  1  distance  0.462963
# 174           1  manhattan            2  4   uniform  0.462963
# 773           2  manhattan           17  3  distance  0.462963
# 315           1  manhattan           20  2  distance  0.462963
# 313           1  manhattan           20  1  distance  0.462963
# 168           1  manhattan            2  1   uniform  0.462963
# 793           2  manhattan           20  1  distance  0.462963
# 1759          4  manhattan           20  4  distance  0.462963
# 473           1  minkowski           20  1  distance  0.462963
# 172           1  manhattan            2  3   uniform  0.462963
# 319           1  manhattan           20  4  distance  0.462963
# 1277          3  manhattan           20  3  distance  0.462963
# 1279          3  manhattan           20  4  distance  0.462963
# 953           2  minkowski           20  1  distance  0.462963
# 1273          3  manhattan           20  1  distance  0.462963
# 795           2  manhattan           20  2  distance  0.462963
# 170           1  manhattan            2  2   uniform  0.462963
# 771           2  manhattan           17  2  distance  0.462963
# 317           1  manhattan           20  3  distance  0.462963
# 1433          3  minkowski           20  1  distance  0.462963
# 1753          4  manhattan           20  1  distance  0.462963
# 342           1  minkowski            3  4   uniform  0.462963
# 1249          3  manhattan           17  1  distance  0.462963
# 1757          4  manhattan           20  3  distance  0.462963
# 1302          3  minkowski            3  4   uniform  0.462963
# 328           1  minkowski            2  1   uniform  0.462963
# 797           2  manhattan           20  3  distance  0.462963
# 1913          4  minkowski           20  1  distance  0.462963
# 1253          3  manhattan           17  3  distance  0.462963
# 1251          3  manhattan           17  2  distance  0.462963
# 1275          3  manhattan           20  2  distance  0.462963
# 1255          3  manhattan           17  4  distance  0.462963
# 1790          4  minkowski            4  4   uniform  0.462963
# 929           2  minkowski           17  1  distance  0.462963
# 799           2  manhattan           20  4  distance  0.462963
# 822           2  minkowski            3  4   uniform  0.462963
# 775           2  manhattan           17  4  distance  0.462963
# 1321          3  minkowski            6  1  distance  0.462963
# 1645          4  manhattan            6  3  distance  0.462963
# 1747          4  manhattan           19  2  distance  0.462963
# 1745          4  manhattan           19  1  distance  0.462963
# 1751          4  manhattan           19  4  distance  0.462963
# 1647          4  manhattan            6  4  distance  0.462963
# 465           1  minkowski           19  1  distance  0.462963
# 305           1  manhattan           19  1  distance  0.462963
# 307           1  manhattan           19  2  distance  0.462963
# 340           1  minkowski            3  3   uniform  0.462963
# 1749          4  manhattan           19  3  distance  0.462963
# 203           1  manhattan            6  2  distance  0.462963
# 309           1  manhattan           19  3  distance  0.462963
# 311           1  manhattan           19  4  distance  0.462963
# 207           1  manhattan            6  4  distance  0.462963
# 1643          4  manhattan            6  2  distance  0.462963
# 1801          4  minkowski            6  1  distance  0.462963
# 361           1  minkowski            6  1  distance  0.462963
# 787           2  manhattan           19  2  distance  0.462963
# 201           1  manhattan            6  1  distance  0.462963
# 785           2  manhattan           19  1  distance  0.462963
# 1267          3  manhattan           19  2  distance  0.462963
# 1161          3  manhattan            6  1  distance  0.462963
# 841           2  minkowski            6  1  distance  0.462963
# 789           2  manhattan           19  3  distance  0.462963
# 205           1  manhattan            6  3  distance  0.462963
# 1269          3  manhattan           19  3  distance  0.462963
# 1300          3  minkowski            3  3   uniform  0.462963
# 1163          3  manhattan            6  2  distance  0.462963
# 945           2  minkowski           19  1  distance  0.462963
# 820           2  minkowski            3  3   uniform  0.462963
# 1167          3  manhattan            6  4  distance  0.462963
# 1641          4  manhattan            6  1  distance  0.462963
# 1165          3  manhattan            6  3  distance  0.462963
# 1265          3  manhattan           19  1  distance  0.462963
# 1905          4  minkowski           19  1  distance  0.462963
# 791           2  manhattan           19  4  distance  0.462963
# 687           2  manhattan            6  4  distance  0.462963
# 685           2  manhattan            6  3  distance  0.462963
# 1425          3  minkowski           19  1  distance  0.462963
# 683           2  manhattan            6  2  distance  0.462963
# 1271          3  manhattan           19  4  distance  0.462963
# 681           2  manhattan            6  1  distance  0.462963
# 1153          3  manhattan            5  1  distance  0.460648
# 193           1  manhattan            5  1  distance  0.460648
# 1155          3  manhattan            5  2  distance  0.460648
# 195           1  manhattan            5  2  distance  0.460648
# 1157          3  manhattan            5  3  distance  0.460648
# 197           1  manhattan            5  3  distance  0.460648
# 1313          3  minkowski            5  1  distance  0.460648
# 353           1  minkowski            5  1  distance  0.460648
# 1793          4  minkowski            5  1  distance  0.460648
# 1639          4  manhattan            5  4  distance  0.460648
# 1637          4  manhattan            5  3  distance  0.460648
# 833           2  minkowski            5  1  distance  0.460648
# 673           2  manhattan            5  1  distance  0.460648
# 675           2  manhattan            5  2  distance  0.460648
# 677           2  manhattan            5  3  distance  0.460648
# 679           2  manhattan            5  4  distance  0.460648
# 1159          3  manhattan            5  4  distance  0.460648
# 1635          4  manhattan            5  2  distance  0.460648
# 1633          4  manhattan            5  1  distance  0.460648
# 199           1  manhattan            5  4  distance  0.460648
# 823           2  minkowski            3  4  distance  0.460648
# 1303          3  minkowski            3  4  distance  0.460648
# 1917          4  minkowski           20  3  distance  0.460648
# 457           1  minkowski           18  1  distance  0.460648
# 1299          3  minkowski            3  2  distance  0.460648
# 819           2  minkowski            3  2  distance  0.460648
# 23            1  euclidean            3  4  distance  0.460648
# 297           1  manhattan           18  1  distance  0.460648
# 499           2  euclidean            3  2  distance  0.460648
# 497           2  euclidean            3  1  distance  0.460648
# 977           3  euclidean            3  1  distance  0.460648
# ...
# 111   50                     ovo      2      rbf  0.490741
# 138   50                     ovr      2      rbf  0.490741
# 165  100                     ovo      2      rbf  0.490741
# 219  200                     ovo      2      rbf  0.490741
# 246  200                     ovr      2      rbf  0.490741
# 195  100                     ovr      3      rbf  0.488426
# 198  100                     ovr      4      rbf  0.488426
# 63    10                     ovo      4      rbf  0.488426
# 252  200                     ovr      4      rbf  0.488426
# 84    10                     ovr      2      rbf  0.488426
# 90    10                     ovr      4      rbf  0.488426
# 249  200                     ovr      3      rbf  0.488426
# 114   50                     ovo      3      rbf  0.488426
# 117   50                     ovo      4      rbf  0.488426
# 225  200                     ovo      4      rbf  0.488426
# 141   50                     ovr      3      rbf  0.488426
# 144   50                     ovr      4      rbf  0.488426
# 222  200                     ovo      3      rbf  0.488426
# 168  100                     ovo      3      rbf  0.488426
# 171  100                     ovo      4      rbf  0.488426
# 57    10                     ovo      2      rbf  0.488426
# 87    10                     ovr      3      rbf  0.486111
# 60    10                     ovo      3      rbf  0.486111
# 0      1                     ovo      1      rbf  0.486111
# 30     1                     ovr      2      rbf  0.486111
# 27     1                     ovr      1      rbf  0.486111
# 3      1                     ovo      2      rbf  0.486111
# 147   50                     ovr      5      rbf  0.486111
# 258  200                     ovr      6      rbf  0.486111
# 69    10                     ovo      6      rbf  0.486111
# 231  200                     ovo      6      rbf  0.486111
# 228  200                     ovo      5      rbf  0.486111
# 93    10                     ovr      5      rbf  0.486111
# 96    10                     ovr      6      rbf  0.486111
# 66    10                     ovo      5      rbf  0.486111
# 204  100                     ovr      6      rbf  0.486111
# 201  100                     ovr      5      rbf  0.486111
# 255  200                     ovr      5      rbf  0.486111
# 120   50                     ovo      5      rbf  0.486111
# 177  100                     ovo      6      rbf  0.486111
# 150   50                     ovr      6      rbf  0.486111
# 174  100                     ovo      5      rbf  0.486111
# 123   50                     ovo      6      rbf  0.486111
# 72    10                     ovo      7      rbf  0.483796
# 153   50                     ovr      7      rbf  0.483796
# 75    10                     ovo      8      rbf  0.483796
# 156   50                     ovr      8      rbf  0.483796
# 6      1                     ovo      3      rbf  0.483796
# 129   50                     ovo      8      rbf  0.483796
# 180  100                     ovo      7      rbf  0.483796
# 99    10                     ovr      7      rbf  0.483796
# 126   50                     ovo      7      rbf  0.483796
# 210  100                     ovr      8      rbf  0.483796
# 102   10                     ovr      8      rbf  0.483796
# 207  100                     ovr      7      rbf  0.483796
# 183  100                     ovo      8      rbf  0.483796
# 234  200                     ovo      7      rbf  0.483796
# 33     1                     ovr      3      rbf  0.483796
# 9      1                     ovo      4      rbf  0.483796
# 237  200                     ovo      8      rbf  0.483796
# 264  200                     ovr      8      rbf  0.483796
# 261  200                     ovr      7      rbf  0.483796
# 36     1                     ovr      4      rbf  0.483796
# 15     1                     ovo      6      rbf  0.481481
# 39     1                     ovr      5      rbf  0.481481
# 42     1                     ovr      6      rbf  0.481481
# 12     1                     ovo      5      rbf  0.481481
# 267  200                     ovr      9      rbf  0.481481
# 159   50                     ovr      9      rbf  0.481481
# 132   50                     ovo      9      rbf  0.481481
# 78    10                     ovo      9      rbf  0.481481
# 240  200                     ovo      9      rbf  0.481481
# 213  100                     ovr      9      rbf  0.481481
# 186  100                     ovo      9      rbf  0.481481
# 105   10                     ovr      9      rbf  0.481481
# 24     1                     ovo      9      rbf  0.479167
# 51     1                     ovr      9      rbf  0.479167
# 45     1                     ovr      7      rbf  0.479167
# 48     1                     ovr      8      rbf  0.479167
# 21     1                     ovo      8      rbf  0.479167
# 18     1                     ovo      7      rbf  0.479167
# 106   10                     ovr      9   linear  0.437500
# 103   10                     ovr      8   linear  0.437500
# 100   10                     ovr      7   linear  0.437500
# 97    10                     ovr      6   linear  0.437500
# 55    10                     ovo      1   linear  0.437500
# 67    10                     ovo      5   linear  0.437500
# 94    10                     ovr      5   linear  0.437500
# 73    10                     ovo      7   linear  0.437500
# 82    10                     ovr      1   linear  0.437500
# 79    10                     ovo      9   linear  0.437500
# 76    10                     ovo      8   linear  0.437500
# 61    10                     ovo      3   linear  0.437500
# 58    10                     ovo      2   linear  0.437500
# 88    10                     ovr      3   linear  0.437500
# 91    10                     ovr      4   linear  0.437500
# 70    10                     ovo      6   linear  0.437500
# 64    10                     ovo      4   linear  0.437500
# 85    10                     ovr      2   linear  0.437500
# 238  200                     ovo      8   linear  0.430556
# 265  200                     ovr      8   linear  0.430556
# 232  200                     ovo      6   linear  0.430556
# 229  200                     ovo      5   linear  0.430556
# 262  200                     ovr      7   linear  0.430556
# 226  200                     ovo      4   linear  0.430556
# 259  200                     ovr      6   linear  0.430556
# 244  200                     ovr      1   linear  0.430556
# 268  200                     ovr      9   linear  0.430556
# 253  200                     ovr      4   linear  0.430556
# 217  200                     ovo      1   linear  0.430556
# 256  200                     ovr      5   linear  0.430556
# 235  200                     ovo      7   linear  0.430556
# 220  200                     ovo      2   linear  0.430556
# 223  200                     ovo      3   linear  0.430556
# 250  200                     ovr      3   linear  0.430556
# 247  200                     ovr      2   linear  0.430556
# 241  200                     ovo      9   linear  0.430556
# 214  100                     ovr      9   linear  0.425926
# 154   50                     ovr      7   linear  0.425926
# 208  100                     ovr      7   linear  0.425926
# 157   50                     ovr      8   linear  0.425926
# 148   50                     ovr      5   linear  0.425926
# 211  100                     ovr      8   linear  0.425926
# 160   50                     ovr      9   linear  0.425926
# 163  100                     ovo      1   linear  0.425926
# 166  100                     ovo      2   linear  0.425926
# 190  100                     ovr      1   linear  0.425926
# 169  100                     ovo      3   linear  0.425926
# 172  100                     ovo      4   linear  0.425926
# 187  100                     ovo      9   linear  0.425926
# 175  100                     ovo      5   linear  0.425926
# 205  100                     ovr      6   linear  0.425926
# 178  100                     ovo      6   linear  0.425926
# 202  100                     ovr      5   linear  0.425926
# 181  100                     ovo      7   linear  0.425926
# 199  100                     ovr      4   linear  0.425926
# 196  100                     ovr      3   linear  0.425926
# 193  100                     ovr      2   linear  0.425926
# 184  100                     ovo      8   linear  0.425926
# 151   50                     ovr      6   linear  0.425926
# 124   50                     ovo      6   linear  0.425926
# 112   50                     ovo      2   linear  0.425926
# 130   50                     ovo      8   linear  0.425926
# 145   50                     ovr      4   linear  0.425926
# 127   50                     ovo      7   linear  0.425926
# 121   50                     ovo      5   linear  0.425926
# 142   50                     ovr      3   linear  0.425926
# 133   50                     ovo      9   linear  0.425926
# 136   50                     ovr      1   linear  0.425926
# 118   50                     ovo      4   linear  0.425926
# 139   50                     ovr      2   linear  0.425926
# 115   50                     ovo      3   linear  0.425926
# 109   50                     ovo      1   linear  0.425926
# 43     1                     ovr      6   linear  0.421296
# 13     1                     ovo      5   linear  0.421296
# 31     1                     ovr      2   linear  0.421296
# 40     1                     ovr      5   linear  0.421296
# 1      1                     ovo      1   linear  0.421296
# 52     1                     ovr      9   linear  0.421296
# 4      1                     ovo      2   linear  0.421296
# 22     1                     ovo      8   linear  0.421296
# 16     1                     ovo      6   linear  0.421296
# 49     1                     ovr      8   linear  0.421296
# 37     1                     ovr      4   linear  0.421296
# 28     1                     ovr      1   linear  0.421296
# 19     1                     ovo      7   linear  0.421296
# 25     1                     ovo      9   linear  0.421296
# 7      1                     ovo      3   linear  0.421296
# 46     1                     ovr      7   linear  0.421296
# 34     1                     ovr      3   linear  0.421296
# 10     1                     ovo      4   linear  0.421296
# 41     1                     ovr      5  sigmoid  0.386574
# 14     1                     ovo      5  sigmoid  0.386574
# 101   10                     ovr      7  sigmoid  0.386574
# 23     1                     ovo      8  sigmoid  0.386574
# 50     1                     ovr      8  sigmoid  0.386574
# 74    10                     ovo      7  sigmoid  0.386574
# 5      1                     ovo      2  sigmoid  0.384259
# 32     1                     ovr      2  sigmoid  0.384259
# 134   50                     ovo      9  sigmoid  0.381944
# 161   50                     ovr      9  sigmoid  0.381944
# 26     1                     ovo      9  sigmoid  0.379630
# 53     1                     ovr      9  sigmoid  0.379630
# 29     1                     ovr      1  sigmoid  0.379630
# 2      1                     ovo      1  sigmoid  0.379630
# 8      1                     ovo      3  sigmoid  0.377315
# 35     1                     ovr      3  sigmoid  0.377315
# 17     1                     ovo      6  sigmoid  0.377315
# 44     1                     ovr      6  sigmoid  0.377315
# 143   50                     ovr      3  sigmoid  0.375000
# 116   50                     ovo      3  sigmoid  0.375000
# 47     1                     ovr      7  sigmoid  0.372685
# 224  200                     ovo      3  sigmoid  0.372685
# 206  100                     ovr      6  sigmoid  0.372685
# 152   50                     ovr      6  sigmoid  0.372685
# 125   50                     ovo      6  sigmoid  0.372685
# 20     1                     ovo      7  sigmoid  0.372685
# 260  200                     ovr      6  sigmoid  0.372685
# 197  100                     ovr      3  sigmoid  0.372685
# 170  100                     ovo      3  sigmoid  0.372685
# 233  200                     ovo      6  sigmoid  0.372685
# 179  100                     ovo      6  sigmoid  0.372685
# 251  200                     ovr      3  sigmoid  0.372685
# 107   10                     ovr      9  sigmoid  0.370370
# 104   10                     ovr      8  sigmoid  0.370370
# 77    10                     ovo      8  sigmoid  0.370370
# 80    10                     ovo      9  sigmoid  0.370370
# 11     1                     ovo      4  sigmoid  0.370370
# 38     1                     ovr      4  sigmoid  0.370370
# 242  200                     ovo      9  sigmoid  0.368056
# 71    10                     ovo      6  sigmoid  0.368056
# 269  200                     ovr      9  sigmoid  0.368056
# 188  100                     ovo      9  sigmoid  0.368056
# 158   50                     ovr      8  sigmoid  0.368056
# 215  100                     ovr      9  sigmoid  0.368056
# 131   50                     ovo      8  sigmoid  0.368056
# 98    10                     ovr      6  sigmoid  0.368056
# 254  200                     ovr      4  sigmoid  0.368056
# 173  100                     ovo      4  sigmoid  0.368056
# 62    10                     ovo      3  sigmoid  0.368056
# 89    10                     ovr      3  sigmoid  0.368056
# 200  100                     ovr      4  sigmoid  0.368056
# 227  200                     ovo      4  sigmoid  0.368056
# 110   50                     ovo      1  sigmoid  0.363426
# 137   50                     ovr      1  sigmoid  0.363426
# 164  100                     ovo      1  sigmoid  0.363426
# 245  200                     ovr      1  sigmoid  0.363426
# 191  100                     ovr      1  sigmoid  0.363426
# 218  200                     ovo      1  sigmoid  0.363426
# 119   50                     ovo      4  sigmoid  0.361111
# 92    10                     ovr      4  sigmoid  0.361111
# 65    10                     ovo      4  sigmoid  0.361111
# 146   50                     ovr      4  sigmoid  0.361111
# 59    10                     ovo      2  sigmoid  0.358796
# 95    10                     ovr      5  sigmoid  0.358796
# 68    10                     ovo      5  sigmoid  0.358796
# 86    10                     ovr      2  sigmoid  0.358796
# 239  200                     ovo      8  sigmoid  0.356481
# 212  100                     ovr      8  sigmoid  0.356481
# 266  200                     ovr      8  sigmoid  0.356481
# 185  100                     ovo      8  sigmoid  0.356481
# 263  200                     ovr      7  sigmoid  0.354167
# 209  100                     ovr      7  sigmoid  0.354167
# 236  200                     ovo      7  sigmoid  0.354167
# 155   50                     ovr      7  sigmoid  0.354167
# 182  100                     ovo      7  sigmoid  0.354167
# 128   50                     ovo      7  sigmoid  0.354167
# 176  100                     ovo      5  sigmoid  0.354167
# 230  200                     ovo      5  sigmoid  0.354167
# 257  200                     ovr      5  sigmoid  0.354167
# 203  100                     ovr      5  sigmoid  0.354167
# 83    10                     ovr      1  sigmoid  0.351852
# 56    10                     ovo      1  sigmoid  0.351852
# 194  100                     ovr      2  sigmoid  0.349537
# 140   50                     ovr      2  sigmoid  0.349537
# 167  100                     ovo      2  sigmoid  0.349537
# 149   50                     ovr      5  sigmoid  0.349537
# 122   50                     ovo      5  sigmoid  0.349537
# 113   50                     ovo      2  sigmoid  0.349537
# 221  200                     ovo      2  sigmoid  0.344907
# 248  200                     ovr      2  sigmoid  0.344907>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-263240bbee7e> in <module>
# ----> 1 main()
#
# <ipython-input-2-62736f404ff3> in main()
#      42     data = data_loader.load_real_dataset(remove_multicollinearity=False, only_proposed=True)
#      43     # determine which model we are using.
# ---> 44     model = LMNN(data, normalize=True)
#      45     model.find_hyperparams()
#      46     #model.train()
#
# NameError: name 'LMNN' is not defined

# %%
# printing pca - after removing all 0 variance metrics and correlation 0.9 and pca
def describe_data():
    data = data_loader.load_real_dataset(sqaured=False, remove_multicollinearity=False)
    data_xy = pre_training_analysis_tools.join_dataxy(data['train_x'], data['train_y'])
    output_xy = pre_training_analysis_tools.remove_collinear_features(data_xy, 'maven_reuse', 0.90, 'True')
    output_x = pre_training_analysis_tools.split_dataxy(output_xy)
    output = pre_training_analysis_tools.variance_threshold(output_x,data['train_y'])
    output = pre_training_analysis_tools.split_dataxy(output)
    pre_training_analysis_tools.pca(output)
    
    pre_training_analysis_tools.all_model_score(data['train_x'],data['train_y'],data['test_x'],data['test_y'])

# %%
describe_data()
# Out:
# publicMethodsQty_stdev | lcom_average | 0.93
# publicMethodsQty_stdev: 0.079
# lcom_average: 0.083
# dropped: publicMethodsQty_stdev
# -----------------------------------------------------------------------------
# staticFieldsQty_sum | publicMethodsQty_sum | 0.98
# staticFieldsQty_sum: 0.129
# publicMethodsQty_sum: 0.126
# dropped: publicMethodsQty_sum
# -----------------------------------------------------------------------------
# staticFieldsQty_max | staticFieldsQty_stdev | 0.9
# staticFieldsQty_max: 0.028
# staticFieldsQty_stdev: 0.024
# dropped: staticFieldsQty_stdev
# -----------------------------------------------------------------------------
# publicFieldsQty_sum | parenthesizedExpsQty_sum | 0.9
# publicFieldsQty_sum: 0.079
# parenthesizedExpsQty_sum: 0.106
# dropped: publicFieldsQty_sum
# -----------------------------------------------------------------------------
# publicFieldsQty_max | publicFieldsQty_stdev | 0.93
# publicFieldsQty_max: 0.005
# publicFieldsQty_stdev: -0.035
# dropped: publicFieldsQty_max
# -----------------------------------------------------------------------------
# lambdasQty_stdev | lambdasQty_average | 0.93
# lambdasQty_stdev: -0.023
# lambdasQty_average: 0.055
# dropped: lambdasQty_stdev
# -----------------------------------------------------------------------------
# logStatementsQty_sum | staticFieldsQty_sum | 0.9
# logStatementsQty_sum: 0.099
# staticFieldsQty_sum: 0.129
# dropped: logStatementsQty_sum
# -----------------------------------------------------------------------------
# tryCatchQty_sum | staticFieldsQty_sum | 0.92
# tryCatchQty_sum: 0.043
# staticFieldsQty_sum: 0.129
# dropped: tryCatchQty_sum
# -----------------------------------------------------------------------------
# maxNestedBlocksQty_sum | parenthesizedExpsQty_sum | 0.9
# maxNestedBlocksQty_sum: 0.098
# parenthesizedExpsQty_sum: 0.106
# dropped: maxNestedBlocksQty_sum
# -----------------------------------------------------------------------------
# wmc_sum | parenthesizedExpsQty_sum | 0.91
# wmc_sum: 0.108
# parenthesizedExpsQty_sum: 0.106
# dropped: parenthesizedExpsQty_sum
# -----------------------------------------------------------------------------
# wmc_sum | staticFieldsQty_sum | 0.97
# wmc_sum: 0.108
# staticFieldsQty_sum: 0.129
# dropped: wmc_sum
# -----------------------------------------------------------------------------
# rfc_sum | staticFieldsQty_sum | 0.97
# rfc_sum: 0.122
# staticFieldsQty_sum: 0.129
# dropped: rfc_sum
# -----------------------------------------------------------------------------
# privateMethodsQty_sum | staticFieldsQty_sum | 0.93
# privateMethodsQty_sum: 0.155
# staticFieldsQty_sum: 0.129
# dropped: staticFieldsQty_sum
# -----------------------------------------------------------------------------
# visibleFieldsQty_max | visibleFieldsQty_stdev | 0.98
# visibleFieldsQty_max: 0.019
# visibleFieldsQty_stdev: 0.033
# dropped: visibleFieldsQty_max
# -----------------------------------------------------------------------------
# uniqueWordsQty_sum | privateMethodsQty_sum | 0.93
# uniqueWordsQty_sum: 0.093
# privateMethodsQty_sum: 0.155
# dropped: uniqueWordsQty_sum
# -----------------------------------------------------------------------------
# stringLiteralsQty_sum | privateMethodsQty_sum | 0.92
# stringLiteralsQty_sum: 0.088
# privateMethodsQty_sum: 0.155
# dropped: stringLiteralsQty_sum
# -----------------------------------------------------------------------------
# returnQty_sum | mathOperationsQty_sum | 0.92
# returnQty_sum: 0.139
# mathOperationsQty_sum: 0.057
# dropped: mathOperationsQty_sum
# -----------------------------------------------------------------------------
# modifiers_sum | privateMethodsQty_sum | 0.91
# modifiers_sum: 0.067
# privateMethodsQty_sum: 0.155
# dropped: modifiers_sum
# -----------------------------------------------------------------------------
# lcc_sum | privateMethodsQty_sum | 0.92
# lcc_sum: -0.102
# privateMethodsQty_sum: 0.155
# dropped: lcc_sum
# -----------------------------------------------------------------------------
# abstractMethodsQty_sum | privateMethodsQty_sum | 0.94
# abstractMethodsQty_sum: 0.117
# privateMethodsQty_sum: 0.155
# dropped: abstractMethodsQty_sum
# -----------------------------------------------------------------------------
# abstractMethodsQty_average | publicMethodsQty_average | 0.97
# abstractMethodsQty_average: 0.067
# publicMethodsQty_average: 0.05
# dropped: publicMethodsQty_average
# -----------------------------------------------------------------------------
# abstractMethodsQty_stdev | lcom_average | 0.91
# abstractMethodsQty_stdev: 0.084
# lcom_average: 0.083
# dropped: lcom_average
# -----------------------------------------------------------------------------
# abstractMethodsQty_median | publicMethodsQty_median | 0.93
# abstractMethodsQty_median: -0.007
# publicMethodsQty_median: -0.033
# dropped: abstractMethodsQty_median
# -----------------------------------------------------------------------------
# abstractMethodsQty_max | publicMethodsQty_max | 0.99
# abstractMethodsQty_max: 0.106
# publicMethodsQty_max: 0.08
# dropped: publicMethodsQty_max
# -----------------------------------------------------------------------------
# protectedFieldsQty_sum | privateMethodsQty_sum | 0.95
# protectedFieldsQty_sum: 0.133
# privateMethodsQty_sum: 0.155
# dropped: protectedFieldsQty_sum
# -----------------------------------------------------------------------------
# staticMethodsQty_sum | returnQty_sum | 0.91
# staticMethodsQty_sum: 0.12
# returnQty_sum: 0.139
# dropped: staticMethodsQty_sum
# -----------------------------------------------------------------------------
# staticMethodsQty_median | logStatementsQty_median | 0.9
# staticMethodsQty_median: -0.024
# logStatementsQty_median: nan
# dropped: logStatementsQty_median
# -----------------------------------------------------------------------------
# assignmentsQty_sum | privateMethodsQty_sum | 0.92
# assignmentsQty_sum: 0.097
# privateMethodsQty_sum: 0.155
# dropped: assignmentsQty_sum
# -----------------------------------------------------------------------------
# assignmentsQty_average | wmc_average | 0.92
# assignmentsQty_average: 0.102
# wmc_average: 0.149
# dropped: assignmentsQty_average
# -----------------------------------------------------------------------------
# finalFieldsQty_sum | privateMethodsQty_sum | 0.96
# finalFieldsQty_sum: 0.092
# privateMethodsQty_sum: 0.155
# dropped: finalFieldsQty_sum
# -----------------------------------------------------------------------------
# finalFieldsQty_stdev | publicFieldsQty_stdev | 0.98
# finalFieldsQty_stdev: -0.03
# publicFieldsQty_stdev: -0.035
# dropped: finalFieldsQty_stdev
# -----------------------------------------------------------------------------
# finalFieldsQty_max | publicFieldsQty_stdev | 0.94
# finalFieldsQty_max: 0.009
# publicFieldsQty_stdev: -0.035
# dropped: finalFieldsQty_max
# -----------------------------------------------------------------------------
# dit_sum | privateMethodsQty_sum | 0.94
# dit_sum: 0.124
# privateMethodsQty_sum: 0.155
# dropped: dit_sum
# -----------------------------------------------------------------------------
# totalMethodsQty_sum | privateMethodsQty_sum | 0.95
# totalMethodsQty_sum: 0.12
# privateMethodsQty_sum: 0.155
# dropped: totalMethodsQty_sum
# -----------------------------------------------------------------------------
# totalMethodsQty_average | abstractMethodsQty_average | 0.98
# totalMethodsQty_average: 0.104
# abstractMethodsQty_average: 0.067
# dropped: abstractMethodsQty_average
# -----------------------------------------------------------------------------
# totalMethodsQty_stdev | abstractMethodsQty_stdev | 0.99
# totalMethodsQty_stdev: 0.101
# abstractMethodsQty_stdev: 0.084
# dropped: abstractMethodsQty_stdev
# -----------------------------------------------------------------------------
# totalMethodsQty_max | abstractMethodsQty_max | 1.0
# totalMethodsQty_max: 0.102
# abstractMethodsQty_max: 0.106
# dropped: totalMethodsQty_max
# -----------------------------------------------------------------------------
# defaultFieldsQty_stdev | defaultFieldsQty_average | 0.9
# defaultFieldsQty_stdev: 0.109
# defaultFieldsQty_average: 0.055
# dropped: defaultFieldsQty_average
# -----------------------------------------------------------------------------
# loc_sum | privateMethodsQty_sum | 0.94
# loc_sum: 0.127
# privateMethodsQty_sum: 0.155
# dropped: loc_sum
# -----------------------------------------------------------------------------
# loc_average | wmc_average | 0.93
# loc_average: 0.171
# wmc_average: 0.149
# dropped: wmc_average
# -----------------------------------------------------------------------------
# loc_median | wmc_median | 0.97
# loc_median: 0.165
# wmc_median: 0.142
# dropped: wmc_median
# -----------------------------------------------------------------------------
# loc_median | assignmentsQty_median | 0.92
# loc_median: 0.165
# assignmentsQty_median: 0.115
# dropped: assignmentsQty_median
# -----------------------------------------------------------------------------
# cbo_sum | privateMethodsQty_sum | 0.96
# cbo_sum: 0.126
# privateMethodsQty_sum: 0.155
# dropped: cbo_sum
# -----------------------------------------------------------------------------
# variablesQty_sum | privateMethodsQty_sum | 0.94
# variablesQty_sum: 0.096
# privateMethodsQty_sum: 0.155
# dropped: variablesQty_sum
# -----------------------------------------------------------------------------
# variablesQty_median | loc_median | 0.92
# variablesQty_median: 0.132
# loc_median: 0.165
# dropped: variablesQty_median
# -----------------------------------------------------------------------------
# variablesQty_max | staticFieldsQty_max | 0.95
# variablesQty_max: -0.002
# staticFieldsQty_max: 0.028
# dropped: variablesQty_max
# -----------------------------------------------------------------------------
# protectedMethodsQty_sum | privateMethodsQty_sum | 0.91
# protectedMethodsQty_sum: 0.1
# privateMethodsQty_sum: 0.155
# dropped: protectedMethodsQty_sum
# -----------------------------------------------------------------------------
# tcc_sum | privateMethodsQty_sum | 0.92
# tcc_sum: -0.102
# privateMethodsQty_sum: 0.155
# dropped: tcc_sum
# -----------------------------------------------------------------------------
# tcc_average | lcc_average | 1.0
# tcc_average: 0.031
# lcc_average: 0.031
# dropped: lcc_average
# -----------------------------------------------------------------------------
# tcc_stdev | lcc_stdev | 1.0
# tcc_stdev: -0.008
# lcc_stdev: -0.008
# dropped: lcc_stdev
# -----------------------------------------------------------------------------
# tcc_median | lcc_median | 1.0
# tcc_median: -0.037
# lcc_median: -0.037
# dropped: lcc_median
# -----------------------------------------------------------------------------
# tcc_min | lcc_min | 1.0
# tcc_min: -0.058
# lcc_min: -0.058
# dropped: lcc_min
# -----------------------------------------------------------------------------
# privateFieldsQty_stdev | staticFieldsQty_max | 0.94
# privateFieldsQty_stdev: 0.014
# staticFieldsQty_max: 0.028
# dropped: privateFieldsQty_stdev
# -----------------------------------------------------------------------------
# privateFieldsQty_max | staticFieldsQty_max | 0.95
# privateFieldsQty_max: 0.026
# staticFieldsQty_max: 0.028
# dropped: privateFieldsQty_max
# -----------------------------------------------------------------------------
# finalMethodsQty_median | modifiers_median | 1.0
# finalMethodsQty_median: -0.108
# modifiers_median: -0.109
# dropped: finalMethodsQty_median
# -----------------------------------------------------------------------------
# innerClassesQty_sum | privateMethodsQty_sum | 0.95
# innerClassesQty_sum: 0.102
# privateMethodsQty_sum: 0.155
# dropped: innerClassesQty_sum
# -----------------------------------------------------------------------------
# comparisonsQty_sum | cbo_max | 0.91
# comparisonsQty_sum: 0.096
# cbo_max: 0.052
# dropped: cbo_max
# -----------------------------------------------------------------------------
# dropped columns:
# ['publicMethodsQty_sum', 'wmc_median', 'totalMethodsQty_sum', 'abstractMethodsQty_sum', 'abstractMethodsQty_median', 'totalMethodsQty_max', 'cbo_sum', 'loc_sum', 'wmc_sum', 'parenthesizedExpsQty_sum', 'wmc_average', 'variablesQty_max', 'lcc_stdev', 'publicMethodsQty_stdev', 'finalMethodsQty_median', 'assignmentsQty_sum', 'tryCatchQty_sum', 'tcc_sum', 'lcc_min', 'privateFieldsQty_max', 'assignmentsQty_average', 'stringLiteralsQty_sum', 'lcc_sum', 'protectedFieldsQty_sum', 'lcc_average', 'variablesQty_median', 'visibleFieldsQty_max', 'staticFieldsQty_sum', 'publicMethodsQty_average', 'lcc_median', 'variablesQty_sum', 'cbo_max', 'publicFieldsQty_sum', 'logStatementsQty_median', 'abstractMethodsQty_stdev', 'publicFieldsQty_max', 'protectedMethodsQty_sum', 'lcom_average', 'staticMethodsQty_sum', 'uniqueWordsQty_sum', 'finalFieldsQty_sum', 'rfc_sum', 'publicMethodsQty_max', 'mathOperationsQty_sum', 'finalFieldsQty_max', 'finalFieldsQty_stdev', 'lambdasQty_stdev', 'maxNestedBlocksQty_sum', 'dit_sum', 'staticFieldsQty_stdev', 'privateFieldsQty_stdev', 'assignmentsQty_median', 'abstractMethodsQty_average', 'logStatementsQty_sum', 'modifiers_sum', 'defaultFieldsQty_average', 'innerClassesQty_sum']
# -----------------------------------------------------------------------------
# used columns:
# ['synchronizedMethodsQty_sum', 'synchronizedMethodsQty_average', 'synchronizedMethodsQty_stdev', 'synchronizedMethodsQty_median', 'synchronizedMethodsQty_min', 'synchronizedMethodsQty_max', 'parenthesizedExpsQty_average', 'parenthesizedExpsQty_stdev', 'parenthesizedExpsQty_median', 'parenthesizedExpsQty_min', 'parenthesizedExpsQty_max', 'lcom_sum', 'lcom_stdev', 'lcom_median', 'lcom_min', 'lcom_max', 'publicMethodsQty_median', 'publicMethodsQty_min', 'staticFieldsQty_average', 'staticFieldsQty_median', 'staticFieldsQty_min', 'staticFieldsQty_max', 'publicFieldsQty_average', 'publicFieldsQty_stdev', 'publicFieldsQty_median', 'publicFieldsQty_min', 'lambdasQty_sum', 'lambdasQty_average', 'lambdasQty_median', 'lambdasQty_min', 'lambdasQty_max', 'logStatementsQty_average', 'logStatementsQty_stdev', 'logStatementsQty_min', 'logStatementsQty_max', 'tryCatchQty_average', 'tryCatchQty_stdev', 'tryCatchQty_median', 'tryCatchQty_min', 'tryCatchQty_max', 'maxNestedBlocksQty_average', 'maxNestedBlocksQty_stdev', 'maxNestedBlocksQty_median', 'maxNestedBlocksQty_min', 'maxNestedBlocksQty_max', 'wmc_stdev', 'wmc_min', 'wmc_max', 'rfc_average', 'rfc_stdev', 'rfc_median', 'rfc_min', 'rfc_max', 'privateMethodsQty_sum', 'privateMethodsQty_average', 'privateMethodsQty_stdev', 'privateMethodsQty_median', 'privateMethodsQty_min', 'privateMethodsQty_max', 'defaultMethodsQty_sum', 'defaultMethodsQty_average', 'defaultMethodsQty_stdev', 'defaultMethodsQty_median', 'defaultMethodsQty_min', 'defaultMethodsQty_max', 'nosi_sum', 'nosi_average', 'nosi_stdev', 'nosi_median', 'nosi_min', 'nosi_max', 'visibleFieldsQty_sum', 'visibleFieldsQty_average', 'visibleFieldsQty_stdev', 'visibleFieldsQty_median', 'visibleFieldsQty_min', 'uniqueWordsQty_average', 'uniqueWordsQty_stdev', 'uniqueWordsQty_median', 'uniqueWordsQty_min', 'uniqueWordsQty_max', 'synchronizedFieldsQty_sum', 'synchronizedFieldsQty_average', 'synchronizedFieldsQty_stdev', 'synchronizedFieldsQty_median', 'synchronizedFieldsQty_min', 'synchronizedFieldsQty_max', 'stringLiteralsQty_average', 'stringLiteralsQty_stdev', 'stringLiteralsQty_median', 'stringLiteralsQty_min', 'stringLiteralsQty_max', 'anonymousClassesQty_sum', 'anonymousClassesQty_average', 'anonymousClassesQty_stdev', 'anonymousClassesQty_median', 'anonymousClassesQty_min', 'anonymousClassesQty_max', 'mathOperationsQty_average', 'mathOperationsQty_stdev', 'mathOperationsQty_median', 'mathOperationsQty_min', 'mathOperationsQty_max', 'returnQty_sum', 'returnQty_average', 'returnQty_stdev', 'returnQty_median', 'returnQty_min', 'returnQty_max', 'modifiers_average', 'modifiers_stdev', 'modifiers_median', 'modifiers_min', 'modifiers_max', 'lcc_max', 'abstractMethodsQty_min', 'abstractMethodsQty_max', 'protectedFieldsQty_average', 'protectedFieldsQty_stdev', 'protectedFieldsQty_median', 'protectedFieldsQty_min', 'protectedFieldsQty_max', 'numbersQty_sum', 'numbersQty_average', 'numbersQty_stdev', 'numbersQty_median', 'numbersQty_min', 'numbersQty_max', 'staticMethodsQty_average', 'staticMethodsQty_stdev', 'staticMethodsQty_median', 'staticMethodsQty_min', 'staticMethodsQty_max', 'assignmentsQty_stdev', 'assignmentsQty_min', 'assignmentsQty_max', 'finalFieldsQty_average', 'finalFieldsQty_median', 'finalFieldsQty_min', 'dit_average', 'dit_stdev', 'dit_median', 'dit_min', 'dit_max', 'totalMethodsQty_average', 'totalMethodsQty_stdev', 'totalMethodsQty_median', 'totalMethodsQty_min', 'loopQty_sum', 'loopQty_average', 'loopQty_stdev', 'loopQty_median', 'loopQty_min', 'loopQty_max', 'defaultFieldsQty_sum', 'defaultFieldsQty_stdev', 'defaultFieldsQty_median', 'defaultFieldsQty_min', 'defaultFieldsQty_max', 'loc_average', 'loc_stdev', 'loc_median', 'loc_min', 'loc_max', 'totalFieldsQty_sum', 'totalFieldsQty_average', 'totalFieldsQty_stdev', 'totalFieldsQty_median', 'totalFieldsQty_min', 'totalFieldsQty_max', 'cbo_average', 'cbo_stdev', 'cbo_median', 'cbo_min', 'variablesQty_average', 'variablesQty_stdev', 'variablesQty_min', 'protectedMethodsQty_average ...
# Original feature shape: (319, 208)
# Transformed feature shape: (319, 152)
# [pca] >Processing dataframe..
# [pca] >The PCA reduction is performed to capture [95.0%] explained variance using the [152] columns of the input data.
# [pca] >Fitting using PCA..
# [pca] >Computing loadings and PCs..
# [pca] >Computing explained variance..
# [pca] >Number of components is [33] that covers the [95.00%] explained variance.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[5]
# [pca] >Outlier detection using SPE/DmodX with n_std=[2]
#         PC                         feature   loading  type
# 0      PC1       maxNestedBlocksQty_median  0.200954  best
# 1      PC2                         wmc_max  0.262686  best
# 2      PC3                         tcc_min  0.407690  best
# 3      PC4        parenthesizedExpsQty_max -0.256018  best
# 4      PC5                   modifiers_min -0.379790  best
# 5      PC6                 modifiers_stdev  0.387464  best
# 6      PC7                   modifiers_min -0.428141  best
# 7      PC8                      dit_median  0.295256  best
# 8      PC9            staticMethodsQty_max -0.266177  best
# 9     PC10            totalFieldsQty_stdev  0.260178  best
# 10    PC11            totalFieldsQty_stdev -0.285399  best
# 11    PC12         defaultMethodsQty_stdev  0.311019  best
# 12    PC13            staticMethodsQty_max -0.270613  best
# 13    PC14                   modifiers_min  0.261963  best
# 14    PC15                     cbo_average  0.285533  best
# 15    PC16       anonymousClassesQty_stdev -0.250017  best
# 16    PC17         stringLiteralsQty_stdev  0.271575  best
# 17    PC18              lambdasQty_average  0.301198  best
# 18    PC19           finalFieldsQty_median  0.265024  best
# 19    PC20                      dit_median -0.314060  best
# 20    PC21        defaultMethodsQty_median  0.375355  best
# 21    PC22        defaultMethodsQty_median  0.375654  best
# 22    PC23                   modifiers_max  0.276307  best
# 23    PC24           defaultMethodsQty_max  0.313498  best
# 24    PC25           finalFieldsQty_median -0.294123  best
# 25    PC26                      tcc_median -0.570903  best
# 26    PC27              totalFieldsQty_sum -0.286112  best
# 27    PC28                      dit_median -0.276871  best
# 28    PC29           stringLiteralsQty_max  0.334019  best
# 29    PC30                returnQty_median -0.329528  best
# 30    PC31       protectedMethodsQty_stdev  0.251281  best
# 31    PC32             innerClassesQty_max  0.270431  best
# 32    PC33                   returnQty_max  0.283745  best
# 33    PC34                returnQty_median -0.374127  best
# 34    PC35                     dit_average  0.283803  best
# 35    PC36      synchronizedMethodsQty_max -0.240084  best
# 36    PC37         innerClassesQty_average -0.299990  best
# 37    PC38                      dit_median -0.275931  best
# 38    PC39            staticMethodsQty_max  0.279903  best
# 39    PC40             innerClassesQty_max  0.298356  best
# 40    PC41       anonymousClassesQty_stdev  0.275472  best
# 41    PC42          maxNestedBlocksQty_max  0.308768  best
# 42    PC43           privateMethodsQty_max -0.289735  best
# 43    PC44           finalMethodsQty_stdev  0.279600  best
# 44    PC45              lambdasQty_average  0.341764  best
# 45    PC46           finalFieldsQty_median  0.237934  best
# 46    PC47       maxNestedBlocksQty_median -0.319506  best
# 47    PC48                     dit_average  0.284420  best
# 48    PC49       maxNestedBlocksQty_median -0.262249  best
# 49    PC50           publicFieldsQty_stdev  0.435691  best
# 50    PC51       defaultMethodsQty_average -0.227692  best
# 51    PC52                      lcom_stdev  0.262658  best
# 52    PC53              totalFieldsQty_sum  0.256016  best
# 53    PC54                returnQty_median  0.248931  best
# 54    PC55       maxNestedBlocksQty_median  0.230385  best
# 55    PC56          finalFieldsQty_average  0.315337  best
# 56    PC57       stringLiteralsQty_average  0.324217  best
# 57    PC58           publicFieldsQty_stdev  0.264720  best
# 58    PC59                      nosi_stdev -0.226397  best
# 59    PC60                  lambdasQty_max  0.238020  best
# 60    PC61                       rfc_stdev  0.251745  best
# 61    PC62           uniqueWordsQty_median  0.221416  best
# 62    PC63                numbersQty_stdev  0.229186  best
# 63    PC64             tryCatchQty_average  0.254474  best
# 64    PC65     protectedMethodsQty_average  0.242768  best
# 65    PC66                      rfc_median  0.246388  best
# 66    PC67                       rfc_stdev -0.213739  best
# 67    PC68              totalFieldsQty_sum  0.282431  best
# 68    PC69          staticFieldsQty_median -0.330447  best
# 69    PC70                  lambdasQty_max -0.286220  best
# 70    PC71                     cbo_average -0.208649  best
# 71    PC72            uniqueWordsQty_stdev  0.224108  best
# 72    PC73                         dit_max -0.249342  best
# 73    PC74     protectedMethodsQty_average  0.358797  best
# 74    PC75           mathOperationsQty_max  0.224103  best
# 75    PC76            uniqueWordsQty_stdev -0.241538  best
# 76    PC77       protectedFieldsQty_median  0.286472  best
# 77    PC78                         rfc_max  0.334707  best
# 78    PC79          totalMethodsQty_median  0.219049  best
# 79    PC80          staticFieldsQty_median -0.252730  best
# 80    PC81         publicFieldsQty_average -0.347648  best
# 81    PC82                   modifiers_max -0.249527  best
# 82    PC83    parenthesizedExpsQty_average  0.235899  best
# 83    PC84                       dit_stdev  0.239199  best
# 84    PC85         publicMethodsQty_median  0.222533  best
# 85    PC86               modifiers_average -0.231522  best
# 86    PC87        maxNestedBlocksQty_stdev  0.257215  best
# 87    PC88          defaultFieldsQty_stdev  0.291120  best
# 88    PC89                      loc_median -0.315136  best
# 89    PC90                        nosi_sum  0.300277  best
# 90    PC91         anonymousClassesQty_max  0.240193  best
# 91    PC92         anonymousClassesQty_sum  0.261521  best
# 92    PC93         anonymousClassesQty_max -0.268946  best
# 93    PC94         anonymousClassesQty_max -0.242737  best
# 94    PC95        stringLiteralsQty_median -0.265245  best
# 95    PC96       mathOperationsQty_average  0.257901  best
# 96    PC97                       dit_stdev -0.296555  best
# 97    PC98                      lcom_stdev -0.315147  best
# 98    PC99                 returnQty_stdev -0.307112  best
# 99   PC100                  loopQty_median -0.227266  best
# 100  PC101                     lcom_median  0.254914  best
# 101  PC102                  lambdasQty_sum  0.325584  best
# 102  PC103                 tryCatchQty_max -0.277171  best
# 103  PC104              uniqueWordsQty_max  0.351380  best
# 104  PC105         anonymousClassesQty_sum  0.342713  best
# 105  PC106                         rfc_max  0.278368  best
# 106  PC107         totalMethodsQty_average -0.265944  best
# 107  PC108                       wmc_stdev  0.284288  best
# 108  PC109                 tryCatchQty_max  0.233711  best
# 109  PC110                        lcom_max -0.293886  best
# 110  PC111                   loopQty_stdev  0.255820  best
# 111  PC112         staticMethodsQty_median  0.322841  best
# 112  PC113        mathOperationsQty_median -0.323902  best
# 113   PC53      synchronizedMethodsQty_sum  0.222450  weak
# 114   PC66  synchronizedMethodsQty_average -0.229589  weak
# 115   PC93    synchronizedMethodsQty_stdev  0.194025  weak
# 116  PC110      parenthesizedExpsQty_stdev  0.259280  weak
# 117   PC57     parenthesizedExpsQty_median  0.268151  weak
# 118  PC108                        lcom_sum  0.210356  weak
# 119   PC80         staticFieldsQty_average  0.228384  weak
# 120  PC104             staticFieldsQty_max -0.249581  weak
# 121   PC98          publicFieldsQty_median -0.228919  weak
# 122  PC111        logStatementsQty_average  0.250859  weak
# 123   PC12          logStatementsQty_stdev  0.268546  weak
# 124   PC16            logStatementsQty_max  0.226283  weak
# 125  PC108               tryCatchQty_stdev  0.214603  weak
# 126   PC23              tryCatchQty_median -0.272092  weak
# 127   PC87      maxNestedBlocksQty_average -0.217806  weak
# 128  PC109                     rfc_average -0.230535  weak
# 129    PC3           privateMethodsQty_sum  0.297303  weak
# 130  PC109       privateMethodsQty_average  0.171707  weak
# 131   PC68         privateMethodsQty_stdev -0.204697  weak
# 132   PC88        privateMethodsQty_median  0.249963  weak
# 133  PC102           defaultMethodsQty_sum -0.281835  weak
# 134   PC77                    nosi_average  0.230751  weak
# 135   PC86                     nosi_median -0.215335  weak
# 136  PC105                        nosi_max  0.293839  weak
# 137   PC78            visibleFieldsQty_sum  0.283223  weak
# 138   PC59        visibleFieldsQty_average  0.213927  weak
# 139  PC111          visibleFieldsQty_stdev  0.158346  weak
# 140   PC89          uniqueWordsQty_average  0.248097  weak
# 141   PC16     anonymousClassesQty_average -0.242300  weak
# 142   PC32         mathOperationsQty_stdev -0.242983  weak
# 143  PC106                   returnQty_sum -0.178870  weak
# 144  PC113               returnQty_average -0.265560  weak
# 145   PC94                modifiers_median -0.181407  weak
# 146   PC98          abstractMethodsQty_max  0.217219  weak
# 147   PC79      protectedFieldsQty_average -0.209922  weak
# 148    PC8        protectedFieldsQty_stdev -0.279116  weak
# 149   PC68          protectedFieldsQty_max  0.190828  weak
# 150   PC61                  numbersQty_sum  0.187893  weak
# 151   PC85              numbersQty_average -0.216644  weak
# 152  PC103               numbersQty_median  0.208112  weak
# 153   PC66                  numbersQty_max  0.204135  weak
# 154  PC112        staticMethodsQty_average -0.202939  weak
# 155  PC104          staticMethodsQty_stdev  0.212287  weak
# 156  PC113            assignmentsQty_stdev -0.218088  weak
# 157  PC113              assignmentsQty_max  0.306615  weak
# 158    PC4           totalMethodsQty_stdev  0.206457  weak
# 159   PC99                     loopQty_sum -0.197844  weak
# 160   PC41                 loopQty_average -0.206832  weak
# 161  PC111                     loopQty_max -0.221909  weak
# 162   PC59            defaultFieldsQty_sum -0.213488  weak
# 163   PC28            defaultFieldsQty_max  0.248416  weak
# 164   PC93                     loc_average  0.232435  weak
# 165   PC80                       loc_stdev -0.214675  weak
# 166   PC80                         loc_max  0.229991  weak
# 167   PC10          totalFieldsQty_average  0.205308  weak
# 168   PC25           totalFieldsQty_median  0.202874  weak
# 169  PC101              totalFieldsQty_max -0.224627  weak
# 170   PC37                       cbo_stdev  0.224697  weak
# 171   PC49                      cbo_median  0.224448  weak
# 172  PC107            variablesQty_average  0.201962  weak
# 173   PC65              variablesQty_stdev  0.208030  weak
# 174   PC83         protectedMethodsQty_max  0.200626  weak
# 175   PC64                     tcc_average -0.206241  weak
# 176    PC5                       tcc_stdev  0.321285  weak
# 177  PC103            privateFieldsQty_sum -0.207605  weak
# 178   PC42        privateFieldsQty_average -0.256496  weak
# 179    PC1         privateFieldsQty_median -0.000000  weak
# 180  PC100             finalMethodsQty_sum  0.225887  weak
# 181    PC9         finalMethodsQty_average  0.188223  weak
# 182   PC44             finalMethodsQty_max  0.274798  weak
# 183   PC96           innerClassesQty_stdev  0.247965  weak
# 184  PC108              comparisonsQty_sum  0.074615  weak
# 185   PC97          comparisonsQty_average  0.234175  weak
# 186   PC83            comparisonsQty_stdev -0.216017  weak
# 187   PC46           comparisonsQty_median -0.197195  weak
# 188   PC53              comparisonsQty_max -0.233525  weak

# %%
# printing pca - after removing all 0 variance metrics and correlation 0.9
def describe_data():
    data = data_loader.load_real_dataset(sqaured=False, remove_multicollinearity=False)
    data_xy = pre_training_analysis_tools.join_dataxy(data['train_x'], data['train_y'])
    output_xy = pre_training_analysis_tools.remove_collinear_features(data_xy, 'maven_reuse', 0.90, 'True')
    output_x = pre_training_analysis_tools.split_dataxy(output_xy)
    output_xy = pre_training_analysis_tools.variance_threshold(output_x['train_x'],data['train_y'])
    
    data = pre_training_analysis_tools.generate_train_test_xy(output_xy)
    pre_training_analysis_tools.all_model_score(data['train_x'],data['train_y'],data['test_x'],data['test_y'])

# %%
describe_data()
# Out:
# publicMethodsQty_stdev | lcom_average | 0.93
# publicMethodsQty_stdev: 0.079
# lcom_average: 0.083
# dropped: publicMethodsQty_stdev
# -----------------------------------------------------------------------------
# staticFieldsQty_sum | publicMethodsQty_sum | 0.98
# staticFieldsQty_sum: 0.129
# publicMethodsQty_sum: 0.126
# dropped: publicMethodsQty_sum
# -----------------------------------------------------------------------------
# staticFieldsQty_max | staticFieldsQty_stdev | 0.9
# staticFieldsQty_max: 0.028
# staticFieldsQty_stdev: 0.024
# dropped: staticFieldsQty_stdev
# -----------------------------------------------------------------------------
# publicFieldsQty_sum | parenthesizedExpsQty_sum | 0.9
# publicFieldsQty_sum: 0.079
# parenthesizedExpsQty_sum: 0.106
# dropped: publicFieldsQty_sum
# -----------------------------------------------------------------------------
# publicFieldsQty_max | publicFieldsQty_stdev | 0.93
# publicFieldsQty_max: 0.005
# publicFieldsQty_stdev: -0.035
# dropped: publicFieldsQty_max
# -----------------------------------------------------------------------------
# lambdasQty_stdev | lambdasQty_average | 0.93
# lambdasQty_stdev: -0.023
# lambdasQty_average: 0.055
# dropped: lambdasQty_stdev
# -----------------------------------------------------------------------------
# logStatementsQty_sum | staticFieldsQty_sum | 0.9
# logStatementsQty_sum: 0.099
# staticFieldsQty_sum: 0.129
# dropped: logStatementsQty_sum
# -----------------------------------------------------------------------------
# tryCatchQty_sum | staticFieldsQty_sum | 0.92
# tryCatchQty_sum: 0.043
# staticFieldsQty_sum: 0.129
# dropped: tryCatchQty_sum
# -----------------------------------------------------------------------------
# maxNestedBlocksQty_sum | parenthesizedExpsQty_sum | 0.9
# maxNestedBlocksQty_sum: 0.098
# parenthesizedExpsQty_sum: 0.106
# dropped: maxNestedBlocksQty_sum
# -----------------------------------------------------------------------------
# wmc_sum | parenthesizedExpsQty_sum | 0.91
# wmc_sum: 0.108
# parenthesizedExpsQty_sum: 0.106
# dropped: parenthesizedExpsQty_sum
# -----------------------------------------------------------------------------
# wmc_sum | staticFieldsQty_sum | 0.97
# wmc_sum: 0.108
# staticFieldsQty_sum: 0.129
# dropped: wmc_sum
# -----------------------------------------------------------------------------
# rfc_sum | staticFieldsQty_sum | 0.97
# rfc_sum: 0.122
# staticFieldsQty_sum: 0.129
# dropped: rfc_sum
# -----------------------------------------------------------------------------
# privateMethodsQty_sum | staticFieldsQty_sum | 0.93
# privateMethodsQty_sum: 0.155
# staticFieldsQty_sum: 0.129
# dropped: staticFieldsQty_sum
# -----------------------------------------------------------------------------
# visibleFieldsQty_max | visibleFieldsQty_stdev | 0.98
# visibleFieldsQty_max: 0.019
# visibleFieldsQty_stdev: 0.033
# dropped: visibleFieldsQty_max
# -----------------------------------------------------------------------------
# uniqueWordsQty_sum | privateMethodsQty_sum | 0.93
# uniqueWordsQty_sum: 0.093
# privateMethodsQty_sum: 0.155
# dropped: uniqueWordsQty_sum
# -----------------------------------------------------------------------------
# stringLiteralsQty_sum | privateMethodsQty_sum | 0.92
# stringLiteralsQty_sum: 0.088
# privateMethodsQty_sum: 0.155
# dropped: stringLiteralsQty_sum
# -----------------------------------------------------------------------------
# returnQty_sum | mathOperationsQty_sum | 0.92
# returnQty_sum: 0.139
# mathOperationsQty_sum: 0.057
# dropped: mathOperationsQty_sum
# -----------------------------------------------------------------------------
# modifiers_sum | privateMethodsQty_sum | 0.91
# modifiers_sum: 0.067
# privateMethodsQty_sum: 0.155
# dropped: modifiers_sum
# -----------------------------------------------------------------------------
# lcc_sum | privateMethodsQty_sum | 0.92
# lcc_sum: -0.102
# privateMethodsQty_sum: 0.155
# dropped: lcc_sum
# -----------------------------------------------------------------------------
# abstractMethodsQty_sum | privateMethodsQty_sum | 0.94
# abstractMethodsQty_sum: 0.117
# privateMethodsQty_sum: 0.155
# dropped: abstractMethodsQty_sum
# -----------------------------------------------------------------------------
# abstractMethodsQty_average | publicMethodsQty_average | 0.97
# abstractMethodsQty_average: 0.067
# publicMethodsQty_average: 0.05
# dropped: publicMethodsQty_average
# -----------------------------------------------------------------------------
# abstractMethodsQty_stdev | lcom_average | 0.91
# abstractMethodsQty_stdev: 0.084
# lcom_average: 0.083
# dropped: lcom_average
# -----------------------------------------------------------------------------
# abstractMethodsQty_median | publicMethodsQty_median | 0.93
# abstractMethodsQty_median: -0.007
# publicMethodsQty_median: -0.033
# dropped: abstractMethodsQty_median
# -----------------------------------------------------------------------------
# abstractMethodsQty_max | publicMethodsQty_max | 0.99
# abstractMethodsQty_max: 0.106
# publicMethodsQty_max: 0.08
# dropped: publicMethodsQty_max
# -----------------------------------------------------------------------------
# protectedFieldsQty_sum | privateMethodsQty_sum | 0.95
# protectedFieldsQty_sum: 0.133
# privateMethodsQty_sum: 0.155
# dropped: protectedFieldsQty_sum
# -----------------------------------------------------------------------------
# staticMethodsQty_sum | returnQty_sum | 0.91
# staticMethodsQty_sum: 0.12
# returnQty_sum: 0.139
# dropped: staticMethodsQty_sum
# -----------------------------------------------------------------------------
# staticMethodsQty_median | logStatementsQty_median | 0.9
# staticMethodsQty_median: -0.024
# logStatementsQty_median: nan
# dropped: logStatementsQty_median
# -----------------------------------------------------------------------------
# assignmentsQty_sum | privateMethodsQty_sum | 0.92
# assignmentsQty_sum: 0.097
# privateMethodsQty_sum: 0.155
# dropped: assignmentsQty_sum
# -----------------------------------------------------------------------------
# assignmentsQty_average | wmc_average | 0.92
# assignmentsQty_average: 0.102
# wmc_average: 0.149
# dropped: assignmentsQty_average
# -----------------------------------------------------------------------------
# finalFieldsQty_sum | privateMethodsQty_sum | 0.96
# finalFieldsQty_sum: 0.092
# privateMethodsQty_sum: 0.155
# dropped: finalFieldsQty_sum
# -----------------------------------------------------------------------------
# finalFieldsQty_stdev | publicFieldsQty_stdev | 0.98
# finalFieldsQty_stdev: -0.03
# publicFieldsQty_stdev: -0.035
# dropped: finalFieldsQty_stdev
# -----------------------------------------------------------------------------
# finalFieldsQty_max | publicFieldsQty_stdev | 0.94
# finalFieldsQty_max: 0.009
# publicFieldsQty_stdev: -0.035
# dropped: finalFieldsQty_max
# -----------------------------------------------------------------------------
# dit_sum | privateMethodsQty_sum | 0.94
# dit_sum: 0.124
# privateMethodsQty_sum: 0.155
# dropped: dit_sum
# -----------------------------------------------------------------------------
# totalMethodsQty_sum | privateMethodsQty_sum | 0.95
# totalMethodsQty_sum: 0.12
# privateMethodsQty_sum: 0.155
# dropped: totalMethodsQty_sum
# -----------------------------------------------------------------------------
# totalMethodsQty_average | abstractMethodsQty_average | 0.98
# totalMethodsQty_average: 0.104
# abstractMethodsQty_average: 0.067
# dropped: abstractMethodsQty_average
# -----------------------------------------------------------------------------
# totalMethodsQty_stdev | abstractMethodsQty_stdev | 0.99
# totalMethodsQty_stdev: 0.101
# abstractMethodsQty_stdev: 0.084
# dropped: abstractMethodsQty_stdev
# -----------------------------------------------------------------------------
# totalMethodsQty_max | abstractMethodsQty_max | 1.0
# totalMethodsQty_max: 0.102
# abstractMethodsQty_max: 0.106
# dropped: totalMethodsQty_max
# -----------------------------------------------------------------------------
# defaultFieldsQty_stdev | defaultFieldsQty_average | 0.9
# defaultFieldsQty_stdev: 0.109
# defaultFieldsQty_average: 0.055
# dropped: defaultFieldsQty_average
# -----------------------------------------------------------------------------
# loc_sum | privateMethodsQty_sum | 0.94
# loc_sum: 0.127
# privateMethodsQty_sum: 0.155
# dropped: loc_sum
# -----------------------------------------------------------------------------
# loc_average | wmc_average | 0.93
# loc_average: 0.171
# wmc_average: 0.149
# dropped: wmc_average
# -----------------------------------------------------------------------------
# loc_median | wmc_median | 0.97
# loc_median: 0.165
# wmc_median: 0.142
# dropped: wmc_median
# -----------------------------------------------------------------------------
# loc_median | assignmentsQty_median | 0.92
# loc_median: 0.165
# assignmentsQty_median: 0.115
# dropped: assignmentsQty_median
# -----------------------------------------------------------------------------
# cbo_sum | privateMethodsQty_sum | 0.96
# cbo_sum: 0.126
# privateMethodsQty_sum: 0.155
# dropped: cbo_sum
# -----------------------------------------------------------------------------
# variablesQty_sum | privateMethodsQty_sum | 0.94
# variablesQty_sum: 0.096
# privateMethodsQty_sum: 0.155
# dropped: variablesQty_sum
# -----------------------------------------------------------------------------
# variablesQty_median | loc_median | 0.92
# variablesQty_median: 0.132
# loc_median: 0.165
# dropped: variablesQty_median
# -----------------------------------------------------------------------------
# variablesQty_max | staticFieldsQty_max | 0.95
# variablesQty_max: -0.002
# staticFieldsQty_max: 0.028
# dropped: variablesQty_max
# -----------------------------------------------------------------------------
# protectedMethodsQty_sum | privateMethodsQty_sum | 0.91
# protectedMethodsQty_sum: 0.1
# privateMethodsQty_sum: 0.155
# dropped: protectedMethodsQty_sum
# -----------------------------------------------------------------------------
# tcc_sum | privateMethodsQty_sum | 0.92
# tcc_sum: -0.102
# privateMethodsQty_sum: 0.155
# dropped: tcc_sum
# -----------------------------------------------------------------------------
# tcc_average | lcc_average | 1.0
# tcc_average: 0.031
# lcc_average: 0.031
# dropped: lcc_average
# -----------------------------------------------------------------------------
# tcc_stdev | lcc_stdev | 1.0
# tcc_stdev: -0.008
# lcc_stdev: -0.008
# dropped: lcc_stdev
# -----------------------------------------------------------------------------
# tcc_median | lcc_median | 1.0
# tcc_median: -0.037
# lcc_median: -0.037
# dropped: lcc_median
# -----------------------------------------------------------------------------
# tcc_min | lcc_min | 1.0
# tcc_min: -0.058
# lcc_min: -0.058
# dropped: lcc_min
# -----------------------------------------------------------------------------
# privateFieldsQty_stdev | staticFieldsQty_max | 0.94
# privateFieldsQty_stdev: 0.014
# staticFieldsQty_max: 0.028
# dropped: privateFieldsQty_stdev
# -----------------------------------------------------------------------------
# privateFieldsQty_max | staticFieldsQty_max | 0.95
# privateFieldsQty_max: 0.026
# staticFieldsQty_max: 0.028
# dropped: privateFieldsQty_max
# -----------------------------------------------------------------------------
# finalMethodsQty_median | modifiers_median | 1.0
# finalMethodsQty_median: -0.108
# modifiers_median: -0.109
# dropped: finalMethodsQty_median
# -----------------------------------------------------------------------------
# innerClassesQty_sum | privateMethodsQty_sum | 0.95
# innerClassesQty_sum: 0.102
# privateMethodsQty_sum: 0.155
# dropped: innerClassesQty_sum
# -----------------------------------------------------------------------------
# comparisonsQty_sum | cbo_max | 0.91
# comparisonsQty_sum: 0.096
# cbo_max: 0.052
# dropped: cbo_max
# -----------------------------------------------------------------------------
# dropped columns:
# ['lambdasQty_stdev', 'totalMethodsQty_sum', 'assignmentsQty_sum', 'variablesQty_max', 'parenthesizedExpsQty_sum', 'assignmentsQty_median', 'stringLiteralsQty_sum', 'logStatementsQty_median', 'lcc_average', 'finalFieldsQty_max', 'abstractMethodsQty_stdev', 'privateFieldsQty_stdev', 'publicFieldsQty_max', 'variablesQty_sum', 'modifiers_sum', 'abstractMethodsQty_sum', 'publicMethodsQty_max', 'tryCatchQty_sum', 'wmc_median', 'finalFieldsQty_sum', 'cbo_sum', 'tcc_sum', 'lcc_min', 'totalMethodsQty_max', 'publicFieldsQty_sum', 'variablesQty_median', 'publicMethodsQty_stdev', 'privateFieldsQty_max', 'publicMethodsQty_sum', 'abstractMethodsQty_median', 'visibleFieldsQty_max', 'staticFieldsQty_stdev', 'staticFieldsQty_sum', 'mathOperationsQty_sum', 'maxNestedBlocksQty_sum', 'lcc_sum', 'logStatementsQty_sum', 'lcom_average', 'dit_sum', 'protectedMethodsQty_sum', 'finalMethodsQty_median', 'loc_sum', 'cbo_max', 'abstractMethodsQty_average', 'lcc_stdev', 'publicMethodsQty_average', 'wmc_average', 'uniqueWordsQty_sum', 'assignmentsQty_average', 'wmc_sum', 'rfc_sum', 'defaultFieldsQty_average', 'innerClassesQty_sum', 'finalFieldsQty_stdev', 'protectedFieldsQty_sum', 'staticMethodsQty_sum', 'lcc_median']
# -----------------------------------------------------------------------------
# used columns:
# ['synchronizedMethodsQty_sum', 'synchronizedMethodsQty_average', 'synchronizedMethodsQty_stdev', 'synchronizedMethodsQty_median', 'synchronizedMethodsQty_min', 'synchronizedMethodsQty_max', 'parenthesizedExpsQty_average', 'parenthesizedExpsQty_stdev', 'parenthesizedExpsQty_median', 'parenthesizedExpsQty_min', 'parenthesizedExpsQty_max', 'lcom_sum', 'lcom_stdev', 'lcom_median', 'lcom_min', 'lcom_max', 'publicMethodsQty_median', 'publicMethodsQty_min', 'staticFieldsQty_average', 'staticFieldsQty_median', 'staticFieldsQty_min', 'staticFieldsQty_max', 'publicFieldsQty_average', 'publicFieldsQty_stdev', 'publicFieldsQty_median', 'publicFieldsQty_min', 'lambdasQty_sum', 'lambdasQty_average', 'lambdasQty_median', 'lambdasQty_min', 'lambdasQty_max', 'logStatementsQty_average', 'logStatementsQty_stdev', 'logStatementsQty_min', 'logStatementsQty_max', 'tryCatchQty_average', 'tryCatchQty_stdev', 'tryCatchQty_median', 'tryCatchQty_min', 'tryCatchQty_max', 'maxNestedBlocksQty_average', 'maxNestedBlocksQty_stdev', 'maxNestedBlocksQty_median', 'maxNestedBlocksQty_min', 'maxNestedBlocksQty_max', 'wmc_stdev', 'wmc_min', 'wmc_max', 'rfc_average', 'rfc_stdev', 'rfc_median', 'rfc_min', 'rfc_max', 'privateMethodsQty_sum', 'privateMethodsQty_average', 'privateMethodsQty_stdev', 'privateMethodsQty_median', 'privateMethodsQty_min', 'privateMethodsQty_max', 'defaultMethodsQty_sum', 'defaultMethodsQty_average', 'defaultMethodsQty_stdev', 'defaultMethodsQty_median', 'defaultMethodsQty_min', 'defaultMethodsQty_max', 'nosi_sum', 'nosi_average', 'nosi_stdev', 'nosi_median', 'nosi_min', 'nosi_max', 'visibleFieldsQty_sum', 'visibleFieldsQty_average', 'visibleFieldsQty_stdev', 'visibleFieldsQty_median', 'visibleFieldsQty_min', 'uniqueWordsQty_average', 'uniqueWordsQty_stdev', 'uniqueWordsQty_median', 'uniqueWordsQty_min', 'uniqueWordsQty_max', 'synchronizedFieldsQty_sum', 'synchronizedFieldsQty_average', 'synchronizedFieldsQty_stdev', 'synchronizedFieldsQty_median', 'synchronizedFieldsQty_min', 'synchronizedFieldsQty_max', 'stringLiteralsQty_average', 'stringLiteralsQty_stdev', 'stringLiteralsQty_median', 'stringLiteralsQty_min', 'stringLiteralsQty_max', 'anonymousClassesQty_sum', 'anonymousClassesQty_average', 'anonymousClassesQty_stdev', 'anonymousClassesQty_median', 'anonymousClassesQty_min', 'anonymousClassesQty_max', 'mathOperationsQty_average', 'mathOperationsQty_stdev', 'mathOperationsQty_median', 'mathOperationsQty_min', 'mathOperationsQty_max', 'returnQty_sum', 'returnQty_average', 'returnQty_stdev', 'returnQty_median', 'returnQty_min', 'returnQty_max', 'modifiers_average', 'modifiers_stdev', 'modifiers_median', 'modifiers_min', 'modifiers_max', 'lcc_max', 'abstractMethodsQty_min', 'abstractMethodsQty_max', 'protectedFieldsQty_average', 'protectedFieldsQty_stdev', 'protectedFieldsQty_median', 'protectedFieldsQty_min', 'protectedFieldsQty_max', 'numbersQty_sum', 'numbersQty_average', 'numbersQty_stdev', 'numbersQty_median', 'numbersQty_min', 'numbersQty_max', 'staticMethodsQty_average', 'staticMethodsQty_stdev', 'staticMethodsQty_median', 'staticMethodsQty_min', 'staticMethodsQty_max', 'assignmentsQty_stdev', 'assignmentsQty_min', 'assignmentsQty_max', 'finalFieldsQty_average', 'finalFieldsQty_median', 'finalFieldsQty_min', 'dit_average', 'dit_stdev', 'dit_median', 'dit_min', 'dit_max', 'totalMethodsQty_average', 'totalMethodsQty_stdev', 'totalMethodsQty_median', 'totalMethodsQty_min', 'loopQty_sum', 'loopQty_average', 'loopQty_stdev', 'loopQty_median', 'loopQty_min', 'loopQty_max', 'defaultFieldsQty_sum', 'defaultFieldsQty_stdev', 'defaultFieldsQty_median', 'defaultFieldsQty_min', 'defaultFieldsQty_max', 'loc_average', 'loc_stdev', 'loc_median', 'loc_min', 'loc_max', 'totalFieldsQty_sum', 'totalFieldsQty_average', 'totalFieldsQty_stdev', 'totalFieldsQty_median', 'totalFieldsQty_min', 'totalFieldsQty_max', 'cbo_average', 'cbo_stdev', 'cbo_median', 'cbo_min', 'variablesQty_average', 'variablesQty_stdev', 'variablesQty_min', 'protectedMethodsQty_average ...
# Original feature shape: (113, 208)
# Transformed feature shape: (113, 151)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-a2164dc6536c> in <module>
# ----> 1 describe_data()
#
# <ipython-input-14-ac41bb48e76f> in describe_data()
#       8
#       9     data = pre_training_analysis_tools.generate_train_test_xy(output_xy)
# ---> 10     pre_training_analysis_tools.all_model_score(data['train_x'],data['train_y'],data['test_x'],data['test_y'])
#
# ~/Desktop/FIT4003/ProjectCodeBase/utils/pre_training_analysis_tools.py in all_model_score(data_x, data_y, test_x, test_y)
#     291     knn = KNeighborsClassifier()
#     292     clf = DecisionTreeClassifier()
# --> 293     svc = SVC()
#     294     lmnn = LMNN()
#     295
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/neighbors/_base.py in fit(self, X, y)
#    1130         if not isinstance(X, (KDTree, BallTree)):
#    1131             X, y = self._validate_data(X, y, accept_sparse="csr",
# -> 1132                                        multi_output=True)
#    1133
#    1134         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     800                     ensure_min_samples=ensure_min_samples,
#     801                     ensure_min_features=ensure_min_features,
# --> 802                     estimator=estimator)
#     803     if multi_output:
#     804         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     643         if force_all_finite:
#     644             _assert_all_finite(array,
# --> 645                                allow_nan=force_all_finite == 'allow-nan')
#     646
#     647     if ensure_min_samples > 0:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      97                     msg_err.format
#      98                     (type_err,
# ---> 99                      msg_dtype if msg_dtype is not None else X.dtype)
#     100             )
#     101     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
def describe_data():
    data = data_loader.load_real_dataset(sqaured=False, remove_multicollinearity=False)
    data_xy = pre_training_analysis_tools.join_dataxy(data['train_x'], data['train_y'])
    output_xy = pre_training_analysis_tools.remove_collinear_features(data_xy, 'maven_reuse', 0.90, 'True')
    output_x = pre_training_analysis_tools.split_dataxy(output_xy)
    output_xy = pre_training_analysis_tools.variance_threshold(output_x,data['train_y'])
    
    
    data = pre_training_analysis_tools.generate_train_test_xy(output_xy)
    pre_training_analysis_tools.all_model_score(data['train_x'],data['train_y'],data['test_x'],data['test_y'])

# %%
# variance remove + collinear feature remove + use rfecv on decision tree
def describe_data():
    data = data_loader.load_real_dataset(sqaured=False, remove_multicollinearity=False)
    output_xy = pre_training_analysis_tools.variance_threshold(data['train_x'],data['train_y'])
    output_xy = pre_training_analysis_tools.remove_collinear_features(output_xy, 'maven_reuse', 0.90, 'True')
    split_xy = pre_training_analysis_tools.split_dataxy(output_xy)

    pre_training_analysis_tools.recursive_feature_elimination(split_xy['train_x'], split_xy['train_y'])

   # pre_training_analysis_tools.all_model_score(data['train_x'],data['train_y'],data['test_x'],data['test_y'])
    
describe_data()
# Out:
# Original feature shape: (216, 265)
# Transformed feature shape: (216, 209)
# publicMethodsQty_stdev | lcom_average | 0.93
# publicMethodsQty_stdev: 0.079
# lcom_average: 0.083
# dropped: publicMethodsQty_stdev
# -----------------------------------------------------------------------------
# staticFieldsQty_sum | publicMethodsQty_sum | 0.98
# staticFieldsQty_sum: 0.129
# publicMethodsQty_sum: 0.126
# dropped: publicMethodsQty_sum
# -----------------------------------------------------------------------------
# staticFieldsQty_max | staticFieldsQty_stdev | 0.9
# staticFieldsQty_max: 0.028
# staticFieldsQty_stdev: 0.024
# dropped: staticFieldsQty_stdev
# -----------------------------------------------------------------------------
# publicFieldsQty_sum | parenthesizedExpsQty_sum | 0.9
# publicFieldsQty_sum: 0.079
# parenthesizedExpsQty_sum: 0.106
# dropped: publicFieldsQty_sum
# -----------------------------------------------------------------------------
# publicFieldsQty_max | publicFieldsQty_stdev | 0.93
# publicFieldsQty_max: 0.005
# publicFieldsQty_stdev: -0.035
# dropped: publicFieldsQty_max
# -----------------------------------------------------------------------------
# lambdasQty_stdev | lambdasQty_average | 0.93
# lambdasQty_stdev: -0.023
# lambdasQty_average: 0.055
# dropped: lambdasQty_stdev
# -----------------------------------------------------------------------------
# logStatementsQty_sum | staticFieldsQty_sum | 0.9
# logStatementsQty_sum: 0.099
# staticFieldsQty_sum: 0.129
# dropped: logStatementsQty_sum
# -----------------------------------------------------------------------------
# tryCatchQty_sum | staticFieldsQty_sum | 0.92
# tryCatchQty_sum: 0.043
# staticFieldsQty_sum: 0.129
# dropped: tryCatchQty_sum
# -----------------------------------------------------------------------------
# maxNestedBlocksQty_sum | parenthesizedExpsQty_sum | 0.9
# maxNestedBlocksQty_sum: 0.098
# parenthesizedExpsQty_sum: 0.106
# dropped: maxNestedBlocksQty_sum
# -----------------------------------------------------------------------------
# wmc_sum | parenthesizedExpsQty_sum | 0.91
# wmc_sum: 0.108
# parenthesizedExpsQty_sum: 0.106
# dropped: parenthesizedExpsQty_sum
# -----------------------------------------------------------------------------
# wmc_sum | staticFieldsQty_sum | 0.97
# wmc_sum: 0.108
# staticFieldsQty_sum: 0.129
# dropped: wmc_sum
# -----------------------------------------------------------------------------
# rfc_sum | staticFieldsQty_sum | 0.97
# rfc_sum: 0.122
# staticFieldsQty_sum: 0.129
# dropped: rfc_sum
# -----------------------------------------------------------------------------
# privateMethodsQty_sum | staticFieldsQty_sum | 0.93
# privateMethodsQty_sum: 0.155
# staticFieldsQty_sum: 0.129
# dropped: staticFieldsQty_sum
# -----------------------------------------------------------------------------
# visibleFieldsQty_max | visibleFieldsQty_stdev | 0.98
# visibleFieldsQty_max: 0.019
# visibleFieldsQty_stdev: 0.033
# dropped: visibleFieldsQty_max
# -----------------------------------------------------------------------------
# uniqueWordsQty_sum | privateMethodsQty_sum | 0.93
# uniqueWordsQty_sum: 0.093
# privateMethodsQty_sum: 0.155
# dropped: uniqueWordsQty_sum
# -----------------------------------------------------------------------------
# stringLiteralsQty_sum | privateMethodsQty_sum | 0.92
# stringLiteralsQty_sum: 0.088
# privateMethodsQty_sum: 0.155
# dropped: stringLiteralsQty_sum
# -----------------------------------------------------------------------------
# returnQty_sum | mathOperationsQty_sum | 0.92
# returnQty_sum: 0.139
# mathOperationsQty_sum: 0.057
# dropped: mathOperationsQty_sum
# -----------------------------------------------------------------------------
# modifiers_sum | privateMethodsQty_sum | 0.91
# modifiers_sum: 0.067
# privateMethodsQty_sum: 0.155
# dropped: modifiers_sum
# -----------------------------------------------------------------------------
# lcc_sum | privateMethodsQty_sum | 0.92
# lcc_sum: -0.102
# privateMethodsQty_sum: 0.155
# dropped: lcc_sum
# -----------------------------------------------------------------------------
# abstractMethodsQty_sum | privateMethodsQty_sum | 0.94
# abstractMethodsQty_sum: 0.117
# privateMethodsQty_sum: 0.155
# dropped: abstractMethodsQty_sum
# -----------------------------------------------------------------------------
# abstractMethodsQty_average | publicMethodsQty_average | 0.97
# abstractMethodsQty_average: 0.067
# publicMethodsQty_average: 0.05
# dropped: publicMethodsQty_average
# -----------------------------------------------------------------------------
# abstractMethodsQty_stdev | lcom_average | 0.91
# abstractMethodsQty_stdev: 0.084
# lcom_average: 0.083
# dropped: lcom_average
# -----------------------------------------------------------------------------
# abstractMethodsQty_median | publicMethodsQty_median | 0.93
# abstractMethodsQty_median: -0.007
# publicMethodsQty_median: -0.033
# dropped: abstractMethodsQty_median
# -----------------------------------------------------------------------------
# abstractMethodsQty_max | publicMethodsQty_max | 0.99
# abstractMethodsQty_max: 0.106
# publicMethodsQty_max: 0.08
# dropped: publicMethodsQty_max
# -----------------------------------------------------------------------------
# protectedFieldsQty_sum | privateMethodsQty_sum | 0.95
# protectedFieldsQty_sum: 0.133
# privateMethodsQty_sum: 0.155
# dropped: protectedFieldsQty_sum
# -----------------------------------------------------------------------------
# staticMethodsQty_sum | returnQty_sum | 0.91
# staticMethodsQty_sum: 0.12
# returnQty_sum: 0.139
# dropped: staticMethodsQty_sum
# -----------------------------------------------------------------------------
# staticMethodsQty_median | logStatementsQty_median | 0.9
# staticMethodsQty_median: -0.024
# logStatementsQty_median: nan
# dropped: logStatementsQty_median
# -----------------------------------------------------------------------------
# assignmentsQty_sum | privateMethodsQty_sum | 0.92
# assignmentsQty_sum: 0.097
# privateMethodsQty_sum: 0.155
# dropped: assignmentsQty_sum
# -----------------------------------------------------------------------------
# assignmentsQty_average | wmc_average | 0.92
# assignmentsQty_average: 0.102
# wmc_average: 0.149
# dropped: assignmentsQty_average
# -----------------------------------------------------------------------------
# finalFieldsQty_sum | privateMethodsQty_sum | 0.96
# finalFieldsQty_sum: 0.092
# privateMethodsQty_sum: 0.155
# dropped: finalFieldsQty_sum
# -----------------------------------------------------------------------------
# finalFieldsQty_stdev | publicFieldsQty_stdev | 0.98
# finalFieldsQty_stdev: -0.03
# publicFieldsQty_stdev: -0.035
# dropped: finalFieldsQty_stdev
# -----------------------------------------------------------------------------
# finalFieldsQty_max | publicFieldsQty_stdev | 0.94
# finalFieldsQty_max: 0.009
# publicFieldsQty_stdev: -0.035
# dropped: finalFieldsQty_max
# -----------------------------------------------------------------------------
# dit_sum | privateMethodsQty_sum | 0.94
# dit_sum: 0.124
# privateMethodsQty_sum: 0.155
# dropped: dit_sum
# -----------------------------------------------------------------------------
# totalMethodsQty_sum | privateMethodsQty_sum | 0.95
# totalMethodsQty_sum: 0.12
# privateMethodsQty_sum: 0.155
# dropped: totalMethodsQty_sum
# -----------------------------------------------------------------------------
# totalMethodsQty_average | abstractMethodsQty_average | 0.98
# totalMethodsQty_average: 0.104
# abstractMethodsQty_average: 0.067
# dropped: abstractMethodsQty_average
# -----------------------------------------------------------------------------
# totalMethodsQty_stdev | abstractMethodsQty_stdev | 0.99
# totalMethodsQty_stdev: 0.101
# abstractMethodsQty_stdev: 0.084
# dropped: abstractMethodsQty_stdev
# -----------------------------------------------------------------------------
# totalMethodsQty_max | abstractMethodsQty_max | 1.0
# totalMethodsQty_max: 0.102
# abstractMethodsQty_max: 0.106
# dropped: totalMethodsQty_max
# -----------------------------------------------------------------------------
# defaultFieldsQty_stdev | defaultFieldsQty_average | 0.9
# defaultFieldsQty_stdev: 0.109
# defaultFieldsQty_average: 0.055
# dropped: defaultFieldsQty_average
# -----------------------------------------------------------------------------
# loc_sum | privateMethodsQty_sum | 0.94
# loc_sum: 0.127
# privateMethodsQty_sum: 0.155
# dropped: loc_sum
# -----------------------------------------------------------------------------
# loc_average | wmc_average | 0.93
# loc_average: 0.171
# wmc_average: 0.149
# dropped: wmc_average
# -----------------------------------------------------------------------------
# loc_median | wmc_median | 0.97
# loc_median: 0.165
# wmc_median: 0.142
# dropped: wmc_median
# -----------------------------------------------------------------------------
# loc_median | assignmentsQty_median | 0.92
# loc_median: 0.165
# assignmentsQty_median: 0.115
# dropped: assignmentsQty_median
# -----------------------------------------------------------------------------
# cbo_sum | privateMethodsQty_sum | 0.96
# cbo_sum: 0.126
# privateMethodsQty_sum: 0.155
# dropped: cbo_sum
# -----------------------------------------------------------------------------
# variablesQty_sum | privateMethodsQty_sum | 0.94
# variablesQty_sum: 0.096
# privateMethodsQty_sum: 0.155
# dropped: variablesQty_sum
# -----------------------------------------------------------------------------
# variablesQty_median | loc_median | 0.92
# variablesQty_median: 0.132
# loc_median: 0.165
# dropped: variablesQty_median
# -----------------------------------------------------------------------------
# variablesQty_max | staticFieldsQty_max | 0.95
# variablesQty_max: -0.002
# staticFieldsQty_max: 0.028
# dropped: variablesQty_max
# -----------------------------------------------------------------------------
# protectedMethodsQty_sum | privateMethodsQty_sum | 0.91
# protectedMethodsQty_sum: 0.1
# privateMethodsQty_sum: 0.155
# dropped: protectedMethodsQty_sum
# -----------------------------------------------------------------------------
# tcc_sum | privateMethodsQty_sum | 0.92
# tcc_sum: -0.102
# privateMethodsQty_sum: 0.155
# dropped: tcc_sum
# -----------------------------------------------------------------------------
# tcc_average | lcc_average | 1.0
# tcc_average: 0.031
# lcc_average: 0.031
# dropped: lcc_average
# -----------------------------------------------------------------------------
# tcc_stdev | lcc_stdev | 1.0
# tcc_stdev: -0.008
# lcc_stdev: -0.008
# dropped: lcc_stdev
# -----------------------------------------------------------------------------
# tcc_median | lcc_median | 1.0
# tcc_median: -0.037
# lcc_median: -0.037
# dropped: lcc_median
# -----------------------------------------------------------------------------
# tcc_min | lcc_min | 1.0
# tcc_min: -0.058
# lcc_min: -0.058
# dropped: lcc_min
# -----------------------------------------------------------------------------
# privateFieldsQty_stdev | staticFieldsQty_max | 0.94
# privateFieldsQty_stdev: 0.014
# staticFieldsQty_max: 0.028
# dropped: privateFieldsQty_stdev
# -----------------------------------------------------------------------------
# privateFieldsQty_max | staticFieldsQty_max | 0.95
# privateFieldsQty_max: 0.026
# staticFieldsQty_max: 0.028
# dropped: privateFieldsQty_max
# -----------------------------------------------------------------------------
# finalMethodsQty_median | modifiers_median | 1.0
# finalMethodsQty_median: -0.108
# modifiers_median: -0.109
# dropped: finalMethodsQty_median
# -----------------------------------------------------------------------------
# innerClassesQty_sum | privateMethodsQty_sum | 0.95
# innerClassesQty_sum: 0.102
# privateMethodsQty_sum: 0.155
# dropped: innerClassesQty_sum
# -----------------------------------------------------------------------------
# comparisonsQty_sum | cbo_max | 0.91
# comparisonsQty_sum: 0.096
# cbo_max: 0.052
# dropped: cbo_max
# -----------------------------------------------------------------------------
# dropped columns:
# ['publicMethodsQty_max', 'publicFieldsQty_sum', 'variablesQty_max', 'innerClassesQty_sum', 'lcc_median', 'logStatementsQty_sum', 'publicFieldsQty_max', 'protectedMethodsQty_sum', 'variablesQty_median', 'assignmentsQty_average', 'abstractMethodsQty_median', 'abstractMethodsQty_stdev', 'tcc_sum', 'visibleFieldsQty_max', 'staticMethodsQty_sum', 'tryCatchQty_sum', 'lambdasQty_stdev', 'rfc_sum', 'loc_sum', 'lcc_min', 'variablesQty_sum', 'publicMethodsQty_average', 'uniqueWordsQty_sum', 'defaultFieldsQty_average', 'wmc_average', 'assignmentsQty_median', 'lcc_average', 'staticFieldsQty_stdev', 'maxNestedBlocksQty_sum', 'totalMethodsQty_sum', 'assignmentsQty_sum', 'publicMethodsQty_sum', 'cbo_max', 'abstractMethodsQty_average', 'wmc_median', 'lcc_sum', 'abstractMethodsQty_sum', 'cbo_sum', 'parenthesizedExpsQty_sum', 'stringLiteralsQty_sum', 'lcom_average', 'dit_sum', 'logStatementsQty_median', 'publicMethodsQty_stdev', 'finalMethodsQty_median', 'lcc_stdev', 'totalMethodsQty_max', 'privateFieldsQty_max', 'modifiers_sum', 'mathOperationsQty_sum', 'protectedFieldsQty_sum', 'finalFieldsQty_stdev', 'finalFieldsQty_sum', 'wmc_sum', 'staticFieldsQty_sum', 'privateFieldsQty_stdev', 'finalFieldsQty_max']
# -----------------------------------------------------------------------------
# used columns:
# ['synchronizedMethodsQty_sum', 'synchronizedMethodsQty_average', 'synchronizedMethodsQty_stdev', 'synchronizedMethodsQty_max', 'parenthesizedExpsQty_average', 'parenthesizedExpsQty_stdev', 'parenthesizedExpsQty_median', 'parenthesizedExpsQty_max', 'lcom_sum', 'lcom_stdev', 'lcom_median', 'lcom_max', 'publicMethodsQty_median', 'staticFieldsQty_average', 'staticFieldsQty_median', 'staticFieldsQty_max', 'publicFieldsQty_average', 'publicFieldsQty_stdev', 'publicFieldsQty_median', 'lambdasQty_sum', 'lambdasQty_average', 'lambdasQty_max', 'logStatementsQty_average', 'logStatementsQty_stdev', 'logStatementsQty_max', 'tryCatchQty_average', 'tryCatchQty_stdev', 'tryCatchQty_median', 'tryCatchQty_max', 'maxNestedBlocksQty_average', 'maxNestedBlocksQty_stdev', 'maxNestedBlocksQty_median', 'maxNestedBlocksQty_max', 'wmc_stdev', 'wmc_max', 'rfc_average', 'rfc_stdev', 'rfc_median', 'rfc_max', 'privateMethodsQty_sum', 'privateMethodsQty_average', 'privateMethodsQty_stdev', 'privateMethodsQty_median', 'privateMethodsQty_max', 'defaultMethodsQty_sum', 'defaultMethodsQty_average', 'defaultMethodsQty_stdev', 'defaultMethodsQty_median', 'defaultMethodsQty_max', 'nosi_sum', 'nosi_average', 'nosi_stdev', 'nosi_median', 'nosi_max', 'visibleFieldsQty_sum', 'visibleFieldsQty_average', 'visibleFieldsQty_stdev', 'uniqueWordsQty_average', 'uniqueWordsQty_stdev', 'uniqueWordsQty_median', 'uniqueWordsQty_max', 'stringLiteralsQty_average', 'stringLiteralsQty_stdev', 'stringLiteralsQty_median', 'stringLiteralsQty_max', 'anonymousClassesQty_sum', 'anonymousClassesQty_average', 'anonymousClassesQty_stdev', 'anonymousClassesQty_max', 'mathOperationsQty_average', 'mathOperationsQty_stdev', 'mathOperationsQty_median', 'mathOperationsQty_max', 'returnQty_sum', 'returnQty_average', 'returnQty_stdev', 'returnQty_median', 'returnQty_max', 'modifiers_average', 'modifiers_stdev', 'modifiers_median', 'modifiers_min', 'modifiers_max', 'abstractMethodsQty_max', 'protectedFieldsQty_average', 'protectedFieldsQty_stdev', 'protectedFieldsQty_median', 'protectedFieldsQty_max', 'numbersQty_sum', 'numbersQty_average', 'numbersQty_stdev', 'numbersQty_median', 'numbersQty_max', 'staticMethodsQty_average', 'staticMethodsQty_stdev', 'staticMethodsQty_median', 'staticMethodsQty_max', 'assignmentsQty_stdev', 'assignmentsQty_max', 'finalFieldsQty_average', 'finalFieldsQty_median', 'dit_average', 'dit_stdev', 'dit_median', 'dit_max', 'totalMethodsQty_average', 'totalMethodsQty_stdev', 'totalMethodsQty_median', 'loopQty_sum', 'loopQty_average', 'loopQty_stdev', 'loopQty_median', 'loopQty_max', 'defaultFieldsQty_sum', 'defaultFieldsQty_stdev', 'defaultFieldsQty_max', 'loc_average', 'loc_stdev', 'loc_median', 'loc_max', 'totalFieldsQty_sum', 'totalFieldsQty_average', 'totalFieldsQty_stdev', 'totalFieldsQty_median', 'totalFieldsQty_max', 'cbo_average', 'cbo_stdev', 'cbo_median', 'variablesQty_average', 'variablesQty_stdev', 'protectedMethodsQty_average', 'protectedMethodsQty_stdev', 'protectedMethodsQty_max', 'tcc_average', 'tcc_stdev', 'tcc_median', 'tcc_min', 'privateFieldsQty_sum', 'privateFieldsQty_average', 'privateFieldsQty_median', 'finalMethodsQty_sum', 'finalMethodsQty_average', 'finalMethodsQty_stdev', 'finalMethodsQty_max', 'innerClassesQty_average', 'innerClassesQty_stdev', 'innerClassesQty_max', 'comparisonsQty_sum', 'comparisonsQty_average', 'comparisonsQty_stdev', 'comparisonsQty_median', 'comparisonsQty_max', 'maven_reuse']
# Optimal number of features : 2
#                         Feature  Ranking  Selected     Score
# 58         uniqueWordsQty_stdev        1      True  0.350593
# 109             loopQty_average        1      True  0.365481
# 94       staticMethodsQty_stdev        2     False  0.350856
# 90             numbersQty_stdev        3     False  0.359552
# 5    parenthesizedExpsQty_stdev        4     False  0.352701
# 105     totalMethodsQty_average        5     False  0.350988
# 93     staticMethodsQty_average        6     False  0.356522
# 76             returnQty_median        7     False  0.359420
# 99       finalFieldsQty_average        8     False  0.359420
# 129          variablesQty_stdev        9     False  0.353228
# 29   maxNestedBlocksQty_average       10     False  0.341765
# 11                     lcom_max       11     False  0.347563
# 102                   dit_stdev       12     False  0.344928
# 35                  rfc_average       13     False  0.362451
# 17        publicFieldsQty_stdev       14     False  0.344664
# 128        variablesQty_average       15     False  0.373781
# 92               numbersQty_max       16     False  0.356522
# 96         staticMethodsQty_max       17     False  0.365217
# 9                    lcom_stdev       18     False  0.389196
# 13      staticFieldsQty_average       19     False  0.332675

# %%
# debuggin testg
def main():
    # get data to use in this analysis.
    data = data_loader.load_real_dataset(remove_multicollinearity=False, only_pca=True)    
    # determine which model we are using.
    model = LMNN(data, normalize=True)

    #model.find_hyperparams()
    model.train()
    model.describe()
    model.test()

main()
# Out:
# >> initialising model...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-9d097c92ff22> in <module>
#      11     model.test()
#      12
# ---> 13 main()
#
# <ipython-input-3-9d097c92ff22> in main()
#       4     data = data_loader.load_real_dataset(remove_multicollinearity=False, only_pca=True)
#       5     # determine which model we are using.
# ----> 6     model = LMNN(data, normalize=True)
#       7
#       8     #model.find_hyperparams()
#
# ~/Desktop/FIT4003/ProjectCodeBase/model/lmnn.py in __init__(self, data, normalize)
#      33         # Reference to the library used: https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.ExtraTreesClassifier.html
#      34         # Selecting the most important features using a tress classifer algorithm# initialise a statsmodels OLS instance.
# ---> 35         self.model = LMNN()
#      36         self.knnmodel = KNeighborsClassifier()
#      37
#
# TypeError: __init__() missing 1 required positional argument: 'data'

# %%
#relief f algo, after removing variance zero
def describe_data():
    data = data_loader.load_real_dataset(sqaured=False, remove_multicollinearity=False)
    output_xy = pre_training_analysis_tools.variance_threshold(data['train_x'],data['train_y'])
    split_xy = pre_training_analysis_tools.split_dataxy(output_xy)
    x = split_xy['train_x']
    y = split_xy['train_y']
    
    from skfeature.function.statistical_based import CFS
    score = CFS.cfs(x.to_numpy() , y.to_numpy())
    display(score)
    
    x = x.iloc[:, [32, 131,  33,  39, 174,  26, 132, 144,   9,  10,  15,  20]]
    
    data_xy = pre_training_analysis_tools.join_dataxy(x, y)
    data = pre_training_analysis_tools.generate_train_test_xy(data_xy)
    pre_training_analysis_tools.all_model_score(data['train_x'],data['train_y'],data['test_x'],data['test_y'])
    
describe_data()
# Out:
# Original feature shape: (216, 265)
# Transformed feature shape: (216, 209)
# array([ 15, 144,  20,  30,  92,  61, 137,  93,  10,  31,  11,  16,  21,
#         25,  41,  26])
# 0.5555555555555556
# 0.30434782608695654
#               precision    recall  f1-score   support
#
#          1.0       0.20      0.50      0.29         6
#          2.0       0.50      0.31      0.38        13
#          3.0       0.00      0.00      0.00         4
#
#     accuracy                           0.30        23
#    macro avg       0.23      0.27      0.22        23
# weighted avg       0.33      0.30      0.29        23
#
# 0.9666666666666667
# 0.34782608695652173
#               precision    recall  f1-score   support
#
#          1.0       0.00      0.00      0.00         6
#          2.0       0.62      0.62      0.62        13
#          3.0       0.00      0.00      0.00         4
#
#     accuracy                           0.35        23
#    macro avg       0.21      0.21      0.21        23
# weighted avg       0.35      0.35      0.35        23
#
# 0.5888888888888889
# 0.391304347826087
#               precision    recall  f1-score   support
#
#          1.0       0.18      0.33      0.24         6
#          2.0       0.58      0.54      0.56        13
#          3.0       0.00      0.00      0.00         4
#
#     accuracy                           0.39        23
#    macro avg       0.26      0.29      0.27        23
# weighted avg       0.38      0.39      0.38        23
#
# LMNN accuracy on train set of 90 points: 0.5778
# LMNN accuracy on test set of 23 points: 0.4783

# %%
#relief f algo, after removing variance zero
def describe_data():
    data = data_loader.load_real_dataset(sqaured=False, remove_multicollinearity=False)
    output_xy = pre_training_analysis_tools.variance_threshold(data['train_x'],data['train_y'])
    split_xy = pre_training_analysis_tools.split_dataxy(output_xy)
    x = split_xy['train_x']
    y = split_xy['train_y']
    
    from skfeature.function.similarity_based import reliefF
    score = reliefF.reliefF(x.to_numpy() , y.to_numpy())
    display(score)

   # pre_training_analysis_tools.all_model_score(data['train_x'],data['train_y'],data['test_x'],data['test_y'])
    
describe_data()
# Out:
# Original feature shape: (216, 265)
# Transformed feature shape: (216, 209)
# array([26.24778935, 17.39100886, 25.02908036, 41.50195363, 10.44898907,
#        25.1934945 , 37.36571432,  9.99692276, 45.47764806, 12.25361192,
#        19.9683064 , 14.90709506,  5.36210104,  4.04770518, 18.25702324,
#        33.06285107, 31.1275214 , 24.30865938, 18.93220815, 25.11890567,
#        39.29110469,  8.50167821, 26.32986708,  6.2489507 , 20.08680764,
#        39.73661087, 13.97276786,  5.70233609,  6.83465408, 23.54937356,
#        23.51266188, 16.57147037, 12.41604587, 13.65734301,  9.44954044,
#        13.27511588,  0.        , 23.01469219, 25.51499684, 26.99018991,
#        19.7062946 , 12.96592632, 14.73449484, 13.30953623, 42.74827075,
#        30.62723759, 33.34944777, 34.8381325 , 15.8186869 , 19.03238036,
#        34.23261025, 26.88872042, 47.77093474, 23.15867575, 31.2832573 ,
#        38.91474356, 38.80920053, 33.68137517, 30.54338487, 20.97256069,
#        27.74889314, 10.6878517 , 51.10086637, 21.73033397, 29.73824762,
#        21.67556519,  7.55391285, 39.28913817, 20.53392778, 42.25877205,
#        43.39123656, 15.45234206, 21.50351671,  8.42689703, 20.32792637,
#         4.21278354,  2.46523034, 21.39979768, 30.48320035, 29.54492526,
#        41.54758665, 17.28749593, 25.25362894, 32.22930521, 25.79963156,
#         6.92893584, 22.9335645 , 21.29612449, 57.96407771, 31.89269329,
#        17.92120972,  8.4761216 , 21.146143  , 30.62472046,  4.68164663,
#        32.2402703 , 11.15793363, 23.8788247 , 34.23372407, 47.28055118,
#        40.26911972, 21.73843252, 31.77979339, 70.20321727,  4.6805602 ,
#        48.30161068, 22.69082308, 24.27706612, 43.38030316, 77.03004745,
#         8.60110931, 45.52004747, 21.94322536, 34.82169064, 33.74955757,
#        27.7872788 , 20.22359005, 20.58359734, 41.25215363, 48.18948105,
#        13.65188693, 27.23366666, 19.44336758, 12.62780216, 10.31871755,
#        16.98934009,  7.25030441, 25.69670677, 15.12639587, 24.19277646,
#         1.70168721, 55.06594838, 21.25611294, 19.80239844, 25.6146975 ,
#        21.34129501, 18.86528481, 27.04451151, 49.57538375, 12.89861446,
#        21.37518105,  6.67761998, 24.44103476, 68.12976213, 16.72000583,
#        50.47272265, 18.14609636, 23.3113691 , 36.91484585, 33.83827568,
#        31.98060552, 20.31873444, 14.79652277, 20.75959837, 20.96762769,
#         9.17877903, 15.97084224, 19.36809782, 36.05867178, 30.01127947,
#        32.06614389, 24.79690496, 23.57797495, 44.72735374, 27.44962408,
#        29.18139106, 27.91789341, 11.19493296, 38.5671362 ,  3.42130937,
#        28.59973662, 24.49950366, 58.69810238, 48.91273736, 40.85025755,
#        13.71916714, 23.77395008, 22.66969802, 25.22815446, 21.25208616,
#        10.36621969, 22.21062043, 30.69098195, 21.9159575 , 21.79426752,
#        24.27706612, 43.38030316, 77.03004745,  8.60110931, 45.52004747,
#        10.57386533, 32.9634695 ,  9.88082046,  0.        ,  5.30601541,
#        18.2849812 , 11.58730135, 25.80577418,  4.14796425, 23.35652471,
#        23.91779562, 72.10685128, 36.23606419, 32.18424399,  4.63375921,
#        15.91301727, 28.37749584,  9.06398111, 41.77622308])

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import itertools
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from mlxtend.classifier import EnsembleVoteClassifier
from mlxtend.data import iris_data
from mlxtend.plotting import plot_decision_regions

# Initializing Classifiers
clf1 = LogisticRegression(random_state=0)
clf2 = RandomForestClassifier(random_state=0)
clf3 = SVC(random_state=0, probability=True)
eclf = EnsembleVoteClassifier(clfs=[clf1, clf2, clf3],
                              weights=[2, 1, 1], voting='soft')



data = data_loader.load_real_dataset(sqaured=False, remove_multicollinearity=False)

# Loading some example data
y = data['train_y'].to_numpy().astype(np.integer)
X = data['train_x'].to_numpy()

# Plotting Decision Regions

gs = gridspec.GridSpec(2, 2)
fig = plt.figure(figsize=(10, 8))

labels = ['Logistic Regression',
          'Random Forest',
          'RBF kernel SVM',
          'Ensemble']

for clf, lab, grd in zip([clf1, clf2, clf3, eclf],
                         labels,
                         itertools.product([0, 1],
                         repeat=2)):
    clf.fit(X, y)
    ax = plt.subplot(gs[grd[0], grd[1]])
    fig = plot_decision_regions(X=X, y=y,
                                clf=clf, legend=2)
    plt.title(lab)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-cc67b5304993> in <module>
#      42     ax = plt.subplot(gs[grd[0], grd[1]])
#      43     fig = plot_decision_regions(X=X, y=y,
# ---> 44                                 clf=clf, legend=2)
#      45     plt.title(lab)
#      46
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/mlxtend/plotting/decision_regions.py in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, res, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, scatter_highlight_kwargs)
#     176     if dim > 2:
#     177         if filler_feature_values is None:
# --> 178             raise ValueError('Filler values must be provided when '
#     179                              'X has more than 2 training features.')
#     180
#
# ValueError: Filler values must be provided when X has more than 2 training features.

# %%
# Initialize the dataset

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

data = data_loader.load_real_dataset(only_pca=True)

# Loading some example data
y_train = data['train_y']
y_test = data['test_y']
X_train = data['train_x']
X_test = data['test_x']

knn = KNeighborsClassifier(n_neighbors=3)
# Select the "best" three features via
# 5-fold cross-validation on the training set.

from mlxtend.feature_selection import SequentialFeatureSelector as EFS

efs1 = EFS(knn, 
           min_features=1,
           max_features=25,
           scoring='f1_weighted',
            verbose=2,
           cv=5)
efs1 = efs1.fit(X_train, y_train)

display('Selected features:', efs1.best_idx_)

# Generate the new subsets based on the selected features
# Note that the transform call is equivalent to
# X_train[:, efs1.k_feature_idx_]

X_train_efs = efs1.transform(X_train)
X_test_efs = efs1.transform(X_test)

# Fit the estimator using the new feature subset
# and make a prediction on the test data
knn.fit(X_train_efs, y_train)
y_pred = knn.predict(X_test_efs)

# Compute the accuracy of the prediction
print(accuracy_score(y_train, knn.predict(X_train)))
print(accuracy_score(y_test, y_pred))

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.tree import DecisionTreeClassifier
from model.support_vector_machine import SupportVectorMachine
from skopt.space import Real, Categorical, Integer
from skopt import BayesSearchCV
from sklearn.pipeline import Pipeline
import mlxtend
from sklearn.model_selection import GridSearchCV

data = data_loader.load_real_dataset(sqaured=False, remove_multicollinearity=False)
output_xy = pre_training_analysis_tools.variance_threshold(data['train_x'],data['train_y'])
output_xy = pre_training_analysis_tools.remove_collinear_features(output_xy, 'maven_reuse', 0.90, 'True')
data = pre_training_analysis_tools.generate_train_test_xy(output_xy)

# Loading some example data
y_train = data['train_y']
y_test = data['test_y']
X_train = data['train_x']
X_test = data['test_x']
# Out:
# Original feature shape: (216, 265)
# Transformed feature shape: (216, 209)
# publicMethodsQty_stdev | lcom_average | 0.93
# publicMethodsQty_stdev: 0.079
# lcom_average: 0.083
# dropped: publicMethodsQty_stdev
# -----------------------------------------------------------------------------
# staticFieldsQty_sum | publicMethodsQty_sum | 0.98
# staticFieldsQty_sum: 0.129
# publicMethodsQty_sum: 0.126
# dropped: publicMethodsQty_sum
# -----------------------------------------------------------------------------
# staticFieldsQty_max | staticFieldsQty_stdev | 0.9
# staticFieldsQty_max: 0.028
# staticFieldsQty_stdev: 0.024
# dropped: staticFieldsQty_stdev
# -----------------------------------------------------------------------------
# publicFieldsQty_sum | parenthesizedExpsQty_sum | 0.9
# publicFieldsQty_sum: 0.079
# parenthesizedExpsQty_sum: 0.106
# dropped: publicFieldsQty_sum
# -----------------------------------------------------------------------------
# publicFieldsQty_max | publicFieldsQty_stdev | 0.93
# publicFieldsQty_max: 0.005
# publicFieldsQty_stdev: -0.035
# dropped: publicFieldsQty_max
# -----------------------------------------------------------------------------
# lambdasQty_stdev | lambdasQty_average | 0.93
# lambdasQty_stdev: -0.023
# lambdasQty_average: 0.055
# dropped: lambdasQty_stdev
# -----------------------------------------------------------------------------
# logStatementsQty_sum | staticFieldsQty_sum | 0.9
# logStatementsQty_sum: 0.099
# staticFieldsQty_sum: 0.129
# dropped: logStatementsQty_sum
# -----------------------------------------------------------------------------
# tryCatchQty_sum | staticFieldsQty_sum | 0.92
# tryCatchQty_sum: 0.043
# staticFieldsQty_sum: 0.129
# dropped: tryCatchQty_sum
# -----------------------------------------------------------------------------
# maxNestedBlocksQty_sum | parenthesizedExpsQty_sum | 0.9
# maxNestedBlocksQty_sum: 0.098
# parenthesizedExpsQty_sum: 0.106
# dropped: maxNestedBlocksQty_sum
# -----------------------------------------------------------------------------
# wmc_sum | parenthesizedExpsQty_sum | 0.91
# wmc_sum: 0.108
# parenthesizedExpsQty_sum: 0.106
# dropped: parenthesizedExpsQty_sum
# -----------------------------------------------------------------------------
# wmc_sum | staticFieldsQty_sum | 0.97
# wmc_sum: 0.108
# staticFieldsQty_sum: 0.129
# dropped: wmc_sum
# -----------------------------------------------------------------------------
# rfc_sum | staticFieldsQty_sum | 0.97
# rfc_sum: 0.122
# staticFieldsQty_sum: 0.129
# dropped: rfc_sum
# -----------------------------------------------------------------------------
# privateMethodsQty_sum | staticFieldsQty_sum | 0.93
# privateMethodsQty_sum: 0.155
# staticFieldsQty_sum: 0.129
# dropped: staticFieldsQty_sum
# -----------------------------------------------------------------------------
# visibleFieldsQty_max | visibleFieldsQty_stdev | 0.98
# visibleFieldsQty_max: 0.019
# visibleFieldsQty_stdev: 0.033
# dropped: visibleFieldsQty_max
# -----------------------------------------------------------------------------
# uniqueWordsQty_sum | privateMethodsQty_sum | 0.93
# uniqueWordsQty_sum: 0.093
# privateMethodsQty_sum: 0.155
# dropped: uniqueWordsQty_sum
# -----------------------------------------------------------------------------
# stringLiteralsQty_sum | privateMethodsQty_sum | 0.92
# stringLiteralsQty_sum: 0.088
# privateMethodsQty_sum: 0.155
# dropped: stringLiteralsQty_sum
# -----------------------------------------------------------------------------
# returnQty_sum | mathOperationsQty_sum | 0.92
# returnQty_sum: 0.139
# mathOperationsQty_sum: 0.057
# dropped: mathOperationsQty_sum
# -----------------------------------------------------------------------------
# modifiers_sum | privateMethodsQty_sum | 0.91
# modifiers_sum: 0.067
# privateMethodsQty_sum: 0.155
# dropped: modifiers_sum
# -----------------------------------------------------------------------------
# lcc_sum | privateMethodsQty_sum | 0.92
# lcc_sum: -0.102
# privateMethodsQty_sum: 0.155
# dropped: lcc_sum
# -----------------------------------------------------------------------------
# abstractMethodsQty_sum | privateMethodsQty_sum | 0.94
# abstractMethodsQty_sum: 0.117
# privateMethodsQty_sum: 0.155
# dropped: abstractMethodsQty_sum
# -----------------------------------------------------------------------------
# abstractMethodsQty_average | publicMethodsQty_average | 0.97
# abstractMethodsQty_average: 0.067
# publicMethodsQty_average: 0.05
# dropped: publicMethodsQty_average
# -----------------------------------------------------------------------------
# abstractMethodsQty_stdev | lcom_average | 0.91
# abstractMethodsQty_stdev: 0.084
# lcom_average: 0.083
# dropped: lcom_average
# -----------------------------------------------------------------------------
# abstractMethodsQty_median | publicMethodsQty_median | 0.93
# abstractMethodsQty_median: -0.007
# publicMethodsQty_median: -0.033
# dropped: abstractMethodsQty_median
# -----------------------------------------------------------------------------
# abstractMethodsQty_max | publicMethodsQty_max | 0.99
# abstractMethodsQty_max: 0.106
# publicMethodsQty_max: 0.08
# dropped: publicMethodsQty_max
# -----------------------------------------------------------------------------
# protectedFieldsQty_sum | privateMethodsQty_sum | 0.95
# protectedFieldsQty_sum: 0.133
# privateMethodsQty_sum: 0.155
# dropped: protectedFieldsQty_sum
# -----------------------------------------------------------------------------
# staticMethodsQty_sum | returnQty_sum | 0.91
# staticMethodsQty_sum: 0.12
# returnQty_sum: 0.139
# dropped: staticMethodsQty_sum
# -----------------------------------------------------------------------------
# staticMethodsQty_median | logStatementsQty_median | 0.9
# staticMethodsQty_median: -0.024
# logStatementsQty_median: nan
# dropped: logStatementsQty_median
# -----------------------------------------------------------------------------
# assignmentsQty_sum | privateMethodsQty_sum | 0.92
# assignmentsQty_sum: 0.097
# privateMethodsQty_sum: 0.155
# dropped: assignmentsQty_sum
# -----------------------------------------------------------------------------
# assignmentsQty_average | wmc_average | 0.92
# assignmentsQty_average: 0.102
# wmc_average: 0.149
# dropped: assignmentsQty_average
# -----------------------------------------------------------------------------
# finalFieldsQty_sum | privateMethodsQty_sum | 0.96
# finalFieldsQty_sum: 0.092
# privateMethodsQty_sum: 0.155
# dropped: finalFieldsQty_sum
# -----------------------------------------------------------------------------
# finalFieldsQty_stdev | publicFieldsQty_stdev | 0.98
# finalFieldsQty_stdev: -0.03
# publicFieldsQty_stdev: -0.035
# dropped: finalFieldsQty_stdev
# -----------------------------------------------------------------------------
# finalFieldsQty_max | publicFieldsQty_stdev | 0.94
# finalFieldsQty_max: 0.009
# publicFieldsQty_stdev: -0.035
# dropped: finalFieldsQty_max
# -----------------------------------------------------------------------------
# dit_sum | privateMethodsQty_sum | 0.94
# dit_sum: 0.124
# privateMethodsQty_sum: 0.155
# dropped: dit_sum
# -----------------------------------------------------------------------------
# totalMethodsQty_sum | privateMethodsQty_sum | 0.95
# totalMethodsQty_sum: 0.12
# privateMethodsQty_sum: 0.155
# dropped: totalMethodsQty_sum
# -----------------------------------------------------------------------------
# totalMethodsQty_average | abstractMethodsQty_average | 0.98
# totalMethodsQty_average: 0.104
# abstractMethodsQty_average: 0.067
# dropped: abstractMethodsQty_average
# -----------------------------------------------------------------------------
# totalMethodsQty_stdev | abstractMethodsQty_stdev | 0.99
# totalMethodsQty_stdev: 0.101
# abstractMethodsQty_stdev: 0.084
# dropped: abstractMethodsQty_stdev
# -----------------------------------------------------------------------------
# totalMethodsQty_max | abstractMethodsQty_max | 1.0
# totalMethodsQty_max: 0.102
# abstractMethodsQty_max: 0.106
# dropped: totalMethodsQty_max
# -----------------------------------------------------------------------------
# defaultFieldsQty_stdev | defaultFieldsQty_average | 0.9
# defaultFieldsQty_stdev: 0.109
# defaultFieldsQty_average: 0.055
# dropped: defaultFieldsQty_average
# -----------------------------------------------------------------------------
# loc_sum | privateMethodsQty_sum | 0.94
# loc_sum: 0.127
# privateMethodsQty_sum: 0.155
# dropped: loc_sum
# -----------------------------------------------------------------------------
# loc_average | wmc_average | 0.93
# loc_average: 0.171
# wmc_average: 0.149
# dropped: wmc_average
# -----------------------------------------------------------------------------
# loc_median | wmc_median | 0.97
# loc_median: 0.165
# wmc_median: 0.142
# dropped: wmc_median
# -----------------------------------------------------------------------------
# loc_median | assignmentsQty_median | 0.92
# loc_median: 0.165
# assignmentsQty_median: 0.115
# dropped: assignmentsQty_median
# -----------------------------------------------------------------------------
# cbo_sum | privateMethodsQty_sum | 0.96
# cbo_sum: 0.126
# privateMethodsQty_sum: 0.155
# dropped: cbo_sum
# -----------------------------------------------------------------------------
# variablesQty_sum | privateMethodsQty_sum | 0.94
# variablesQty_sum: 0.096
# privateMethodsQty_sum: 0.155
# dropped: variablesQty_sum
# -----------------------------------------------------------------------------
# variablesQty_median | loc_median | 0.92
# variablesQty_median: 0.132
# loc_median: 0.165
# dropped: variablesQty_median
# -----------------------------------------------------------------------------
# variablesQty_max | staticFieldsQty_max | 0.95
# variablesQty_max: -0.002
# staticFieldsQty_max: 0.028
# dropped: variablesQty_max
# -----------------------------------------------------------------------------
# protectedMethodsQty_sum | privateMethodsQty_sum | 0.91
# protectedMethodsQty_sum: 0.1
# privateMethodsQty_sum: 0.155
# dropped: protectedMethodsQty_sum
# -----------------------------------------------------------------------------
# tcc_sum | privateMethodsQty_sum | 0.92
# tcc_sum: -0.102
# privateMethodsQty_sum: 0.155
# dropped: tcc_sum
# -----------------------------------------------------------------------------
# tcc_average | lcc_average | 1.0
# tcc_average: 0.031
# lcc_average: 0.031
# dropped: lcc_average
# -----------------------------------------------------------------------------
# tcc_stdev | lcc_stdev | 1.0
# tcc_stdev: -0.008
# lcc_stdev: -0.008
# dropped: lcc_stdev
# -----------------------------------------------------------------------------
# tcc_median | lcc_median | 1.0
# tcc_median: -0.037
# lcc_median: -0.037
# dropped: lcc_median
# -----------------------------------------------------------------------------
# tcc_min | lcc_min | 1.0
# tcc_min: -0.058
# lcc_min: -0.058
# dropped: lcc_min
# -----------------------------------------------------------------------------
# privateFieldsQty_stdev | staticFieldsQty_max | 0.94
# privateFieldsQty_stdev: 0.014
# staticFieldsQty_max: 0.028
# dropped: privateFieldsQty_stdev
# -----------------------------------------------------------------------------
# privateFieldsQty_max | staticFieldsQty_max | 0.95
# privateFieldsQty_max: 0.026
# staticFieldsQty_max: 0.028
# dropped: privateFieldsQty_max
# -----------------------------------------------------------------------------
# finalMethodsQty_median | modifiers_median | 1.0
# finalMethodsQty_median: -0.108
# modifiers_median: -0.109
# dropped: finalMethodsQty_median
# -----------------------------------------------------------------------------
# innerClassesQty_sum | privateMethodsQty_sum | 0.95
# innerClassesQty_sum: 0.102
# privateMethodsQty_sum: 0.155
# dropped: innerClassesQty_sum
# -----------------------------------------------------------------------------
# comparisonsQty_sum | cbo_max | 0.91
# comparisonsQty_sum: 0.096
# cbo_max: 0.052
# dropped: cbo_max
# -----------------------------------------------------------------------------
# dropped columns:
# ['mathOperationsQty_sum', 'wmc_median', 'logStatementsQty_sum', 'tryCatchQty_sum', 'stringLiteralsQty_sum', 'lcc_min', 'defaultFieldsQty_average', 'modifiers_sum', 'staticFieldsQty_sum', 'totalMethodsQty_sum', 'parenthesizedExpsQty_sum', 'lcom_average', 'assignmentsQty_median', 'lcc_sum', 'privateFieldsQty_stdev', 'dit_sum', 'publicMethodsQty_stdev', 'cbo_max', 'innerClassesQty_sum', 'lambdasQty_stdev', 'finalFieldsQty_stdev', 'finalFieldsQty_max', 'totalMethodsQty_max', 'cbo_sum', 'abstractMethodsQty_average', 'lcc_stdev', 'visibleFieldsQty_max', 'publicMethodsQty_sum', 'staticMethodsQty_sum', 'assignmentsQty_sum', 'loc_sum', 'variablesQty_sum', 'logStatementsQty_median', 'wmc_average', 'variablesQty_median', 'protectedMethodsQty_sum', 'lcc_average', 'assignmentsQty_average', 'uniqueWordsQty_sum', 'publicMethodsQty_max', 'staticFieldsQty_stdev', 'rfc_sum', 'variablesQty_max', 'wmc_sum', 'protectedFieldsQty_sum', 'publicFieldsQty_max', 'abstractMethodsQty_stdev', 'publicFieldsQty_sum', 'abstractMethodsQty_median', 'privateFieldsQty_max', 'finalFieldsQty_sum', 'maxNestedBlocksQty_sum', 'abstractMethodsQty_sum', 'lcc_median', 'finalMethodsQty_median', 'publicMethodsQty_average', 'tcc_sum']
# -----------------------------------------------------------------------------
# used columns:
# ['synchronizedMethodsQty_sum', 'synchronizedMethodsQty_average', 'synchronizedMethodsQty_stdev', 'synchronizedMethodsQty_max', 'parenthesizedExpsQty_average', 'parenthesizedExpsQty_stdev', 'parenthesizedExpsQty_median', 'parenthesizedExpsQty_max', 'lcom_sum', 'lcom_stdev', 'lcom_median', 'lcom_max', 'publicMethodsQty_median', 'staticFieldsQty_average', 'staticFieldsQty_median', 'staticFieldsQty_max', 'publicFieldsQty_average', 'publicFieldsQty_stdev', 'publicFieldsQty_median', 'lambdasQty_sum', 'lambdasQty_average', 'lambdasQty_max', 'logStatementsQty_average', 'logStatementsQty_stdev', 'logStatementsQty_max', 'tryCatchQty_average', 'tryCatchQty_stdev', 'tryCatchQty_median', 'tryCatchQty_max', 'maxNestedBlocksQty_average', 'maxNestedBlocksQty_stdev', 'maxNestedBlocksQty_median', 'maxNestedBlocksQty_max', 'wmc_stdev', 'wmc_max', 'rfc_average', 'rfc_stdev', 'rfc_median', 'rfc_max', 'privateMethodsQty_sum', 'privateMethodsQty_average', 'privateMethodsQty_stdev', 'privateMethodsQty_median', 'privateMethodsQty_max', 'defaultMethodsQty_sum', 'defaultMethodsQty_average', 'defaultMethodsQty_stdev', 'defaultMethodsQty_median', 'defaultMethodsQty_max', 'nosi_sum', 'nosi_average', 'nosi_stdev', 'nosi_median', 'nosi_max', 'visibleFieldsQty_sum', 'visibleFieldsQty_average', 'visibleFieldsQty_stdev', 'uniqueWordsQty_average', 'uniqueWordsQty_stdev', 'uniqueWordsQty_median', 'uniqueWordsQty_max', 'stringLiteralsQty_average', 'stringLiteralsQty_stdev', 'stringLiteralsQty_median', 'stringLiteralsQty_max', 'anonymousClassesQty_sum', 'anonymousClassesQty_average', 'anonymousClassesQty_stdev', 'anonymousClassesQty_max', 'mathOperationsQty_average', 'mathOperationsQty_stdev', 'mathOperationsQty_median', 'mathOperationsQty_max', 'returnQty_sum', 'returnQty_average', 'returnQty_stdev', 'returnQty_median', 'returnQty_max', 'modifiers_average', 'modifiers_stdev', 'modifiers_median', 'modifiers_min', 'modifiers_max', 'abstractMethodsQty_max', 'protectedFieldsQty_average', 'protectedFieldsQty_stdev', 'protectedFieldsQty_median', 'protectedFieldsQty_max', 'numbersQty_sum', 'numbersQty_average', 'numbersQty_stdev', 'numbersQty_median', 'numbersQty_max', 'staticMethodsQty_average', 'staticMethodsQty_stdev', 'staticMethodsQty_median', 'staticMethodsQty_max', 'assignmentsQty_stdev', 'assignmentsQty_max', 'finalFieldsQty_average', 'finalFieldsQty_median', 'dit_average', 'dit_stdev', 'dit_median', 'dit_max', 'totalMethodsQty_average', 'totalMethodsQty_stdev', 'totalMethodsQty_median', 'loopQty_sum', 'loopQty_average', 'loopQty_stdev', 'loopQty_median', 'loopQty_max', 'defaultFieldsQty_sum', 'defaultFieldsQty_stdev', 'defaultFieldsQty_max', 'loc_average', 'loc_stdev', 'loc_median', 'loc_max', 'totalFieldsQty_sum', 'totalFieldsQty_average', 'totalFieldsQty_stdev', 'totalFieldsQty_median', 'totalFieldsQty_max', 'cbo_average', 'cbo_stdev', 'cbo_median', 'variablesQty_average', 'variablesQty_stdev', 'protectedMethodsQty_average', 'protectedMethodsQty_stdev', 'protectedMethodsQty_max', 'tcc_average', 'tcc_stdev', 'tcc_median', 'tcc_min', 'privateFieldsQty_sum', 'privateFieldsQty_average', 'privateFieldsQty_median', 'finalMethodsQty_sum', 'finalMethodsQty_average', 'finalMethodsQty_stdev', 'finalMethodsQty_max', 'innerClassesQty_average', 'innerClassesQty_stdev', 'innerClassesQty_max', 'comparisonsQty_sum', 'comparisonsQty_average', 'comparisonsQty_stdev', 'comparisonsQty_median', 'comparisonsQty_max', 'maven_reuse']

# %%
knn = KNeighborsClassifier(n_neighbors=5)

sfs = SFS(knn, 
          forward=False, 
          floating=True, 
          k_features=(1,27),
          scoring='f1_weighted',
          cv=4,
          n_jobs=-1)
sfs = sfs.fit(X_train, y_train)

print('Selected features:', sfs.k_feature_idx_, sfs.k_feature_names_)


print('CV Score:')
print(sfs.k_score_)
# Generate the new subsets based on the selected features
# Note that the transform call is equivalent to
# X_train[:, sfs1.k_feature_idx_]

X_train_sfs = sfs.transform(X_train)
X_test_sfs = sfs.transform(X_test)

# Fit the estimator using the new feature subset
# and make a prediction on the test data
knn.fit(X_train_sfs, y_train)
y_pred = knn.predict(X_test_sfs)

# Compute the accuracy of the prediction
acc = float((y_test == y_pred).sum()) / y_pred.shape[0]
print('Test set accuracy: %.2f %%' % (acc * 100))

sfs = SFS(knn, 
          forward=True, 
          floating=True, 
          k_features=(1,27),
          scoring='f1_weighted',
          cv=4,
          n_jobs=-1)
sfs = sfs.fit(X_train, y_train)

print('Selected features:', sfs.k_feature_idx_, sfs.k_feature_names_)


print('CV Score:')
print(sfs.k_score_)
# Generate the new subsets based on the selected features
# Note that the transform call is equivalent to
# X_train[:, sfs1.k_feature_idx_]

X_train_sfs = sfs.transform(X_train)
X_test_sfs = sfs.transform(X_test)

# Fit the estimator using the new feature subset
# and make a prediction on the test data
knn.fit(X_train_sfs, y_train)
y_pred = knn.predict(X_test_sfs)

# Compute the accuracy of the prediction
acc = float((y_test == y_pred).sum()) / y_pred.shape[0]
print('Test set accuracy: %.2f %%' % (acc * 100))

# %%
knn = DecisionTreeClassifier()

sfs = SFS(knn, 
          forward=False, 
          floating=True,
          k_features=(1,50),
          scoring='f1_weighted',
          cv=4,
          n_jobs=-1)
sfs = sfs.fit(X_train, y_train)

print('Selected features:', sfs.k_feature_idx_, sfs.k_feature_names_)


print('CV Score:')
print(sfs.k_score_)
# Generate the new subsets based on the selected features
# Note that the transform call is equivalent to
# X_train[:, sfs1.k_feature_idx_]

X_train_sfs = sfs.transform(X_train)
X_test_sfs = sfs.transform(X_test)

# Fit the estimator using the new feature subset
# and make a prediction on the test data
knn.fit(X_train_sfs, y_train)
y_pred = knn.predict(X_test_sfs)

# Compute the accuracy of the prediction
acc = float((y_test == y_pred).sum()) / y_pred.shape[0]
print('Test set accuracy: %.2f %%' % (acc * 100))

knn = DecisionTreeClassifier()

sfs = SFS(knn, 
          forward=True, 
          floating=True,
          k_features=(1,50),
          scoring='f1_weighted',
          cv=4,
          n_jobs=-1)
sfs = sfs.fit(X_train, y_train)

print('Selected features:', sfs.k_feature_idx_, sfs.k_feature_names_)


print('CV Score:')
print(sfs.k_score_)
# Generate the new subsets based on the selected features
# Note that the transform call is equivalent to
# X_train[:, sfs1.k_feature_idx_]

X_train_sfs = sfs.transform(X_train)
X_test_sfs = sfs.transform(X_test)

# Fit the estimator using the new feature subset
# and make a prediction on the test data
knn.fit(X_train_sfs, y_train)
y_pred = knn.predict(X_test_sfs)

# Compute the accuracy of the prediction
acc = float((y_test == y_pred).sum()) / y_pred.shape[0]
print('Test set accuracy: %.2f %%' % (acc * 100))

# %%
from sklearn import svm

knn = svm.SVC()

sfs = SFS(knn, 
          forward=False, 
          floating=True,
          k_features=(1,27),
          scoring='f1_weighted',
          cv=4,
          n_jobs=-1)
sfs = sfs.fit(X_train, y_train)

print('Selected features:', sfs.k_feature_idx_, sfs.k_feature_names_)


print('CV Score:')
print(sfs.k_score_)
# Generate the new subsets based on the selected features
# Note that the transform call is equivalent to
# X_train[:, sfs1.k_feature_idx_]

X_train_sfs = sfs.transform(X_train)
X_test_sfs = sfs.transform(X_test)

# Fit the estimator using the new feature subset
# and make a prediction on the test data
knn.fit(X_train_sfs, y_train)
y_pred = knn.predict(X_test_sfs)

# Compute the accuracy of the prediction
acc = float((y_test == y_pred).sum()) / y_pred.shape[0]
print('Test set accuracy: %.2f %%' % (acc * 100))

knn = svm.SVC()

sfs = SFS(knn, 
          forward=True, 
          floating=True,
          k_features=(1,27),
          scoring='f1_weighted',
          cv=4,
          n_jobs=-1)
sfs = sfs.fit(X_train, y_train)

print('Selected features:', sfs.k_feature_idx_, sfs.k_feature_names_)


print('CV Score:')
print(sfs.k_score_)
# Generate the new subsets based on the selected features
# Note that the transform call is equivalent to
# X_train[:, sfs1.k_feature_idx_]

X_train_sfs = sfs.transform(X_train)
X_test_sfs = sfs.transform(X_test)

# Fit the estimator using the new feature subset
# and make a prediction on the test data
knn.fit(X_train_sfs, y_train)
y_pred = knn.predict(X_test_sfs)

# Compute the accuracy of the prediction
acc = float((y_test == y_pred).sum()) / y_pred.shape[0]
print('Test set accuracy: %.2f %%' % (acc * 100))

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.tree import DecisionTreeClassifier
from model.support_vector_machine import SupportVectorMachine
from skopt.space import Real, Categorical, Integer
from skopt import BayesSearchCV
from sklearn.pipeline import Pipeline
import mlxtend
from sklearn.model_selection import GridSearchCV

data = data_loader.load_real_dataset(only_dt=True)

# Loading some example data
y_train = data['train_y']
y_test = data['test_y']
X_train = data['train_x']
X_test = data['test_x']

knn = DecisionTreeClassifier(criterion='gini',max_depth=6,max_features=3,min_samples_leaf=2, min_samples_split=2)

sfs = SFS(knn, 
          forward=False, 
          k_features=(1,7),
          scoring='accuracy',
          floating=True,
          cv=10,
          n_jobs=-1)
sfs = sfs.fit(X_train, y_train)

print('Selected features:', sfs.k_feature_idx_, sfs.k_feature_names_)


print('CV Score:')
print(sfs.k_score_)
# Generate the new subsets based on the selected features
# Note that the transform call is equivalent to
# X_train[:, sfs1.k_feature_idx_]

X_train_sfs = sfs.transform(X_train)
X_test_sfs = sfs.transform(X_test)

# Fit the estimator using the new feature subset
# and make a prediction on the test data
knn.fit(X_train_sfs, y_train)
y_pred = knn.predict(X_test_sfs)

# Compute the accuracy of the prediction
acc = float((y_test == y_pred).sum()) / y_pred.shape[0]
print('Test set accuracy: %.2f %%' % (acc * 100))

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.tree import DecisionTreeClassifier
from model.support_vector_machine import SupportVectorMachine
from skopt.space import Real, Categorical, Integer
from skopt import BayesSearchCV
from sklearn.pipeline import Pipeline
import mlxtend
from sklearn.model_selection import GridSearchCV

data = data_loader.load_real_dataset(only_pca=True)

# Loading some example data
y_train = data['train_y']
y_test = data['test_y']
X_train = data['train_x']
X_test = data['test_x']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
import mlxtend

knn = KNeighborsClassifier(n_neighbors=3)

sfs1 = SFS(estimator=knn, 
           k_features=(1,25),
           forward=False, 
           floating=True, 
           scoring='f1_weighted',
           cv=5)

pipe = Pipeline([('sfs', sfs1), 
                 ('knn', knn)])

param_grid = [
  {'sfs__k_features': range(1, 25),
   'sfs__estimator__n_neighbors': range(1,25),
  'sfs__estimator__metric': ['euclidean', 'manhattan', 'minkowski'],
  'sfs__estimator__weights': ['uniform', 'distance'],
  'sfs__estimator__p': range(1,20) }
  ]


gs = GridSearchCV(estimator=pipe, 
                  param_grid=param_grid, 
                  scoring='accuracy', 
                  n_jobs=1, 
                  cv=5,
                  iid=True,
                  refit=False)

# run gridearch
gs = gs.fit(X_train, y_train)

#
print("Best parameters via GridSearch", gs.best_params_)

print('Best features:', gs.best_estimator_.steps[0][1].k_feature_idx_)

print('Best score:', gs.best_score_)

gs.best_params_
# Out:
# STOPPING EARLY DUE TO KEYBOARD INTERRUPT...
# STOPPING EARLY DUE TO KEYBOARD INTERRUPT...
# STOPPING EARLY DUE TO KEYBOARD INTERRUPT...
# STOPPING EARLY DUE TO KEYBOARD INTERRUPT...
# STOPPING EARLY DUE TO KEYBOARD INTERRUPT...
# STOPPING EARLY DUE TO KEYBOARD INTERRUPT...
# STOPPING EARLY DUE TO KEYBOARD INTERRUPT...
# STOPPING EARLY DUE TO KEYBOARD INTERRUPT...
# STOPPING EARLY DUE TO KEYBOARD INTERRUPT...
# STOPPING EARLY DUE TO KEYBOARD INTERRUPT...
# STOPPING EARLY DUE TO KEYBOARD INTERRUPT...

# %%
knn = KNeighborsClassifier()

sfs = SFS(knn, 
          forward=False, 
          floating=True, 
          k_features=(1,25),
          scoring='f1_weighted',
          cv=4,
          n_jobs=-1)
sfs = sfs.fit(X_train, y_train)

print('Selected features:', sfs.k_feature_idx_, sfs.k_feature_names_)

print('CV Score:')
print(sfs.k_score_)
# Generate the new subsets based on the selected features
# Note that the transform call is equivalent to
# X_train[:, sfs1.k_feature_idx_]

X_train_sfs = sfs.transform(X_train)
X_test_sfs = sfs.transform(X_test)

# Fit the estimator using the new feature subset
# and make a prediction on the test data
knn.fit(X_train_sfs, y_train)
y_pred = knn.predict(X_test_sfs)

# Compute the accuracy of the prediction
acc = float((y_test == y_pred).sum()) / y_pred.shape[0]
print('Test set accuracy: %.2f %%' % (acc * 100))
# Out:
# Selected features: (2, 14, 17, 19, 23, 24) ('lcc_min', 'anonymousClassesQty_average', 'lcc_median', 'defaultMethodsQty_median', 'returnQty_median', 'maxNestedBlocksQty_max')
# CV Score:
# 0.5906931015451348
# Test set accuracy: 44.44 %

# %%
knn = DecisionTreeClassifier(criterion='gini', max_depth=5, max_features=7, min_impurity_decrease=0)

sfs = SFS(knn, 
          forward=False, 
          floating=True,
          k_features=(1,25),
          scoring='f1_weighted',
          cv=4,
          n_jobs=-1)
sfs = sfs.fit(X_train, y_train)

print('Selected features:', sfs.k_feature_idx_, sfs.k_feature_names_)


print('CV Score:')
print(sfs.k_score_)
# Generate the new subsets based on the selected features
# Note that the transform call is equivalent to
# X_train[:, sfs1.k_feature_idx_]

X_train_sfs = sfs.transform(X_train)
X_test_sfs = sfs.transform(X_test)

# Fit the estimator using the new feature subset
# and make a prediction on the test data
knn.fit(X_train_sfs, y_train)
y_pred = knn.predict(X_test_sfs)

# Compute the accuracy of the prediction
acc = float((y_test == y_pred).sum()) / y_pred.shape[0]
print('Test set accuracy: %.2f %%' % (acc * 100))
# Out:
# Selected features: (0, 2, 5, 7, 10, 15, 17, 20, 21, 24) ('privateMethodsQty_sum', 'lcc_min', 'modifiers_stdev', 'dit_median', 'totalFieldsQty_stdev', 'loc_max', 'lcc_median', 'finalFieldsQty_median', 'modifiers_max', 'maxNestedBlocksQty_max')
# CV Score:
# 0.5393637810089366
# Test set accuracy: 37.04 %

# %%
from sklearn import svm

knn = svm.SVC(C=50, decision_function_shape='ovo', gamma=1, kernel='rbf')

sfs = SFS(knn, 
          forward=False, 
          floating=True,
          k_features=(1,25),
          scoring='f1_weighted',
          cv=4,
          n_jobs=-1)
sfs = sfs.fit(X_train, y_train)

print('Selected features:', sfs.k_feature_idx_, sfs.k_feature_names_)


print('CV Score:')
print(sfs.k_score_)
# Generate the new subsets based on the selected features
# Note that the transform call is equivalent to
# X_train[:, sfs1.k_feature_idx_]

X_train_sfs = sfs.transform(X_train)
X_test_sfs = sfs.transform(X_test)

# Fit the estimator using the new feature subset
# and make a prediction on the test data
knn.fit(X_train_sfs, y_train)
y_pred = knn.predict(X_test_sfs)

# Compute the accuracy of the prediction
acc = float((y_test == y_pred).sum()) / y_pred.shape[0]
print('Test set accuracy: %.2f %%' % (acc * 100))
# Out:
# Selected features: (2, 3, 4, 5, 8, 9, 10, 11, 14, 15, 17, 21, 24) ('lcc_min', 'abstractMethodsQty_stdev', 'parenthesizedExpsQty_max', 'modifiers_stdev', 'loc_stdev', 'modifiers_average', 'totalFieldsQty_stdev', 'defaultMethodsQty_max', 'anonymousClassesQty_average', 'loc_max', 'lcc_median', 'modifiers_max', 'maxNestedBlocksQty_max')
# CV Score:
# 0.5606533573392197
# Test set accuracy: 33.33 %

# %%
# cfs
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.tree import DecisionTreeClassifier
from model.support_vector_machine import SupportVectorMachine
from sklearn.pipeline import Pipeline
import mlxtend
from sklearn.model_selection import GridSearchCV

data = data_loader.load_real_dataset(sqaured=False, remove_multicollinearity=False)
output_xy = pre_training_analysis_tools.variance_threshold(data['train_x'],data['train_y'])
split_xy = pre_training_analysis_tools.split_dataxy(output_xy)
x = split_xy['train_x']
y = split_xy['train_y']

x = x.iloc[:, [32, 131,  33,  39, 174,  26, 132, 144,   9,  10,  15,  20]]

data_xy = pre_training_analysis_tools.join_dataxy(x, y)
data = pre_training_analysis_tools.generate_train_test_xy(data_xy)

# Loading some example data
y_train = data['train_y']
y_test = data['test_y']
X_train = data['train_x']
X_test = data['test_x']
# Out:
# Original feature shape: (216, 265)
# Transformed feature shape: (216, 209)

# %%
knn = KNeighborsClassifier(leaf_size=1, metric='manhattan', 
                             n_neighbors=23, p=0.1, weights='distance')

sfs = SFS(knn, 
          forward=False, 
          floating=True, 
          k_features=(1,12),
          scoring='f1_weighted',
          cv=4,
          n_jobs=-1)
sfs = sfs.fit(X_train, y_train)

print('Selected features:', sfs.k_feature_idx_, sfs.k_feature_names_)

print('CV Score:')
print(sfs.k_score_)
# Generate the new subsets based on the selected features
# Note that the transform call is equivalent to
# X_train[:, sfs1.k_feature_idx_]

X_train_sfs = sfs.transform(X_train)
X_test_sfs = sfs.transform(X_test)

# Fit the estimator using the new feature subset
# and make a prediction on the test data
knn.fit(X_train_sfs, y_train)
y_pred = knn.predict(X_test_sfs)

# Compute the accuracy of the prediction
acc = float((y_test == y_pred).sum()) / y_pred.shape[0]
print('Test set accuracy: %.2f %%' % (acc * 100))
# Out:
# Selected features: (0, 2, 3, 6, 8, 9, 10, 11) ('lambdasQty_max', 'logStatementsQty_sum', 'tryCatchQty_average', 'assignmentsQty_sum', 'lcom_sum', 'lcom_average', 'publicMethodsQty_average', 'staticFieldsQty_average')
# CV Score:
# 0.5178990224720237
# Test set accuracy: 47.83 %

# %%
knn = DecisionTreeClassifier()

sfs = SFS(knn, 
          forward=False, 
          floating=True,
          k_features=(1,12),
          scoring='f1_weighted',
          cv=4,
          n_jobs=-1)
sfs = sfs.fit(X_train, y_train)

print('Selected features:', sfs.k_feature_idx_, sfs.k_feature_names_)


print('CV Score:')
print(sfs.k_score_)
# Generate the new subsets based on the selected features
# Note that the transform call is equivalent to
# X_train[:, sfs1.k_feature_idx_]

X_train_sfs = sfs.transform(X_train)
X_test_sfs = sfs.transform(X_test)

# Fit the estimator using the new feature subset
# and make a prediction on the test data
knn.fit(X_train_sfs, y_train)
y_pred = knn.predict(X_test_sfs)

# Compute the accuracy of the prediction
acc = float((y_test == y_pred).sum()) / y_pred.shape[0]
print('Test set accuracy: %.2f %%' % (acc * 100))
# Out:
# Selected features: (4, 9, 10) ('cbo_median', 'lcom_average', 'publicMethodsQty_average')
# CV Score:
# 0.5156632589555166
# Test set accuracy: 34.78 %

# %%
from sklearn import svm

data = data_loader.load_real_dataset(sqaured=False, remove_multicollinearity=False)
output_xy = pre_training_analysis_tools.variance_threshold(data['train_x'],data['train_y'])
split_xy = pre_training_analysis_tools.split_dataxy(output_xy)
x = split_xy['train_x']
y = split_xy['train_y']

x = x.iloc[:, [32, 131,  33,  39, 174,  26, 132, 144,   9,  10,  15,  20]]

data_xy = pre_training_analysis_tools.join_dataxy(x, y)
data = pre_training_analysis_tools.generate_train_test_xy(data_xy)

# Loading some example data
y_train = data['train_y']
y_test = data['test_y']
X_train = data['train_x']
X_test = data['test_x']

knn = svm.SVC(C=10,gamma=1750,kernel='rbf')

sfs = SFS(knn, 
          forward=False, 
          floating=True,
          k_features=(1,12),
          scoring='f1_weighted',
          cv=4,
          n_jobs=-1)
sfs = sfs.fit(X_train, y_train)

print('Selected features:', sfs.k_feature_idx_, sfs.k_feature_names_)


print('CV Score:')
print(sfs.k_score_)
# Generate the new subsets based on the selected features
# Note that the transform call is equivalent to
# X_train[:, sfs1.k_feature_idx_]

X_train_sfs = sfs.transform(X_train)
X_test_sfs = sfs.transform(X_test)

# Fit the estimator using the new feature subset
# and make a prediction on the test data
knn.fit(X_train_sfs, y_train)
y_pred = knn.predict(X_test_sfs)

# Compute the accuracy of the prediction
acc = float((y_test == y_pred).sum()) / y_pred.shape[0]
print('Test set accuracy: %.2f %%' % (acc * 100))
# Out:
# Original feature shape: (216, 265)
# Transformed feature shape: (216, 209)
# Selected features: (0, 3, 6, 7, 8) ('lambdasQty_max', 'tryCatchQty_average', 'assignmentsQty_sum', 'dit_stdev', 'lcom_sum')
# CV Score:
# 0.532271713793453
# Test set accuracy: 30.43 %

# %%
# testing
from sklearn.neighbors import KNeighborsClassifier
import numpy as np

data = data_loader.load_real_dataset(only_dt=True)

# Loading some example data
y_train = data['train_y']
y_test = data['test_y']
X_train = data['train_x']
X_test = data['test_x']

display(X_train.shape[1])
display(X_train.shape[0])
display(X_train.shape)
arr = [1,2,3,4,5,6,7]

knn = KNeighborsClassifier(metric='wminkowski', p=2, 
                           metric_params={'w': np.random.random(X_train.shape[1])})


knn.fit(X_train, y_train)
knn_y_pred = knn.predict(X_test)
print(accuracy_score(y_train, knn.predict(X_train)))
print(accuracy_score(y_test, knn_y_pred))
# Out:
# 7
# 189
# (189, 7)
# 0.6772486772486772
# 0.4074074074074074
